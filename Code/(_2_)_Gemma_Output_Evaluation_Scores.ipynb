# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
# !pip install transformers # If you are using collab, "!" is required to download
# !pip install bert-score
# !pip install -U sentence-transformers

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer

# Download NLTK resources
nltk.download('punkt')
nltk.download('wordnet')

# %%
import os, json
import numpy as np
from argparse import ArgumentParser
from tqdm import tqdm
from collections import defaultdict
import pandas as pd
from pprint import pprint
import re, string
from google.colab import files

from transformers import BertTokenizer, BertModel
from sentence_transformers import SentenceTransformer, util
import torch
import copy

# %% [markdown]
# ## Calculating evaluation scores

# %%
def read_json_file(name):
    with open(name, 'r') as f:
        data = json.load(f)
        return data

def save_json(json_data, file_name):
    json_data = json.dumps(json_data)
    print(file_name)
    with open(file_name, "w") as json_file:
          json_file.write(json_data)

# %%
# def perform_lemmatization(text):

#     # Tokenize the text into words
#     words = word_tokenize(text)
#     lemmatizer = WordNetLemmatizer()
#     stemmer = PorterStemmer()
#     lemmatized_and_stemmed_words = [(lemmatizer.lemmatize(word), stemmer.stem(word)) for word in words]

#     lemmatized_words, stemmed_words = zip(*lemmatized_and_stemmed_words)
#     lemmatized_text = ' '.join(lemmatized_words)
#     stemmed_text = ' '.join(stemmed_words)

#     # print("Original text:", text)
#     # print("Lemmatized text:", lemmatized_text)
#     # print("Stemmed text:", stemmed_text)
#     return stemmed_text

def clac_sbert_score(text1, text2):
    model = SentenceTransformer("all-MiniLM-L6-v2")

    embeddings1 = model.encode(text1, convert_to_tensor=True)
    embeddings2 = model.encode(text2, convert_to_tensor=True)

    cosine_score = util.cos_sim(embeddings1, embeddings2)
    #print(cosine_score.item())
    return cosine_score.item()

def calc_cosine_similarity(text1, text2):

    tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
    model = BertModel.from_pretrained("bert-base-uncased")

    # text1 = perform_lemmatization(text1)
    # text2 = perform_lemmatization(text2)

    inputs1 = tokenizer(text1, return_tensors="pt", padding=True, truncation=True)
    inputs2 = tokenizer(text2, return_tensors="pt", padding=True, truncation=True)

    outputs1 = model(**inputs1)
    outputs2 = model(**inputs2)

    embeddings1 = outputs1.last_hidden_state.mean(dim=1).detach().numpy()
    embeddings2 = outputs2.last_hidden_state.mean(dim=1).detach().numpy()

    #Calculate cosine similarity
    similarity = np.dot(embeddings1, embeddings2.T) / (np.linalg.norm(embeddings1) * np.linalg.norm(embeddings2))

    #print("Similarity between the texts:", similarity)
    return similarity[0][0]

# %%
def is_null_or_empty(string):
    return string is None or string.strip().lower() == 'null' or string.strip() == ''

def normalize_string(s):
      def remove_articles(text):
          regex = re.compile(r'\b(a|an|the)\b', re.UNICODE)
          return re.sub(regex, ' ', text)
      def white_space_fix(text):
          return ' '.join(text.split())
      def remove_punc(text):
          exclude = set(string.punctuation)
          return ''.join(ch for ch in text if ch not in exclude)
      def lower(text):
          return text.lower()
      return white_space_fix(remove_articles(remove_punc(lower(s))))


def calculate_score(predictions, ground_truth_labels, similarity_threshold):
    true_pos, pred_count, gtruth_count = 0, len(predictions), len(ground_truth_labels)

    if ((len(ground_truth_labels)==1 and is_null_or_empty(ground_truth_labels[0]))): #only not calculating when ground-truth is null
        #print("xxx ", predictions, labels) #(len(predictions)==1 and is_null_or_empty(predictions[0]))
        return 0, 0, 0 #skipping this sample
    else:
        actual_labels = copy.deepcopy(ground_truth_labels)
        # print(predictions, actual_labels)
        # print(len(predictions), len(actual_labels))
        for p in predictions:
            for g in actual_labels:
                if(g.strip() == ''): gtruth_count -=1 ## if any ground-truth is empty reducing that count.
                if(is_null_or_empty(p) or is_null_or_empty(g)): continue ##if prediction/ground-truth is null then skip
                np, ng = normalize_string(p), normalize_string(g)
                sim_value = calc_cosine_similarity(np,ng)
                sbert_score = clac_sbert_score(np, ng)
                print(np, ng, sim_value, sbert_score)
                if(sim_value>similarity_threshold or sbert_score>similarity_threshold):
                    true_pos += 1
                    actual_labels.remove(g)
        # print(predictions, labels)
        # print(true_pos, pred_count, gtruth_count)
        return true_pos, pred_count, gtruth_count

def calc_precision_recall_f1(true_pos, pred_count, gtruth_count):
    print(true_pos, pred_count, gtruth_count)
    precision = true_pos/(pred_count + 1e-10)
    recall = true_pos/(gtruth_count + 1e-10)
    f1 = 2 * precision * recall / (precision + recall + 1e-10)
    return precision, recall, f1

# %%
def select_event_specific_data(event, data):
    ev_data = []
    for dt in data:
        if event==dt['label']:
            ev_data.append(dt)
    return ev_data

def calc_results(all_data, event_types, arg_types, events_roles, pred_name, gtruth_name, similarity_threshold):
    results = {}
    for event in event_types:
        results[event] = {}
        for arg_type in arg_types:
            results[event][arg_type] = {}
            arguments = list(events_roles[event][arg_type].keys())
            for arg in arguments:
                tp, pc, gc = 0, 0, 0 #initialize the true_positive, pred_count, ground_truth-count for each arguments
                event_specifc_data = select_event_specific_data(event, all_data) ##geting the data for a specific event type.
                for dt in event_specifc_data:
                    label = dt['label']
                    pred_list = dt[pred_name][arg_type][arg] #predictions
                    gtruth_list = dt[gtruth_name][arg_type][arg] #ground-truth arguments
                    #print(pred_list, gtruth_list)
                    true_pos, pred_count, gtruth_count = 0, 0, 0
                    try:
                       true_pos, pred_count, gtruth_count = calculate_score(pred_list,
                                                                         gtruth_list, similarity_threshold)
                    except:
                        print(event, arg_type, arg)
                        print(pred_list, gtruth_list)
                        print("Error occured at", dt['doc_id'])

                    tp+= true_pos
                    pc+= pred_count
                    gc+= gtruth_count
                if(gc==0):
                    continue #skiping those values, where we do not have any ground truth.

                precision, recall, f1 = calc_precision_recall_f1(tp, pc, gc)
                print(event, arg_type, arg, precision, recall, f1)
                #saving the values in two items is a list
                #first item has (precision, recall, f1 scores) #second item has (true_pos, pred_count, ground_truth_count values)
                results[event][arg_type][arg]= [[precision, recall, f1], [tp, pc, gc]]

    return results

# %%
# %%time

events_roles = read_json_file('Final-Data/role_definitions.json')

prompt_types = ['batch'] #['batch', 'isolated']
exp_types = ['description_guided', 'question_guided']
event_types = ['taking-moud', 'tapering', 'relapse']
arg_types = ['main-arguments', 'event-specific-arguments', 'subject-effect-arguments']
similarity_threshold = [0.749, 0.99]

number = '1'
name = 'gemma-1.1-7b-it'
folder_path = 'Argument-Extraction-Predictions'
file_name = f'{number}-processed-{name}_test_100_predictions.json'
print(os.path.join(folder_path, file_name))
all_data = read_json_file(os.path.join(folder_path, file_name))

print(all_data[0].keys())
print(len(all_data))
# Out:
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Predictions/1-processed-gemma-1.1-7b-it_test_100_predictions.json
# dict_keys(['doc_id', 'id', 'text1', 'text2', 'label', 'thread-length', 'ground-truth-arguments', 'raw-batch_description_guided-predictions', 'raw-batch_question_guided-predictions', 'processed-batch_description_guided-predictions', 'processed-batch_question_guided-predictions'])
# 100
# CPU times: user 21.1 ms, sys: 1.41 ms, total: 22.5 ms
# Wall time: 34.6 ms

# %%
# %%time
numbers = ['0', '1', '2']

for number in numbers:
    file_name = f'{number}-processed-{name}_test_100_predictions.json'
    all_data = read_json_file(os.path.join(folder_path, file_name))

    results_dict = {}
    for p_type in prompt_types:
          for e_type in exp_types:
              g_name = 'ground-truth-arguments'
              p_name = f'processed-{p_type}_{e_type}-predictions'
              for s_t in similarity_threshold:
                  print(p_type, e_type, s_t)
                  results = calc_results(all_data, event_types, arg_types, events_roles,
                            p_name, g_name, s_t)
                  save_json(results, f'results-{name}{p_type}_{e_type}_{s_t}.json')
                  results_dict[f'{p_type}_{e_type}_{s_t}']=results


    result_folder_path = 'Argument-Extraction-Results'
    save_json(results_dict, os.path.join(result_folder_path,f'{number}-new-results-{name}.json'))
# Out:
# batch description_guided 0.749
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# 3 mg 3mg 0.79855776 0.9231275320053101
# 0 mg 0mg 0.77785414 0.8933465480804443
# 24 mg 0 mg 0.88468564 0.7035747766494751
# not specified 0125 mg 0.52931577 0.2684679925441742
# 1mg daily 1 mg 0.71297705 0.7789731025695801
# 2530 2530 1.0 1.0
# 34 mg 34 mg 1.0 1.0000001192092896
# 2mg 2mgday 0.74059576 0.7435450553894043
# 24mg 24mg 1.0 1.0
# 5 15 15
# tapering event-specific-arguments current-dosage 0.3333333333311111 0.3333333333311111 0.3333333332811111
# reduce to 05mg per day 05mg day 0.62965655 0.739357590675354
# reduce anxiety and promote sleep 0 0.38739446 0.048865750432014465
# not specified 0mg 0.61207116 0.31904178857803345
# quitting quit or 0mg 0.6968701 0.5923405885696411
# none specified 0mg 0.6654887 0.3554092049598694
# none 0mg 0.677158 0.3613886833190918
# none 0mg 0.677158 0.3613886833190918
# not mentioned 0 mg 0.57867646 0.14579439163208008
# sleep improvement 0 mg 0.58218133 0.1169113740324974
# not specified 0 mg 0.6092585 0.29779237508773804
# 25 25 1.0 1.0
# relief of withdrawal symptoms quit all opiates 0.6596962 0.41970717906951904
# none 0 mg 0.6587009 0.36292019486427307
# getting off subs 0 mg 0.52864146 0.10845574736595154
# none specified 0mg 0.6654887 0.3554092049598694
# getting off suboxone 0mg 0.5156838 0.2243388593196869
# 0mg 0mg 0.9999999 1.0
# 2 21 21
# tapering event-specific-arguments goal-dosage 0.09523809523764173 0.09523809523764173 0.09523809518764173
# not specified 1 month 0.6414475 0.2912513017654419
# 0 5 5
# tapering event-specific-arguments target-duration 0.0 0.0 0.0
# 40 40 1.0000001 1.000000238418579
# 1 1 1
# tapering subject-effect-arguments age 0.9999999999 0.9999999999 0.99999999985
# 0 2 2
# tapering subject-effect-arguments gender 0.0 0.0 0.0
# anxiety recovering from suboxone kratom 0.4439094 0.09377489984035492
# suboxone withdrawal recovering from suboxone kratom 0.75063425 0.6407420635223389
# subutex dependence subutex dependence 0.99999994 1.0000001192092896
# declining health issues declining health issues 0.9999999 1.0
# 2 8 7
# tapering subject-effect-arguments conditions 0.249999999996875 0.2857142857102041 0.2666666666133333
# rls restless leg syndrome 0.4732038 0.17667126655578613
# sneezing fits sneezing fits 0.99999994 1.0
# super acidity feeling ill 0.59932923 0.12296406924724579
# gummy junk in sinuses feeling ill 0.52842915 0.12432816624641418
# anxiety physical dependency to kratom 0.54255617 0.10782419890165329
# anxiety ruined liver 0.7657228 0.13003987073898315
# sleep problems physical dependency to kratom 0.4767706 -0.025382360443472862
# sleep problems ruined liver 0.57565254 0.04359515756368637
# withdrawal symptoms detox 0.66396064 0.3056602478027344
# runny nose runny nose 1.0 0.9999999403953552
# nose running sick 0.70986927 0.2573973536491394
# nose running nose running 1.0 1.0000001192092896
# colder than usual sick 0.60894454 0.29008057713508606
# colder than usual colder 0.58117485 0.7775408625602722
# sneezing sneezing 1.0 1.0
# sneezing insomnia 0.6283476 0.3201625943183899
# yawning yawning 1.0000001 0.9999999403953552
# insomnia insomnia 1.0 1.0
# head
# how individual is described or characterized individual eager to enjoy relapsing on bupe patches 0.57155275 0.018685704097151756
# how individual feels or describes their experience individual relapses with oxycodone and percocet 0.46726197 0.10291855037212372
# how can you describe individual or patient experiencing relapse person quitting h with support group help 0.6455642 0.3344583511352539
# individual trapped in addiction for 5 years individual who wants to start subs 0.65827245 0.17696885764598846
# scared but determined to get off individual who wants to start subs 0.6059801 0.1869347095489502
# how can you describe individual or patient experiencing relapse individual relapsed with beers and wants to taper with subacade 0.6552841 0.44727835059165955
# how can you describe individual or patient experiencing relapse indivdual took kratom during withdrawal treatment 0.58753103 0.24686039984226227
# how can you describe individual or patient experiencing relapse individual aiming to taper dirty 30s 0.55558926 0.014554072171449661
# how can you describe individual or patient experiencing relapse indivdual trying to switch from heroin to suboxone 0.6247953 0.23820549249649048
# relapse history and current dosage individual who relapsed after being on suboxone for past year 0.7571081 0.5836805105209351
# relapsing fentanyl user individual quitting fentanyl 0.84388435 0.7279096841812134
# financial necessity individual restarting subs 0.58906907 -0.028874102979898453
# individual experienced relapse after year of sobriety individual quitting cold turkey for kratom dependency 0.59525985 0.33466053009033203
# fearful state indivdual who snorted suboxone in fear of overdosing 0.38406184 0.1231732964515686
# new user experiencing relapse person struggling to get back to subs after relapse 0.81186426 0.7148723006248474
# feeling sick and in pain individual who relapsed on fentanyl 30 0.46702373 0.05274473503232002
# feeling stressed and wanting to stay clean individual on suboxone who used to use weed but now uses fentanyl for insomnia 0.5252095 0.09178707748651505
# how can you describe individual or patient experiencing relapse individual trying to quit fent 0.5783274 0.3443916440010071
# brief description of individuals relapse experience individual relapsed on heroin for 34 days and aims to resume moud 0.7421465 0.5541696548461914
# how can you describe individual or patient experiencing relapse patient asking about drinking on suboxone 0.65154606 0.23573526740074158
# relapse experience of opioid user individual switching from fent to subs using oxy 0.58216876 0.18082295358181
# individual is experiencing confusion and anxiety about lack of effect of suboxone on their cocaine high patient whose use of suboxone blocks cocaine high 0.86932856 0.7718769907951355
# how can you describe individual or patient experiencing relapse individual taking substances and wants to start suboxone 0.6598643 0.237418532371521
# scatterbrained individual anticipating precipitated withdrawal 0.5294341 -0.05652020126581192
# sleep deprivation individual anticipating precipitated withdrawal 0.51941013 0.2466541826725006
# personal experience individual wondering if kratom helps with withdrawals 0.5183228 0.10544277727603912
# feeling withdrawal symptoms from dirty 30 withdrawals individual wants to quit from 75mg suboxone 0.6599294 0.3377521336078644
# experiencing severe withdrawal symptoms individual starting intake after last heroin dose 0.5845993 0.31075310707092285
# relapse history and current symptoms individual who uses subutex but relapsed on heroin 0.65461195 0.3944154381752014
# relapse is characterized by uncontrolled substance use despite negative consequences individual relapses with lots of medications 0.79054296 0.7391403913497925
# how can you describe individual or patient experiencing relapse indivdual in pain planning to use kratom 0.6684993 0.18884044885635376
# 0 39 36
# relapse main-arguments subject/patient 0.0 0.0 0.0
# using fentanyl daily using around 1015 strong pressed 30’s daily 0.4261812 0.3143704831600189
# selfmedication with kratom and other substances taking kratom 0.59747314 0.6724952459335327
# selfmedication with kratom and other substances subs 0.39050987 -0.05778300017118454
# selfmedication with kratom and other substances oxy 0.34561673 0.052604980766773224
# selfmedication with kratom and other substances diluadin 0.47203287 0.09193097054958344
# accidental use of fentanyl relapse to fent and percs 0.5457971 0.2789781987667084
# manner in which taking or using addictive substances occurs relapsing with morphine soon 0.64333594 0.34229472279548645
# act of taking or using addictive substances 20mg oxycodone this morning 0.593419 0.34603410959243774
# act of taking or using addictive substances percs last night and this morning 0.45793343 0.060845762491226196
# how does occurrence of taking or using addictive substances happen back and forth between h and subs 0.4860091 -0.005338216200470924
# takingusing addictive substances despite previous addiction struggles high dosing thc 0.6142846 0.38785845041275024
# how does occurrence of taking or using addictive substances happen relapsed with beer on fathers day 0.64578813 0.21818852424621582
# how does occurrence of taking or using addictive substances happen took 3g of kratom 0.5000975 0.08180147409439087
# how does occurrence of taking or using addictive substances happen taking heroin 0.63366425 0.5306225419044495
# accidental relapse havent taken suboxone since friday 0.5083722 0.21709120273590088
# taking kratom while on suboxone relapsing on fent after cold turkey withdrawal 0.60810983 0.19920498132705688
# immediate use of opioids using opioids after last dose of suboxone 0.817423 0.6674492955207825
# cold turkey cessation of kratom dependency h and fent 0.3678785 0.0319315567612648
# taking 8mg of subconscious with barely no tolerance snorted 8mg suboxone 0.7306706 0.41211870312690735
# accidental use of oxycodone took oxy 30sfentanyl 0.64440215 0.5279788970947266
# selfadministration of fentanyl relapsed at 1130pm last night 0.49309468 0.0650017037987709
# using fentanyl for sleep despite being on suboxone use fentanyl for sleep 0.81557494 0.8647075891494751
# relapse occurred due to taking heroin relapse on heroin for 34 days 0.8637481 0.8013895750045776
# how does occurrence of taking or using addictive substances happen drinking on suboxone 0.5941493 0.3426471948623657
# taking cocaine despite being on suboxone used coke and adderole while on suboxone 0.7264552 0.7899413108825684
# how does occurrence of taking or using addictive substances happen taking blues 0.40156907 0.1167948842048645
# how does occurrence of taking or using addictive substances happen bars 0.31135264 0.11234043538570404
# how does occurrence of taking or using addictive substances happen and ice 0.37762713 0.05188595876097679
# taking buprenorphine tablets kratom 0.51277554 0.16018038988113403
# taking buprenorphine tablets h 0.34204075 -0.06088069826364517
# friends recommendation used kratom to get off subs 0.51808655 0.05000557005405426
# taking subs for 4 days without enough research dirty 30s and potential use of kratom if needed 0.600371 0.12899979948997498
# taking first dose too soon after last one patient relapsing on heroin 0.63158953 0.3488370180130005
# substance use relapse after 3 years of sobriety relapsed 6 months ago 0.7910148 0.6495071053504944
# substance use relapse after 3 years of sobriety using 15 g herion per day 0.56773645 0.03140250965952873
# taking multiple medications concurrently without proper supervision 3mg clonazepam 0.55860716 0.2360728234052658
# taking multiple medications concurrently without proper supervision 2mg buprenophine 0.5438411 0.19442075490951538
# taking multiple medications concurrently without proper supervision 300mg pregabalin 0.42603004 0.2378333956003189
# how does occurrence of taking or using addictive substances happen considering using kratom while on suboxone 0.50747764 0.15668928623199463
# 0 29 39
# relapse main-arguments relapse-event 0.0 0.0 0.0
# hot soaks getting suboxone 0.5000957 0.05870421603322029
# imodium getting suboxone 0.65217155 0.25576236844062805
# distractions getting suboxone 0.57476026 -0.006978623569011688
# walks getting suboxone 0.61082876 0.005174662917852402
# gradually increasing dose of subs wants to start bernese method 0.6115844 0.2003481686115265
# seeking medical guidance for benzodiazepine withdrawal hoping to get more help than suboxone to quit benzos 0.7074518 0.5360379219055176
# gradual titration of suboxone subs 0.44183448 0.11502804607152939
# actions or intentions following last relapse dose possible use of current bupe patch 0.6157212 0.1783769726753235
# actions or steps taken after last relapse dose taking 1mg or less of suboxone and gaging feeling before taking other 1mg 0.6756375 0.24395693838596344
# what are events subject is doing or intends to follow after last relapse dose subs 0.38613647 -0.013029053807258606
# waiting for next dose of subs starting subs tomorrow morning 0.7555686 0.5621254444122314
# what are events subject is doing or intends to follow after last relapse dose planing to take subacade 0.6025786 0.23616188764572144
# what are events subject is doing or intends to follow after last relapse dose following withdrawl procedure again 0.59882534 0.46518033742904663
# what are events subject is doing or intends to follow after last relapse dose regular use of subs 0.49477994 0.0016140006482601166
# what are events subject is doing or intends to follow after last relapse dose plans to get on suboxone fully 0.6033912 0.29808253049850464
# continue suboxone continuing suboxone 0.9321879 0.9760569334030151
# tapering off fentanyl concurrently with suboxone bernese method with sub 0.4718906 0.20343978703022003
# gradually increase dosage plans to start subs with 4mg am 0.6129176 0.362422376871109
# gradually increase dosage 4pm 0.5042818 0.018177226185798645
# transitioned to suboxone subs after year 0.58616847 0.30623313784599304
# attempting to return to suboxone suboxone 0.7110688 0.7273442149162292
# taking more subs took sub at 630am 0.626477 0.5197069644927979
# taking otc sleep meds or ambien taking suboxone while relapsing 0.7655125 0.252410352230072
# what are events subject is doing or intends to follow after last relapse dose wants to start suboxone 0.62566006 0.19292987883090973
# unknown considering taking small piece of moud 0.41107985 0.05158202722668648
# what are events subject is doing or intends to follow after last relapse dose suboxone 0.4021092 0.11026743054389954
# what are events subject is doing or intends to follow after last relapse dose wants to start moud 0.5949208 0.1633182018995285
# dissolving under tongue buprenorphine tablets 0.4555609 0.17404624819755554
# not specified moud intake after waiting for 20 hours 0.47255975 0.06516678631305695
# transitioning to methadone treatment plans to use methadone 0.7949959 0.8126351833343506
# what are events subject is doing or intends to follow after last relapse dose plans to continue treatment 0.53371114 0.6024035215377808
# 0 30 28
# relapse main-arguments resuming-moud-after-relapse 0.0 0.0 0.0
# potential for sweating and withdrawal symptoms possible sweating and withdrawal symptoms if dose is too high 0.88631344 0.8276408314704895
# unknown feeling very sick from kratom 0.42769736 0.09833991527557373
# but hopes for better outcomes than previous treatments feeling very sick from kratom 0.5322922 0.13817480206489563
# uncertain concerned about precipitated withdrawal 0.41969243 0.16025620698928833
# potential for relief from withdrawal symptoms cold turkey withdrawal 0.5201913 0.5461227893829346
# throwing up and nodding out possible overdose 0.5373269 0.30023983120918274
# suboxone not effective for withdrawal symptoms normal withdrawal symptoms despite full dose 0.80021197 0.5964345932006836
# knee pain sickness 0.59294045 0.30085399746894836
# knee pain achy knees 0.6859174 0.6486077308654785
# otc sleep meds or ambien helped user sleep sleep troubles 0.52604777 0.6326512694358826
# potential for precipitated withdrawals due to bupe precipitated withdrawals 0.78529346 0.6812557578086853
# what are outcomes or side effects of treatments requires more alcohol to get drunk 0.5620324 -0.011589459143579006
# what are outcomes or side effects of treatments less enjoyable 0.36411732 0.13913887739181519
# potential psychosematic interaction between suboxone and cocaine cant feel cocaine high 0.55435187 0.5312022566795349
# leading to diminished or altered effects of both substances cant feel cocaine high 0.5621346 0.22559605538845062
# potential precipitated withdrawals possible precipitated withdrawal 0.9238303 0.9342894554138184
# positive outcome withdrawals 0.6359455 0.282528817653656
# potential for withdrawal symptoms and discomfort might have paws from dirty 30s 0.45363638 -0.044763512909412384
# continuing withdrawal symptoms sweaty 0.58426297 0.13580907881259918
# continuing withdrawal symptoms skin crawling 0.59993196 0.047918979078531265
# continuing withdrawal symptoms cannot sit still 0.5522198 0.15444418787956238
# potential side effects or outcomes of methadone treatment experiencing sickness 0.35144898 0.1860462874174118
# medications are not effectively controlling withdrawal symptoms zero wd symptoms 0.49447498 0.17066380381584167
# potentially leading to further complications zero wd symptoms 0.4872781 0.17987269163131714
# what are outcomes or side effects of treatments suboxone may block effects of kratom 0.5937124 0.23939429223537445
# 0 21 22
# relapse main-arguments effects 0.0 0.0 0.0
# previous recoveryrecovery in progress percocet addiction 0.533936 0.058390531688928604
# previous recovery from substance abuse fentanyl addiction 0.55664873 0.39323747158050537
# methadone and clonazepam was on opiates and benzos for 10 years 0.6536038 0.5082715153694153
# methadone and clonazepam then methadone and clonazepam 0.9528105 0.9055065512657166
# previous opioid recovery recovering from opioid use disorder 0.8221715 0.8180655241012573
# previous recoveryrecovery process back and forth between h and subs 0.52385926 0.030535977333784103
# kratom kratom and thc addict 0.75083727 0.6608705520629883
# previous substance use recovery drank alcohol 0.6603276 0.3967808485031128
# previous substance use historydisorder withdrawal from substance 0.6864601 0.5651963949203491
# fentanyl fent 0.44581997 0.594990074634552
# previous substance use history opioid 0.5204021 0.3045489192008972
# previous substance use history of 90mgday for year off of subs for 7 days 0.58297515 0.1548176407814026
# previous kratom dependency kratom 0.7963585 0.616547703742981
# previous substance use historydisorder suboxone use with low tolerance 0.59797853 0.17594675719738007
# suboxone been on suboxone since august of 2021 0.6302758 0.7351123094558716
# previous substance use disorder recovered from fentanyl 30s use 0.5279411 0.29810017347335815
# previous substance recoveryrecovery process weed and fent addict 0.5729545 0.2941736578941345
# previous substance use recovery fenta addiction 0.57998 0.36599308252334595
# previous recovery from fentanyl fentanyl addiction 0.8527807 0.6675249338150024
# previous recoveryrecovery process using blues 0.5206453 0.02688838727772236
# previous recoveryrecovery process bars 0.42178038 0.04085635766386986
# previous recoveryrecovery process and ice 0.4787092 0.018310004845261574
# previous opiate use opiate use disorder 0.7434721 0.7490505576133728
# previous substance recoverywithdrawal recovering from dirty 30s addiction 0.4959227 0.49256014823913574
# previous recovery or current recovery from opioid use disorder relapsed on heroin 0.64978623 0.5497307181358337
# heroin use disorder recovering from heroin addiction 0.77074236 0.7065529823303223
# previous substance use historydisorder using suboxone 0.48899084 0.17528070509433746
# 0 25 28
# relapse event-specific-arguments condition 0.0 0.0 0.0
# benzo withdrawal symptoms benzos withdrawal 0.8556898 0.8369733691215515
# factors or events contributing to relapse morphine prescription 0.4838634 0.11067581921815872
# emotional response to witnessing traumatic event shitty fent replacing good h 0.4327425 0.031596262007951736
# missed appointment and beers on fathers day fathers day 0.71832794 0.6172728538513184
# relapse factorsevents not specified cold turkey withdrawal 0.4963809 0.2304764688014984
# relapse due to opioid use cold turkey withdrawal 0.4214021 0.319916307926178
# sleep issues insomnia 0.7383745 0.6261427402496338
# relapse factorsevents to get off subs 0.5123055 0.06379137188196182
# dirty 30 withdrawals wanting to quit suboxone 0.57145613 0.34582239389419556
# relapse factors or events not specified has arthritis 0.4004789 0.08930879831314087
# relapse factors or events not specified doesnt want to deal with sickness 0.49866843 0.15448513627052307
# unknown pain 0.7234357 0.3818047046661377
# 0 12 13
# relapse event-specific-arguments trigger 0.0 0.0 0.0
# fentanyl subs 0.36771965 0.05724162608385086
# xanax suboxone 0.47025615 0.30391716957092285
# suboxone suboxone 1.0 1.0
# suboxone sub 0.6590155 0.37370967864990234
# bupe patches bupe patch 0.94221675 0.9494718313217163
# oxycodone suboxone 0.62908375 0.5426725745201111
# thc subs 0.6120343 0.2553676962852478
# suboxone suboxone 1.0 1.0
# subs subs 1.0000001 1.0000001192092896
# subs xanax 0.41115862 0.18329769372940063
# subs muscle relaxers 0.4536728 0.08415370434522629
# gabapentin gabapentin 1.0 1.000000238418579
# gabapentin muscle relaxers 0.6194408 0.3376624584197998
# xanax xanax 1.0000001 0.9999999403953552
# suboxone 812mg suboxone 0.82027054 0.8272020816802979
# suboxone subs 0.6372401 0.35214412212371826
# suboxone suboxone 1.0 1.0
# 20mgdaily subs 0.4411187 0.1492490917444229
# kratom subs 0.64132977 0.1125117763876915
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# suboxone subs 0.6372401 0.35214412212371826
# suboxone suboxone 1.0 1.0
# suboxone ambien 0.55143833 0.34220874309539795
# suboxone benzos 0.80525124 0.35993492603302
# bupe subs 0.5861298 0.2838001549243927
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# kratom buprenorphine 0.5088206 0.3298738896846771
# unknown subs 0.63894975 0.2279113531112671
# subs suboxone 0.6372401 0.35214412212371826
# not specified suboxone 0.520016 0.19709281623363495
# subutex subutex 1.0 0.9999999403953552
# buprenophine buprenophine 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# 14 37 36
# relapse event-specific-arguments existing/current-medications 0.3783783783773557 0.38888888888780865 0.3835616437845749
# percs percocet 0.6829824 0.5684541463851929
# subs pressed 30s 0.6105296 0.27201664447784424
# xanax kratom 0.44039977 0.24177370965480804
# xanax oxy 0.46933532 0.24391794204711914
# xanax diluadin 0.45660466 0.27574270963668823
# fentanyl fent and percs 0.38965976 0.3566676080226898
# morphine morphine 1.0 1.0
# suboxone oxycodone and percocet 0.63573515 0.38661298155784607
# ...
# previous recoveryrecovery process back and forth between h and subs 0.52385926 0.030535977333784103
# kratom kratom and thc addict 0.75083727 0.6608705520629883
# previous substance use recovery drank alcohol 0.6603276 0.3967808485031128
# previous substance use historydisorder withdrawal from substance 0.6864601 0.5651963949203491
# fentanyl fent 0.44581997 0.594990074634552
# previous substance use history opioid 0.5204021 0.3045489192008972
# previous substance use history of 90mgday for year off of subs for 7 days 0.58297515 0.1548176407814026
# previous kratom dependency kratom 0.7963585 0.616547703742981
# previous substance use historydisorder suboxone use with low tolerance 0.59797853 0.17594675719738007
# suboxone been on suboxone since august of 2021 0.6302758 0.7351123094558716
# previous substance use disorder recovered from fentanyl 30s use 0.5279411 0.29810017347335815
# previous substance recoveryrecovery process weed and fent addict 0.5729545 0.2941736578941345
# previous substance use recovery fenta addiction 0.57998 0.36599308252334595
# previous recovery from fentanyl fentanyl addiction 0.8527807 0.6675249338150024
# previous recoveryrecovery process using blues 0.5206453 0.02688838727772236
# previous recoveryrecovery process bars 0.42178038 0.04085635766386986
# previous recoveryrecovery process and ice 0.4787092 0.018310004845261574
# previous opiate use opiate use disorder 0.7434721 0.7490505576133728
# previous substance recoverywithdrawal recovering from dirty 30s addiction 0.4959227 0.49256014823913574
# previous recovery or current recovery from opioid use disorder relapsed on heroin 0.64978623 0.5497307181358337
# heroin use disorder recovering from heroin addiction 0.77074236 0.7065529823303223
# previous substance use historydisorder using suboxone 0.48899084 0.17528070509433746
# 0 25 28
# relapse event-specific-arguments condition 0.0 0.0 0.0
# benzo withdrawal symptoms benzos withdrawal 0.8556898 0.8369733691215515
# factors or events contributing to relapse morphine prescription 0.4838634 0.11067581921815872
# emotional response to witnessing traumatic event shitty fent replacing good h 0.4327425 0.031596262007951736
# missed appointment and beers on fathers day fathers day 0.71832794 0.6172728538513184
# relapse factorsevents not specified cold turkey withdrawal 0.4963809 0.2304764688014984
# relapse due to opioid use cold turkey withdrawal 0.4214021 0.319916307926178
# sleep issues insomnia 0.7383745 0.6261427402496338
# relapse factorsevents to get off subs 0.5123055 0.06379137188196182
# dirty 30 withdrawals wanting to quit suboxone 0.57145613 0.34582239389419556
# relapse factors or events not specified has arthritis 0.4004789 0.08930879831314087
# relapse factors or events not specified doesnt want to deal with sickness 0.49866843 0.15448513627052307
# unknown pain 0.7234357 0.3818047046661377
# 0 12 13
# relapse event-specific-arguments trigger 0.0 0.0 0.0
# fentanyl subs 0.36771965 0.05724162608385086
# xanax suboxone 0.47025615 0.30391716957092285
# suboxone suboxone 1.0 1.0
# suboxone sub 0.6590155 0.37370967864990234
# bupe patches bupe patch 0.94221675 0.9494718313217163
# oxycodone suboxone 0.62908375 0.5426725745201111
# thc subs 0.6120343 0.2553676962852478
# suboxone suboxone 1.0 1.0
# subs subs 1.0000001 1.0000001192092896
# subs xanax 0.41115862 0.18329769372940063
# subs muscle relaxers 0.4536728 0.08415370434522629
# gabapentin gabapentin 1.0 1.000000238418579
# gabapentin muscle relaxers 0.6194408 0.3376624584197998
# xanax xanax 1.0000001 0.9999999403953552
# suboxone 812mg suboxone 0.82027054 0.8272020816802979
# suboxone subs 0.6372401 0.35214412212371826
# suboxone suboxone 1.0 1.0
# 20mgdaily subs 0.4411187 0.1492490917444229
# kratom subs 0.64132977 0.1125117763876915
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# suboxone subs 0.6372401 0.35214412212371826
# suboxone suboxone 1.0 1.0
# suboxone ambien 0.55143833 0.34220874309539795
# suboxone benzos 0.80525124 0.35993492603302
# bupe subs 0.5861298 0.2838001549243927
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# kratom buprenorphine 0.5088206 0.3298738896846771
# unknown subs 0.63894975 0.2279113531112671
# subs suboxone 0.6372401 0.35214412212371826
# not specified suboxone 0.520016 0.19709281623363495
# subutex subutex 1.0 0.9999999403953552
# buprenophine buprenophine 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# 14 37 36
# relapse event-specific-arguments existing/current-medications 0.3783783783773557 0.38888888888780865 0.3835616437845749
# percs percocet 0.6829824 0.5684541463851929
# subs pressed 30s 0.6105296 0.27201664447784424
# xanax kratom 0.44039977 0.24177370965480804
# xanax oxy 0.46933532 0.24391794204711914
# xanax diluadin 0.45660466 0.27574270963668823
# fentanyl fent and percs 0.38965976 0.3566676080226898
# morphine morphine 1.0 1.0
# suboxone oxycodone and percocet 0.63573515 0.38661298155784607
# fentanyl heroin 0.55652463 0.5558615922927856
# fentanyl fentynal 0.43933165 0.5537018775939941
# thc thc 1.0000001 1.0
# suboxone alcohol 0.6259105 0.37320002913475037
# kratom kratom 1.0 1.0
# heroin heroin 1.0 0.9999999403953552
# fentanyl fent 0.44581997 0.594990074634552
# opioid opioid 1.0000001 1.0
# heroin and fentanyl h and fent 0.44119173 0.3855108618736267
# subconscious suboxone 0.6113368 0.12764541804790497
# oxycodone oxy 30s fentanyl 0.8196514 0.6488704085350037
# fentanyl fentanyl 30 0.9129855 0.8508608341217041
# fentanyl fentanyl 0.9999999 1.0
# fentanyl fentanyl 0.9999999 1.0
# heroin heroin 1.0 0.9999999403953552
# cocaine cocaine 0.9999999 1.0
# alcohol blues 0.83052856 0.3220023512840271
# alcohol bars 0.8286211 0.3755338191986084
# alcohol meth 0.64304936 0.47200387716293335
# alcohol ice 0.87793875 0.4238998591899872
# buprenorphine kratom 0.5088206 0.3298738896846771
# buprenorphine h 0.36568502 0.11474878340959549
# subs kratom 0.64132977 0.1125117763876915
# subs kratom 0.64132977 0.1125117763876915
# subs dirty 30s 0.56266874 0.2771579623222351
# heroin heroin 1.0 0.9999999403953552
# heroin heroin 1.0 0.9999999403953552
# heroin clonazepam and pregabalin 0.40234783 0.19952215254306793
# kratom kratom 1.0 1.0
# 12 32 41
# relapse event-specific-arguments relapse-substance 0.3749999999988281 0.2926829268285544 0.32876712323753043
# 3 days 3 days 1.0 1.0
# unknown two days 0.59662694 0.2916256785392761
# 1 week one day 0.6573183 0.6308224201202393
# unknown yesterday and today 0.590166 0.26196593046188354
# 1 year one year 0.8527212 0.9410743713378906
# few days several days 0.9084104 0.8521144390106201
# 34 days 34 days 1.0000001 1.0
# not specified one day 0.6052019 0.21031279861927032
# 6 months 6 months 1.0 1.0
# 3 11 12
# relapse event-specific-arguments relapse-duration 0.2727272727247934 0.24999999999791667 0.26086956516521737
# hot soaks started taking suboxone 0.515602 0.009623666293919086
# imodium started taking suboxone 0.5877016 0.2481502890586853
# distractions started taking suboxone 0.5323041 0.09424546360969543
# walks started taking suboxone 0.47172728 0.01051896158605814
# gradually increasing dose of subs bernese method 0.4998181 0.14104479551315308
# unknown switching back to suboxone 0.49080342 0.004771798849105835
# unknown taking suboxone again 0.38407785 0.012224264442920685
# support group quitting with support group help 0.6587281 0.6805720329284668
# none specified wants to start subacade 0.4546926 0.19620072841644287
# none specified switching clinics 0.70720303 0.012446312233805656
# unknown continue taking subs 0.57059455 0.06784065812826157
# tapering off fentanyl while consuming suboxone bernese method 0.48467255 0.07500502467155457
# suboxone treatment subs 0.4737924 0.18454745411872864
# narcan suggested to use narcan 0.72465396 0.796481728553772
# none mentioned trying to switch back to suboxone 0.4437805 -0.01135335210710764
# unknown taking more subs 0.5304652 0.11234217137098312
# otc sleep meds use sleep meds 0.85235035 0.7227606773376465
# otc sleep meds ambien 0.5215544 0.4475407898426056
# otc sleep meds benzos 0.5582797 0.21580716967582703
# ambien use sleep meds 0.5061209 0.39984118938446045
# ambien ambien 1.0 1.0
# benzodiazepines use sleep meds 0.6169431 0.26483702659606934
# benzodiazepines benzos 0.5866799 0.6965538859367371
# unknown using suboxone 0.5054403 0.00956113263964653
# medical supervision wants to start moud 0.49961168 0.1396143138408661
# medical supervision start at 24mg 0.48163503 0.045766495168209076
# medical supervision no meth 0.61036766 0.10694469511508942
# none mentioned quickmd 0.6867078 0.22884535789489746
# none mentioned buprenorphine 0.41479772 0.18175579607486725
# not specified 2 mg moud 0.5199288 0.2281791865825653
# ongoing subutex treatment plan to use methadone 0.6098572 0.12785187363624573
# 1 24 25
# relapse event-specific-arguments relapse-intervention 0.04166666666649306 0.039999999999840004 0.04081632648046648
# unknown 36 hours 0.6392465 0.29862862825393677
# 26 hours 26 hours after last fent 0.6962218 0.5916523933410645
# 26 hours 1 hour after percs 0.71561867 0.3625604510307312
# hot soaks hot soaks 0.99999994 1.0
# hot soaks distractions 0.59362084 0.08781875669956207
# hot soaks walks 0.43657553 0.07946085184812546
# imodium imodium 1.0 1.0000001192092896
# imodium walks 0.48289353 0.17693763971328735
# distractions distractions 0.9999999 1.0
# walks walks 1.0 1.0000001192092896
# gradually increase dose of subs bernese method 0.5048984 0.10858761519193649
# gradually increase dose of subs gradual increase of subs 0.7950326 0.7107919454574585
# tapering down benzos with medical supervision suboxone 0.57159346 0.1711685061454773
# tapering down benzos with medical supervision oxycodone 0.57786494 0.23808109760284424
# tapering down benzos with medical supervision diliduan 0.37836942 0.08532731235027313
# wait and start with 1mg subs wait 24 hours 0.614254 0.36710262298583984
# wait and start with 1mg subs start off with 1 mg 0.7422613 0.6300828456878662
# wait for morphine to take effect wait 5 days for morphine to work 0.84828687 0.8456693887710571
# taking 1 mg or less of suboxone taking less subs and observing how you feel 0.6009445 0.2918643355369568
# support group help quitting with support group help 0.78422713 0.7726240158081055
# increasing dosage of subs need more than 2mg of subs 0.7479051 0.7275359034538269
# not mentioned switching clinics 0.65259147 -0.009682532399892807
# sub taper regular supply of subs 0.6030479 0.3462325930595398
# tapering off fentanyl at same time as consuming suboxone bernese method 0.474864 0.07863799482584
# none mentioned quitting cold turkey 0.49669397 0.037147246301174164
# narcan on hand suggested to use narcan 0.5848933 0.8518672585487366
# bernese method bernese method 0.9999999 1.0000001192092896
# taking smaller doses more subs 0.64810985 0.18049147725105286
# taking smaller doses comfort meds 0.5863775 0.20421326160430908
# otc sleep meds take sleep meds 0.81830573 0.6619113683700562
# otc sleep meds ambien 0.5215544 0.4475407898426056
# otc sleep meds benzo 0.5030761 0.16665324568748474
# ambien take sleep meds 0.5594879 0.39291852712631226
# ambien ambien 1.0 1.0
# benzodiazepines take sleep meds 0.61260134 0.22466006875038147
# benzodiazepines benzo 0.41159418 0.6370904445648193
# should be able to start at no more than 24mg take 24mg for first month 0.6727612 0.6982414722442627
# should be able to start at no more than 24mg then 8mg or less 0.6425644 0.6276971101760864
# should be able to start at no more than 24mg alcohol can help but no meth 0.5813998 0.26990896463394165
# but take as little as possible take 24mg for first month 0.5494732 0.29369106888771057
# but take as little as possible then 8mg or less 0.5531143 0.37379711866378784
# but take as little as possible alcohol can help but no meth 0.5422685 0.25426673889160156
# wait as long as possible between doses take 24mg for first month 0.6110204 0.5008329153060913
# wait as long as possible between doses then 8mg or less 0.57966524 0.4177795946598053
# wait as long as possible between doses alcohol can help but no meth 0.5998437 0.27033913135528564
# used to get off subs use kratom 0.5824236 0.058046650141477585
# avoid kratom kratom while on suboxone 0.7403131 0.6909029483795166
# 6 31 36
# relapse subject-effect-arguments intervention 0.19354838709614985 0.1666666666662037 0.17910447756168413
# results-gemma-1.1-7b-itbatch_question_guided_0.99.json
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Predictions/2-new-results-gemma-1.1-7b-it.json
# CPU times: user 2h 10min 12s, sys: 15min 10s, total: 2h 25min 22s
# Wall time: 4h 50min 10s

# %% [markdown]
# printing to understanding the nesting in the results dict

# %%
print(results_dict.keys())
print(results_dict['batch_description_guided_0.749'].keys())
print(results_dict['batch_description_guided_0.749']['tapering'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments']['effects'])
# Out:
# dict_keys(['batch_description_guided_0.749', 'batch_description_guided_0.99', 'batch_question_guided_0.749', 'batch_question_guided_0.99', 'isolated_description_guided_0.749', 'isolated_description_guided_0.99', 'isolated_question_guided_0.749', 'isolated_question_guided_0.99'])
# dict_keys(['taking-moud', 'tapering', 'relapse'])
# dict_keys(['main-arguments', 'event-specific-arguments', 'subject-effect-arguments'])
# dict_keys(['subject/patient', 'effects', 'tapering-event'])
# [[0.4583333333314236, 0.54999999999725, 0.49999999994814043], [11, 24, 20]]
