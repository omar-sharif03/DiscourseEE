# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
# !pip install transformers # If you are using collab, "!" is required to download
# !pip install bert-score
# !pip install -U sentence-transformers

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer

# Download NLTK resources
nltk.download('punkt')
nltk.download('wordnet')

# %%
import os, json
import numpy as np
from argparse import ArgumentParser
from tqdm import tqdm
from collections import defaultdict
import pandas as pd
from pprint import pprint
import re, string
from google.colab import files

from transformers import BertTokenizer, BertModel
from sentence_transformers import SentenceTransformer, util
import torch
import copy

# %% [markdown]
# ## Calculating evaluation scores

# %%
def read_json_file(name):
    with open(name, 'r') as f:
        data = json.load(f)
        return data

def save_json(json_data, file_name):
    json_data = json.dumps(json_data)
    print(file_name)
    with open(file_name, "w") as json_file:
          json_file.write(json_data)

# %%
# def perform_lemmatization(text):

#     # Tokenize the text into words
#     words = word_tokenize(text)
#     lemmatizer = WordNetLemmatizer()
#     stemmer = PorterStemmer()
#     lemmatized_and_stemmed_words = [(lemmatizer.lemmatize(word), stemmer.stem(word)) for word in words]

#     lemmatized_words, stemmed_words = zip(*lemmatized_and_stemmed_words)
#     lemmatized_text = ' '.join(lemmatized_words)
#     stemmed_text = ' '.join(stemmed_words)

#     # print("Original text:", text)
#     # print("Lemmatized text:", lemmatized_text)
#     # print("Stemmed text:", stemmed_text)
#     return stemmed_text

def clac_sbert_score(text1, text2):
    model = SentenceTransformer("all-MiniLM-L6-v2")

    embeddings1 = model.encode(text1, convert_to_tensor=True)
    embeddings2 = model.encode(text2, convert_to_tensor=True)

    cosine_score = util.cos_sim(embeddings1, embeddings2)
    #print(cosine_score.item())
    return cosine_score.item()

def calc_cosine_similarity(text1, text2):

    tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
    model = BertModel.from_pretrained("bert-base-uncased")

    # text1 = perform_lemmatization(text1)
    # text2 = perform_lemmatization(text2)

    inputs1 = tokenizer(text1, return_tensors="pt", padding=True, truncation=True)
    inputs2 = tokenizer(text2, return_tensors="pt", padding=True, truncation=True)

    outputs1 = model(**inputs1)
    outputs2 = model(**inputs2)

    embeddings1 = outputs1.last_hidden_state.mean(dim=1).detach().numpy()
    embeddings2 = outputs2.last_hidden_state.mean(dim=1).detach().numpy()

    #Calculate cosine similarity
    similarity = np.dot(embeddings1, embeddings2.T) / (np.linalg.norm(embeddings1) * np.linalg.norm(embeddings2))

    #print("Similarity between the texts:", similarity)
    return similarity[0][0]

# %%
def is_null_or_empty(string):
    return string is None or string.strip().lower() == 'null' or string.strip() == ''

def normalize_string(s):
      def remove_articles(text):
          regex = re.compile(r'\b(a|an|the)\b', re.UNICODE)
          return re.sub(regex, ' ', text)
      def white_space_fix(text):
          return ' '.join(text.split())
      def remove_punc(text):
          exclude = set(string.punctuation)
          return ''.join(ch for ch in text if ch not in exclude)
      def lower(text):
          return text.lower()
      return white_space_fix(remove_articles(remove_punc(lower(s))))


def calculate_score(predictions, ground_truth_labels, similarity_threshold):
    true_pos, pred_count, gtruth_count = 0, len(predictions), len(ground_truth_labels)

    if ((len(ground_truth_labels)==1 and is_null_or_empty(ground_truth_labels[0]))): #only not calculating when ground-truth is null
        #print("xxx ", predictions, labels) #(len(predictions)==1 and is_null_or_empty(predictions[0]))
        return 0, 0, 0 #skipping this sample
    else:
        actual_labels = copy.deepcopy(ground_truth_labels)
        # print(predictions, actual_labels)
        # print(len(predictions), len(actual_labels))
        for p in predictions:
            for g in actual_labels:
                if(g.strip() == ''): gtruth_count -=1 ## if any ground-truth is empty reducing that count.
                if(is_null_or_empty(p) or is_null_or_empty(g)): continue ##if prediction/ground-truth is null then skip
                np, ng = normalize_string(p), normalize_string(g)
                sim_value = calc_cosine_similarity(np,ng)
                sbert_score = clac_sbert_score(np, ng)
                print(np, ng, sim_value, sbert_score)
                if(sim_value>similarity_threshold or sbert_score>similarity_threshold):
                    true_pos += 1
                    actual_labels.remove(g)
        # print(predictions, labels)
        # print(true_pos, pred_count, gtruth_count)
        return true_pos, pred_count, gtruth_count

def calc_precision_recall_f1(true_pos, pred_count, gtruth_count):
    print(true_pos, pred_count, gtruth_count)
    precision = true_pos/(pred_count + 1e-10)
    recall = true_pos/(gtruth_count + 1e-10)
    f1 = 2 * precision * recall / (precision + recall + 1e-10)
    return precision, recall, f1

# %%
def select_event_specific_data(event, data):
    ev_data = []
    for dt in data:
        if event==dt['label']:
            ev_data.append(dt)
    return ev_data

def calc_results(all_data, event_types, arg_types, events_roles, pred_name, gtruth_name, similarity_threshold):
    results = {}
    for event in event_types:
        results[event] = {}
        for arg_type in arg_types:
            results[event][arg_type] = {}
            arguments = list(events_roles[event][arg_type].keys())
            for arg in arguments:
                tp, pc, gc = 0, 0, 0 #initialize the true_positive, pred_count, ground_truth-count for each arguments
                event_specifc_data = select_event_specific_data(event, all_data) ##geting the data for a specific event type.
                for dt in event_specifc_data:
                    label = dt['label']
                    pred_list = dt[pred_name][arg_type][arg] #predictions
                    gtruth_list = dt[gtruth_name][arg_type][arg] #ground-truth arguments
                    #print(pred_list, gtruth_list)
                    true_pos, pred_count, gtruth_count = 0, 0, 0
                    try:
                       true_pos, pred_count, gtruth_count = calculate_score(pred_list,
                                                                         gtruth_list, similarity_threshold)
                    except:
                        print(event, arg_type, arg)
                        print(pred_list, gtruth_list)
                        print("Error occured at", dt['doc_id'])

                    tp+= true_pos
                    pc+= pred_count
                    gc+= gtruth_count
                if(gc==0):
                    continue #skiping those values, where we do not have any ground truth.

                precision, recall, f1 = calc_precision_recall_f1(tp, pc, gc)
                print(event, arg_type, arg, precision, recall, f1)
                #saving the values in two items is a list
                #first item has (precision, recall, f1 scores) #second item has (true_pos, pred_count, ground_truth_count values)
                results[event][arg_type][arg]= [[precision, recall, f1], [tp, pc, gc]]

    return results

# %%
# %%time

events_roles = read_json_file('role_definitions.json')

prompt_types = ['batch'] #['batch', 'isolated']
exp_types = ['description_guided', 'question_guided']
event_types = ['taking-moud', 'tapering', 'relapse']
arg_types = ['main-arguments', 'event-specific-arguments', 'subject-effect-arguments']
similarity_threshold = [0.749, 0.99]

number = '1'
name = 'Mixtral-8x7B-Instruct'
folder_path = 'Argument-Extraction-Predictions'
file_name = f'{number}-processed-{name}_test_100_predictions.json'
print(os.path.join(folder_path, file_name))
all_data = read_json_file(os.path.join(folder_path, file_name))

print(all_data[0].keys())
print(len(all_data))
# Out:
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Predictions/1-processed-Mixtral-8x7B-Instruct_test_100_predictions.json
# dict_keys(['doc_id', 'id', 'text1', 'text2', 'label', 'thread-length', 'ground-truth-arguments', 'raw-batch_description_guided-predictions', 'raw-batch_question_guided-predictions', 'processed-batch_description_guided-predictions', 'processed-batch_question_guided-predictions'])
# 100
# CPU times: user 39.5 ms, sys: 4.95 ms, total: 44.5 ms
# Wall time: 113 ms

# %%
# %%time
numbers = ['0', '1', '2']

for number in numbers:
    file_name = f'{number}-processed-{name}_test_100_predictions.json'
    all_data = read_json_file(os.path.join(folder_path, file_name))

    results_dict = {}
    for p_type in prompt_types:
          for e_type in exp_types:
              g_name = 'ground-truth-arguments'
              p_name = f'processed-{p_type}_{e_type}-predictions'
              for s_t in similarity_threshold:
                  print(p_type, e_type, s_t)
                  results = calc_results(all_data, event_types, arg_types, events_roles,
                            p_name, g_name, s_t)
                  save_json(results, f'results-{name}{p_type}_{e_type}_{s_t}.json')
                  results_dict[f'{p_type}_{e_type}_{s_t}']=results


    result_folder_path = 'Argument-Extraction-Results'
    save_json(results_dict, os.path.join(result_folder_path,f'{number}-new-results-{name}.json'))
# Out:
# Streaming output truncated to the last 5000 lines.
# crush into powder and use 0001g scale or make volumetric solution reduced dosage 0.55119044 0.25451892614364624
# snorting sublingual strips on subs strips 0.6651819 0.43278974294662476
# taking it sublingual on subs strips 0.636515 0.20663172006607056
# putting little corner in bowl and smoking it strips 0.38176844 0.2913033664226532
# heating it from cold till it smokes strips 0.3380697 0.09432690590620041
# tramadol and suboxone suboxone for 15 years 0.80635613 0.5600085258483887
# 8mg film 8mg suboxone 0.6908506 0.5910749435424805
# methadone 30 mg of methadone 0.80504376 0.7230253219604492
# prescribed 2 mg film strips cutting 2 mg film into smaller doses066 0.8045808 0.685590386390686
# 8mg of medication daily since october 16mg every day since october 0.752533 0.8272308111190796
# buprenorphine tablets taking buprenorphine 0.89699763 0.8674102425575256
# used strips instead of pills used strips instead of pills 0.9999999 1.0
# boofing buprenorphine taking bupe 0.676132 0.4979715943336487
# suboxone suboxone prescription 0.8577256 0.8010879755020142
# describe treatments prescribed or undergoing split out substance 0.5944056 0.10956613719463348
# switched from methadone to suboxone suboxone for three days after methadone for twelve years 0.85271 0.7890688180923462
# suboxone 8mg 8mg suboxone 0.9564742 0.9875012636184692
# suboxone suboxone 1.0 1.0
# 8mg day of unspecified medication taking 8mg subs daily 0.6849476 0.650426983833313
# tapering down from 16mg to 8mg day 16mg unnamed medication daily 0.67812455 0.6376546621322632
# subutex 14mg 14mg suboxone daily 0.6302994 0.6351132392883301
# previously on higher doses 14mg suboxone daily 0.6004564 0.4157393276691437
# buprenorphine pill dissolved in mouth taking oral buprenorphine 0.8162242 0.7858703136444092
# addiction switching from 4 mg subs to 2 mg 0.42032453 0.12551157176494598
# took 5mg of sub strip took 05mg of suboxone 0.7429871 0.6807968020439148
# tried rhodes suboxone and subutex for 3 years and 3 months 0.40744084 -0.05605314299464226
# roxanne westward suboxone and subutex for 3 years and 3 months 0.48609555 0.08371735364198685
# hitech akorn suboxone and subutex for 3 years and 3 months 0.5326629 -0.09887531399726868
# alvogen suboxone and subutex for 3 years and 3 months 0.52484185 0.10590584576129913
# dr reddy brands of bupe with and without naloxone suboxone and subutex for 3 years and 3 months 0.7630045 0.19201728701591492
# waiting 2436 hours after last fentanyl dose take subs after 2436 hours 0.6991794 0.32920366525650024
# taking suboxone take subs after 2436 hours 0.56494445 0.3633401095867157
# considering kratom take subs after 2436 hours 0.65027195 0.0839414969086647
# 8mg day trying to maintain 8 mgs dose daily 0.57844 0.7910522222518921
# tapentadol 8mg bup2mg naloxene sub 0.6817832 0.18512098491191864
# tapentadol 5 100 mg tapentadol day for week 0.6802507 0.6159013509750366
# suboxene 8mg bup2mg naloxene sub 0.6994362 0.5000877380371094
# suboxene 5 100 mg tapentadol day for week 0.5550553 0.08151820302009583
# suboxone 4mg to 2mg reducing dosage to 1mg then 5mg 0.7866738 0.5174998044967651
# methadone 8mg films 2x daily 0.37551194 0.2375718057155609
# suboxone 8mg films 2x daily 0.5347296 0.2609691619873047
# and smoking 8mg films 2x daily 0.5087851 0.08779497444629669
# suboxone 8mg twice day 8mg suboxone twice daily 0.9081045 0.9694429636001587
# nonaddictive treatments for anxiety taking 82 suboxone 0.50499517 0.15971824526786804
# suboxone taking suboxone 0.8523089 0.8706018924713135
# suboxone switching to suboxone 0.83728844 0.8078473806381226
# planning to use suboxone for initial induction and switch to subutex for maintenance suboxone and subutex 0.65046406 0.6887141466140747
# intending to taper off using suboxone films suboxone and subutex 0.6516481 0.4731717109680176
# using suboxone 14 x 8mg sublingual films taking 14 8mg subs 0.649637 0.5040770769119263
# sublocade shots monthly shots of sublocade 0.79285955 0.8088235855102539
# 24mg of subutex for 4 days 24mg subutex 0.7345725 0.8423852920532227
# suboxone and vyvanse suboxone 0.80608726 0.6892517805099487
# 22 65 41
# taking-moud main-arguments treatment 0.33846153846101773 0.5365853658523497 0.41509433957442143
# withdrawals in mornings withdrawals in mornings 1.0000001 1.0000001192092896
# heavy past experience with opioids potentially getting sick 0.5846056 0.0809037834405899
# body is 100 cleaned out potentially getting sick 0.5378211 0.2523461580276489
# threw up all night potentially getting sick 0.60178506 0.38949573040008545
# could get headache or be extra tired headache 0.44202995 0.6665608286857605
# could get headache or be extra tired tiredness 0.64929 0.6797575950622559
# sore stomach potential stomach soreness 0.8484356 0.8648050427436829
# levels were off levels were off 1.0 1.0
# withdrawals precipitated withdrawals 0.63956344 0.7195149064064026
# taking low dosage suggested precipitated withdrawals 0.60572904 0.3394198715686798
# felt great on monday and tuesday feeling impaired 0.5060872 0.29018259048461914
# felt great on monday and tuesday possible methadone hangover 0.4735943 0.11662594974040985
# impaired on wednesday feeling impaired 0.68791384 0.6546225547790527
# impaired on wednesday possible methadone hangover 0.4890467 0.23956668376922607
# no more euphoria getting high 0.51816213 0.3330491781234741
# decreased bioavailabilityabsorption of nalaxone headaches and other side affects 0.56104666 0.10582362860441208
# headaches headaches and other side affects 0.7392236 0.6951532363891602
# other side effects headaches and other side affects 0.6752861 0.6424585580825806
# always wanting more addiction 0.5705102 0.34061717987060547
# thinking about taking more addiction 0.5362661 0.32470643520355225
# feeling like more is needed addiction 0.48117492 0.2631443738937378
# addiction addiction 1.0000001 1.0
# dose not lasting 24 hours waking up early with aching legs 0.5276966 0.12190525233745575
# waking up early with aching legs and discomfort waking up early with aching legs 0.9557236 0.9785839319229126
# feels effects more at 2mg feeling warm and fuzzy like kratom 0.60669523 0.315136194229126
# no relapses in 7 months of treatment feeling warm and fuzzy like kratom 0.5097395 0.07060478627681732
# did not reset progress worrying about detox 0.38612378 0.07200814038515091
# getting sick after 8 hours mixing kratom and subs may not work 0.5962488 0.08125258982181549
# side effects from suboxone mixing kratom and subs may not work 0.49728084 0.22378979623317719
# always thinking about taking more cravings 0.6499602 0.367806077003479
# chasing high cravings 0.73629355 0.29688480496406555
# tolerance to tapentadol probably high tolerance 0.56391394 0.44770777225494385
# no suboxene for few weeks probably high tolerance 0.6009809 0.1540314257144928
# unable to kick suboxone addicted to subs 0.6801188 0.2175411880016327
# unable to kick suboxone cant quit 0.5803253 0.2895166575908661
# unable to kick suboxone withdrawal 0.4545983 0.22429567575454712
# bad taste addicted to subs 0.67215383 0.307522714138031
# bad taste cant quit 0.64166546 0.26736727356910706
# bad taste withdrawal 0.6893609 0.21787258982658386
# panic disorder addicted to subs 0.61343765 0.23407334089279175
# panic disorder cant quit 0.60146356 0.22789064049720764
# panic disorder withdrawal 0.637231 0.296804279088974
# irregular sleep patterns wake up every hour 0.64003724 0.4329010844230652
# waking up in middle of night wake up every hour 0.73550177 0.7118573188781738
# feeling right after waking up wake up every hour 0.67046994 0.5284443497657776
# better sleep on methadone wake up every hour 0.59854716 0.38188573718070984
# normal sex drive but cannot reach orgasm anorgasmia 0.48039028 0.15068991482257843
# withdrawal symptoms after fentanyl use withdrawal symptoms 0.69339615 0.7682510614395142
# none mentioned pain from shots 0.5803316 0.09295479208230972
# slipped and used heroin withdrawal 0.52431035 0.37490540742874146
# feeling unwell withdrawal 0.5547364 0.2837212383747101
# zombielike state dependency 0.59106326 0.1340872049331665
# zombielike state zombielike state 1.0 1.0
# zombielike state chronic fatigue 0.5489482 0.15551427006721497
# depression dependency 0.83327657 0.27154672145843506
# depression chronic fatigue 0.82145417 0.46409761905670166
# chronic fatigue depression 0.82145417 0.46409761905670166
# 10 49 30
# taking-moud main-arguments effects 0.20408163265264473 0.33333333333222226 0.2531645569142766
# 4mg tablets subs 0.5190714 0.11787387728691101
# subs subs strips 0.8779379 0.6687115430831909
# their strips 0.8479257 0.25298309326171875
# tramadol suboxone 0.6888135 0.27597925066947937
# buprenorphine suboxone suboxone 0.80434805 0.7540287375450134
# 8mg film suboxone 0.57473046 0.3625829517841339
# methadone methadone 0.99999994 1.0000001192092896
# buprenorphine buprenorphine 1.0 1.0
# pills pillsstrips 0.61862123 0.6092795729637146
# strips pillsstrips 0.53247774 0.5298141241073608
# buprenorphine bupe 0.5045616 0.46576303243637085
# suboxone suboxone 1.0 1.0
# drugsmedications used in treatment suboxone 0.4828396 0.2727375626564026
# suboxone suboxone 1.0 1.0
# buprenorphine subs 0.41856447 0.17016413807868958
# subutex no naloxone suboxone 0.7442417 0.5015277862548828
# buprenorphine buprenorphine 1.0 1.0
# suboxone sub 0.6590155 0.37370967864990234
# percs sub 0.7056707 0.25468647480010986
# bupe sub 0.66269547 0.3247635066509247
# suboxone subs 0.6372401 0.35214412212371826
# suboxone subutex 0.6977222 0.5441408753395081
# fentanyl suboxone 0.6496843 0.4136883616447449
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# tapentadol tapentadol 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# suboxone lyrica 0.59350383 0.16887173056602478
# drugsmedications used in treatment suboxone 0.4828396 0.2727375626564026
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# subutex subutex 1.0 0.9999999403953552
# suboxone suboxone 1.0 1.0
# sublocade sublocade 1.0000001 1.0000001192092896
# subutex subutex 1.0 0.9999999403953552
# subutex diamorphine 0.6222972 0.30106088519096375
# suboxone suboxone 1.0 1.0
# 22 52 43
# taking-moud event-specific-arguments medications 0.42307692307610945 0.5116279069755544 0.4631578946863158
# 4mg twice daily 4mg 0.6613544 0.7142339944839478
# 30mg 30 mg methadone to 2 times sub 0.45578364 0.6370210647583008
# 066 mg 066 0.7989074 0.5859808921813965
# 16mg 16mg 1.0 1.0000001192092896
# 1mg 1mg 0.9999999 1.0000001192092896
# current or previous dosage of medications 1 mg on monday 0.43867978 0.43453389406204224
# current or previous dosage of medications 050 mg on tuesday and wednesday 0.47761044 0.4865701496601105
# 8mg suboxone 8mg 0.5931381 0.715802013874054
# 8mg 8mg 1.0000001 1.0000001192092896
# 16mg day 16mg day 1.0000001 1.000000238418579
# tapering down to 8mg day tapering to 8mg 0.8449822 0.896028995513916
# 14mg 14mg 1.0 1.0
# 8 mg suboxone daily 8 mg 0.68964744 0.5953425168991089
# 15 mg percs 8 mg 0.8320936 0.6562491655349731
# 4mg subsday 2 mg 0.56931156 0.6340498924255371
# 2mg subs 2 mg 0.65783894 0.705478310585022
# 6mg subs 2 mg 0.6262808 0.5810900926589966
# 2mg tolerance 2 mg 0.8054922 0.6774389743804932
# 05mg 05mg 1.0 1.0000001192092896
# 8mg day 8mg 0.670252 0.8178383708000183
# suboxone 2mg buprenorphine05mg naloxone 8mg bup2mg naloxene sub 0.8053996 0.7033247947692871
# tapentadol 100mg five 100mg tapentadol 0.8739581 0.9567098617553711
# 16mg 4mg to 2mg 0.6773108 0.7483353018760681
# 1 film 8mg 0.5875823 0.13927863538265228
# current or previous dosage of medications 16mg 0.3351575 0.50640869140625
# 2mg bar 82 0.58427256 0.19726340472698212
# 8mg 8mg 1.0000001 1.0000001192092896
# 24mg 24mg 1.0 1.0
# 15 31 26
# taking-moud event-specific-arguments dosage 0.48387096774037464 0.576923076920858 0.5263157894222222
# 6 months later 6 months 0.72281545 0.8253852725028992
# since october since october 1.0 0.9999998807907104
# duration of taking medication 3 days 0.59232944 0.3098256587982178
# 1 year suboxone one year 0.657174 0.47131043672561646
# 5 days fent one year 0.6549547 0.33722081780433655
# 24 hours off fent one year 0.5876144 0.21625307202339172
# 11 days 11 days 0.9999999 1.0
# suboxone few weeks ago week 0.47142288 0.33371156454086304
# tapentadol 1 week week 0.53919667 0.4810619354248047
# about year about year 0.99999994 1.0
# several months last several months 0.81528795 0.747855544090271
# 4 days 4 days 1.0 1.0
# 4 years suboxone 4 years 0.66076314 0.47831541299819946
# 2 months hfentanyl 4 years 0.53013676 0.33019864559173584
# 6 16 12
# taking-moud event-specific-arguments treatment-duration 0.3749999999976563 0.49999999999583333 0.4285714285193878
# snorting sublingual 0.56614715 0.22496460378170013
# orally ublingually 0.4481609 0.3885100185871124
# boofing dissolve in water and use syringe 0.33689559 0.06630875170230865
# sublingually absorbed through veins under tongue 0.57189965 0.14504988491535187
# sublingually oralsublingual 0.69377863 0.5491251349449158
# sublingual orally 0.55780464 0.3133595883846283
# sublingually orally 0.5655492 0.4410631060600281
# manner of taking medication orally sublingually as injections orally 0.536298 0.45560967922210693
# as injections injections 0.87282425 0.8710520267486572
# 1 20 21
# taking-moud event-specific-arguments manner 0.04999999999975 0.04761904761882087 0.04878048775466984
# per day per day 1.0000001 0.9999998807907104
# daily per day 0.7259106 0.6831240653991699
# not specified daily 0.6967974 0.27152806520462036
# frequency of taking medication per day per day 0.6083532 0.553192138671875
# week per day 0.6143544 0.39816814661026
# month per day 0.6505272 0.3727915287017822
# per day dailyl 0.53964937 0.5390490293502808
# per day daily 0.7259106 0.6831240653991699
# daily daily 1.0000001 1.0
# suboxone unknown sub twice day 0.5379152 0.27188247442245483
# suboxone unknown tap 5 times day 0.504857 -0.0018343692645430565
# tape sub twice day 0.5999601 0.13424280285835266
# tape tap 5 times day 0.6233547 0.192954882979393
# per day twice daily 0.6378631 0.6076984405517578
# frequency of taking medication per day twice daily 0.5176599 0.5338729619979858
# week twice daily 0.5932781 0.33402329683303833
# month twice daily 0.6010424 0.2756727635860443
# every month monthly 0.7824355 0.75650954246521
# 3 25 22
# taking-moud event-specific-arguments frequency 0.11999999999952 0.13636363636301654 0.12765957441774559
# in morning morning 0.851304 0.8070684671401978
# 1011 am morning 0.5812663 0.3531303405761719
# 1 3 3
# taking-moud event-specific-arguments timing 0.3333333333222222 0.3333333333222222 0.3333333332722222
# withdrawal management avoiding withdrawals 0.7316394 0.8559637665748596
# to quit percs and avoid precipitated withdrawals to quit percs 0.65994126 0.754030704498291
# to manage pain or addiction to manage addiction 0.85012805 0.8527520895004272
# pain management treat withdrawl symptoms 0.685375 0.19960588216781616
# detox detox 1.0000001 0.9999998807907104
# to help stay off fentan to quit fentanyl 0.6179516 0.783818244934082
# treatment for anxiety help withdrawl symptoms 0.6251618 0.27232563495635986
# bernese method microdosing subs to get off street fent getting off street fent 0.70489717 0.412153959274292
# taper off completely to taper off completely 0.8000242 0.9207198619842529
# 6 22 23
# taking-moud event-specific-arguments purpose 0.2727272727260331 0.2608695652162571 0.2666666666155062
# 0 1 1
# taking-moud subject-effect-arguments gender 0.0 0.0 0.0
# addiction spinal fusion 0.6234046 0.050034284591674805
# addiction denied pain management 0.6095259 0.21591508388519287
# spinal fusion spinal fusion 0.9999999 1.0
# denied pain management denied pain management 1.0 1.0
# preexisting or comorbid conditions of subjectpatient few weeks since last suboxone opiate addiction 0.575891 0.3062238097190857
# suboxone dependence depression 0.5952074 0.18225179612636566
# suboxone dependence chronic fatigue syndrome 0.48845592 0.16032814979553223
# depression depression 1.0 1.0
# chronic fatigue syndrome chronic fatigue syndrome 1.0 0.9999999403953552
# 4 13 11
# taking-moud subject-effect-arguments conditions 0.3076923076899408 0.36363636363305785 0.33333333328090275
# butterflies withdrawals 0.7078919 0.22499287128448486
# anxiety withdrawals 0.7142197 0.34046870470046997
# withdrawal withdrawals 0.8930609 0.9343258142471313
# nausea potentially getting sick 0.6112255 0.5923236012458801
# vomiting potentially getting sick 0.6374553 0.5675185918807983
# dosing suboxone 2 times day brink of relapse 0.4544604 0.08417677879333496
# side effects from suboxone brink of relapse 0.5375569 0.06450122594833374
# headache headache 0.9999999 1.0
# extra tiredness tiredness 0.871962 0.8582174777984619
# sore stomach sore stomach 1.0000001 1.0
# levels being off low levels 0.7972184 0.698784589767456
# withdrawals illness from precipated withdrawls 0.5212815 0.6328145265579224
# anxiety illness from precipated withdrawls 0.48231375 0.29945823550224304
# fear illness from precipated withdrawls 0.44770345 0.0853106826543808
# suboxone high feeling high 0.5125009 0.4166698753833771
# headaches headaches 1.0000001 1.0
# desire for more medication addiction 0.4934121 0.46007388830184937
# aching legs waking up early with aching legs 0.7142076 0.6700297594070435
# uncomfortable waking up early with aching legs 0.42142978 0.22360646724700928
# none mentioned failed 7 day subutex detox 0.43216494 0.008373125456273556
# feeling sick bluezz 0.6198497 0.2711702585220337
# feeling sick sick 0.810072 0.690274715423584
# desire for more medication craving for higher dose 0.7692879 0.7047916650772095
# suboxone withdrawal anxiety 0.57346594 0.20139381289482117
# bad taste anxiety 0.7687829 0.28233155608177185
# irregular sleep patterns sleeping difficulty 0.7557668 0.6548538208007812
# reduced orgasm anorgasmia 0.53626066 0.28839176893234253
# anxiety anxiety 0.9999999 1.000000238418579
# withdrawals withdrawals 1.0 1.000000238418579
# used heroin withdrawal symptoms 0.7605658 0.2715573310852051
# zombielike state physical withdrawal symptoms 0.5905062 0.0868915542960167
# 13 36 27
# taking-moud subject-effect-arguments side-effects 0.361111111110108 0.48148148147969827 0.4126984126481229
# crippling worst 0.6698317 0.2073579579591751
# always thinking about taking dose high 0.5603738 0.15793730318546295
# not specified low 0.7009091 0.3522552251815796
# severe high 0.75680393 0.47459423542022705
# beyond frustrating medium 0.73642296 0.18486347794532776
# not specified extreme 0.6694897 0.22603535652160645
# 1 14 13
# taking-moud subject-effect-arguments severity 0.07142857142806122 0.0769230769224852 0.07407407402359395
# every morning in morning 0.8219979 0.7553573846817017
# after switching to subs 6 months after switching 0.7154585 0.35316145420074463
# 8 hours after last fent dose 2436 hours after subs 0.67929673 0.3883036673069
# about year ago 1 year ago 0.7717283 0.8446706533432007
# 2 6 6
# taking-moud subject-effect-arguments start-time 0.33333333332777776 0.33333333332777776 0.33333333327777775
# 0 3 3
# taking-moud subject-effect-arguments side-effect-duration 0.0 0.0 0.0
# timing dose later splitting dosage and changing frequency 0.771561 0.35685643553733826
# got back on methadone methadone 0.7663732 0.7519741654396057
# let strip sit longer proper use of strip 0.5950258 0.6617273092269897
# avoid eatingdrinking after proper use of strip 0.6215244 0.061207689344882965
# dissolve it in water and use syringe without point dissolve it in water and syringe it 0.90702 0.9039024114608765
# suboxone starting with low dosage of suboxone 0.6861592 0.7027593851089478
# low dosage starting with low dosage of suboxone 0.75503194 0.6860544681549072
# spit instead of swallowing spit instead of swallow 0.9426731 0.9669506549835205
# soak in mouth for 5 minutes avoid swallowing sub 0.5905671 0.3958210349082947
# soak in mouth for 5 minutes rinse with water 0.71167636 0.41329070925712585
# spit and rinse with water avoid swallowing sub 0.6467328 0.3962138891220093
# spit and rinse with water rinse with water 0.90439594 0.7696431875228882
# need to maintain daily dose ignore addict brain 0.64419967 0.17983755469322205
# suggestions for tapering ignore addict brain 0.61568433 0.02511570230126381
# micro cuts micro cuts and stay stable 0.6524694 0.7889784574508667
# spitting instead of swallowing spitting out after dissolving in mouth 0.65774304 0.7056077718734741
# bridged gap for 24 hours with 4 15 mg percs pharma switching back to suboxone 0.60869473 0.27817919850349426
# suboxone treatment suboxone treatment 0.9999999 1.0
# taking kratom to reach 2436 hour mark take kratom to wait 2436 hours before subs 0.8434924 0.7235328555107117
# tapering drop to 1mg for month then 5mg for month then jump 0.411847 0.06912922114133835
# using kratom and lyrica drop to 1mg for month then 5mg for month then jump 0.4706913 0.24313032627105713
# dropping to lower doses drop to 1mg for month then 5mg for month then jump 0.5937092 0.5701969265937805
# reduced medication dosage taking less prescription 0.64237916 0.7255904078483582
# cutting dose suggested to cut dose 0.742306 0.8273707032203674
# talk to doctor about nonaddictive treatments for anxiety that are safe to take with suboxone taking 2mg bar 0.44276398 0.2533937394618988
# start suboxone wait 48 hours 0.57838714 0.21684876084327698
# wait 36 hours wait 36 hours 1.0 1.0000001192092896
# 11 32 26
# taking-moud subject-effect-arguments intervention 0.34374999999892575 0.4230769230752959 0.3793103447768133
# individual on daily dose of 32mg individual going down daily dose of 32mg 0.9465794 0.8796879649162292
# individual seeking help with tapering individual trying to taper off sub usage 0.7310612 0.5446840524673462
# individual on taper individual expecting discomfort for tapering 0.6684753 0.44324836134910583
# friend of post author and post author individual who snorted suboxone with naloxone to quit 0.46914557 0.14217206835746765
# post author and their girlfriend individual and their girlfriend suffering from anxiety after tapering 0.6899629 0.22962549328804016
# individual taking subs for 56 years individual needs help tapering 0.58979285 0.17045988142490387
# individual tapering with suboxone indivdual wanting to taper from suboxone 0.82929975 0.8266746997833252
# 40yearold in good shape who was on subutex for 20 years 40yearold who quit subutex for 20 years 0.8270652 0.8207299709320068
# individual taking suboxone individual just quit suboxone 0.820944 0.7770487666130066
# individual taking 1020 mg of oxys daily for 5 years individual wanting to do rapid taper to quit oxy 0.71891004 0.5255787968635559
# individual trying to quit opioid addiction indivdual seeking infromation on when they can quit suboxone 0.74671 0.4659265875816345
# individual taking 24 mg of subs daily patient going cold turkey 0.5874384 0.16959747672080994
# individual patient quitting opioid 0.3722532 0.10002575814723969
# individual tapering off subutex individual tapering off subutex and struggling from side effects 0.71079135 0.7841033339500427
# individual trying to taper off of suboxone individual tapering off suboxone experiencing side effects 0.8828419 0.7797024250030518
# people using kratom to help with sub wd individual using kratom to taper suboxone 0.7763907 0.5031495094299316
# individual starting taper to get off sub and all other opiates individual looking for advice to taper subs and opiates 0.8305211 0.7582800388336182
# brother is in methadone and taking vitadone individual suggesting vitadone for those going through withdrawals or quitting 0.75010365 0.5119248032569885
# individual taking subs for dirty 30 withdrawals individual tapering on subs 0.59982145 0.3084362745285034
# single mom working full time single mom 0.7147279 0.81427401304245
# individual who accidentally got hooked on fake roxies and then started buying suboxone strips off street individual tapering off suboxone after relapse 0.627334 0.42717456817626953
# individual struggling with suboxone tapering individual tapering suboxone and feeling well 0.8512597 0.8423138856887817
# individual taking subs and planning to taper off individual on suboxone for 2 years plans to quit 0.6859436 0.29816585779190063
# 11 26 25
# tapering main-arguments subject/patient 0.4230769230752959 0.43999999999824 0.4313725489679354
# rls kicks in restless leg syndrome 0.4404903 0.2671446204185486
# sleeps fine for 3 days after 2mg dosage restless leg syndrome 0.46728775 0.21114325523376465
# sneezing fits sneezing fits 0.99999994 1.0
# expects discomfort discomfort expected 0.8369755 0.87655109167099
# higher bioavailability able to quit suboxone 0.5210104 0.1323787271976471
# lil buzz able to quit suboxone 0.50336397 0.024643590673804283
# no withdrawal able to quit suboxone 0.48127452 0.4190690517425537
# anxiety insomnia and anxiety 0.680119 0.641838550567627
# insomnia insomnia and anxiety 0.8647173 0.8196682333946228
# feeling like 810 runny nose 0.510604 0.20088917016983032
# runny nose runny nose 1.0 0.9999999403953552
# nose running sick 0.70986927 0.2573973536491394
# nose running little nose running 0.8791177 0.8358966708183289
# feeling cold sick 0.78628653 0.4801843464374542
# withdrawal hits on third day little colder 0.5577358 0.06370635330677032
# sneezing sneezing 1.0 1.0
# sneezing insomnia 0.6283476 0.3201625943183899
# yawning yawning 1.0000001 0.9999999403953552
# insomnia insomnia 1.0 1.0
# headache and neck pain after dosing headache and neck pain 0.82159 0.8058207035064697
# stomachbladder pain after 1220 hours from last dose stomachbladder pain 0.73779017 0.7137284278869629
# restless legs awakeness 0.71243113 0.34229737520217896
# restless legs restless legs 1.0 1.0000001192092896
# discomfort awakeness 0.75601315 0.3745517134666443
# insomnia during withdrawal discomfort 0.47154886 0.10785291343927383
# physical effects may not be severe but mental part will come into play possible withdrawal 0.50780046 0.23872992396354675
# feels like losing mind loss of anxiety 0.6769212 0.42626407742500305
# feels like losing mind less brain fog 0.6746114 0.32810676097869873
# spikes of anxiety loss of anxiety 0.83985233 0.6996114253997803
# brain fog less brain fog 0.8458333 0.8699550628662109
# 14 28 20
# tapering main-arguments effects 0.4999999999982143 0.6999999999965001 0.5833333332822916
# cutting 4mgday going down from 32mg 0.70503056 0.5950319766998291
# cutting 4mgday wants to cut by 4mg day 0.74037564 0.9124075174331665
# two weeks per step going down from 32mg 0.5513709 0.15998762845993042
# tapering to 1mg lasts 2 days reducing subs dosage from 2mg every 3 days to 05mg daily 0.7396086 0.49184083938598633
# 2mg lasts 3 days reducing subs dosage from 2mg every 3 days to 05mg daily 0.53734845 0.5906214714050293
# dropped from 05mg to 025mg drop from 05 mg to 025 mg 0.8483674 0.9011537432670593
# snorting 14 of 82mg sub with naloxone twice day for month snorting suboxone to quit 0.76779413 0.5961847305297852
# kratom usage quit suboxone 0.62227374 0.11805524677038193
# daily quit suboxone 0.47090405 0.0848148912191391
# for sleep quit suboxone 0.5395965 0.15673834085464478
# due to rlsinsomnia quit suboxone 0.48956543 0.21520958840847015
# became physically dependent quit suboxone 0.5924575 0.12379084527492523
# hard to kick quit suboxone 0.56925386 0.12899337708950043
# trying to taper down from 6mg starting with 6mg 0.69158894 0.6648715734481812
# tapered from 24 mg to 3 mg with 90 subs over unspecified duration went from 24mg suboxone to 3mg 0.8004846 0.579248309135437
# 7 months clean after tapering off subutex 7 months clean 0.628789 0.6013197898864746
# last opioid on friday from 12mg to 0mg 0.4317041 0.21912531554698944
# no suboxone since thursday from 12mg to 0mg 0.5016921 0.2777692675590515
# 12mg suboxone from 12mg to 0mg 0.664006 0.6095658540725708
# 6mg in reserve from 12mg to 0mg 0.55888706 0.639150857925415
# prescribed subs with verbal commitment to year or two looking for tapering schedule 0.6668327 0.13479721546173096
# tapering as slowly as possible to as low as possible before stopping looking for tapering schedule 0.5829654 0.40122097730636597
# tried sleeping medicine attempting 0125 mg to 0 mg 0.525583 0.16020986437797546
# weed attempting 0125 mg to 0 mg 0.45186716 0.08076988160610199
# benzos attempting 0125 mg to 0 mg 0.49582592 0.08570801466703415
# phenibut attempting 0125 mg to 0 mg 0.5712406 0.11751676350831985
# currently on 1mg daily tapering off subutex on 1 mgday 0.5300627 0.5143952369689941
# dropped dose 5 days ago tapering off subutex on 1 mgday 0.7462026 0.3297598958015442
# tapering from 5 to 25 suboxone from 5mg suboxone to 30mg 0.8080415 0.6740924715995789
# 4 days duration attempting to jump to 25mg 0.5302881 0.12257031351327896
# goal dosage 25 attempting to jump to 25mg 0.61951643 0.5844429731369019
# uses lowdose benzosopiates 05mg klonopin5mg hydro or 100 tramadol for 4 days taking subs and wants to quit 0.5789593 0.12472566962242126
# natural sleep aids taking subs and wants to quit 0.56358486 0.03746705874800682
# vitamins taking subs and wants to quit 0.5119767 0.08780786395072937
# started at 6mg day 6 mg day to 34 mg in 4 days 0.66574824 0.7343800067901611
# reduced to 34 mg after 4 days 6 mg day to 34 mg in 4 days 0.8417749 0.8276398777961731
# jumped from 2mg after 8 years of use going down to 2mg suboxone 0.7085125 0.5519800782203674
# taking 24mg day for 2 years looking to use 90 8mgs to taper off 0.6676097 0.41133925318717957
# planning to taper off 90 8mg pills looking to use 90 8mgs to taper off 0.8056283 0.8628422021865845
# 7 43 25
# tapering main-arguments tapering-event 0.16279069767404 0.27999999999888003 0.2058823528940744
# on subs daily for 5 to 6 years taking 6mg of subs 0.6392057 0.47389185428619385
# suboxone usage for pain management taking 24 mg of suboxone 0.79984444 0.7160146832466125
# on subutex for 20 years on suboxone for last 20 years 0.80192155 0.6669870018959045
# feeling fine subject was taking 12 mg of suboxone and opioids 0.37798142 0.17115625739097595
# runny nose subject was taking 12 mg of suboxone and opioids 0.3912909 0.14892388880252838
# functioning at 810 subject was taking 12 mg of suboxone and opioids 0.48445225 0.09421412646770477
# 5 years of 1020 mg of oxys daily taking 1020mg of oxy daily for 5 years 0.8868379 0.8999642133712769
# seeking withdrawal relief taking subs for dirty 30 withdrawals for 4 days 0.55680114 0.5229361057281494
# wants off but never experienced wd before single mother who is working full time 0.5732158 0.11818549036979675
# clean off of opiates for four years took fake roxies after being off opiates for 4 years 0.8424669 0.679043173789978
# feeling brain and body chemistry changes felt ill 0.5508422 0.2617068290710449
# anxiety felt ill 0.7437947 0.40579360723495483
# brain fog felt ill 0.7176233 0.2979666590690613
# tired of being on subs for almost 3 years been on subs for 3 years 0.8602835 0.8609787225723267
# 5 16 10
# tapering event-specific-arguments condition 0.3124999999980469 0.499999999995 0.38461538456508876
# want to get clean wanting to quit oxy 0.7425206 0.24784910678863525
# appointment tomorrow just beginning suboxone 0.57688594 0.19811667501926422
# to help with sub wd suboxone taper 0.5425496 0.2722248435020447
# not present desire to quit opiates 0.43168187 0.017301242798566818
# accidentally got hooked on fake roxies wanting to stay off medication after relapse 0.6581858 0.16037002205848694
# buying suboxone strips off street wanting to stay off medication after relapse 0.5428999 0.17456169426441193
# feels ready to get off of subs tired of being on subs 0.7772556 0.6719457507133484
# 1 8 7
# tapering event-specific-arguments trigger 0.1249999999984375 0.14285714285510204 0.13333333328177777
# today today 0.9999999 1.0000001192092896
# not mentioned thursday 0.6446833 0.2551334500312805
# third day three days ago 0.68611664 0.6287094950675964
# not specified trying tapering to 25 for 4 days 0.470424 0.06006079912185669
# 4 days before posting 4 days ago 0.73985845 0.6579082012176514
# four months ago 4 months ago 0.87474024 0.9858983159065247
# 2 7 7
# tapering event-specific-arguments start-time 0.2857142857102041 0.2857142857102041 0.28571428566020407
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# prescribed tapering selftaper 0.6050787 0.10614556819200516
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering self tapering 0.7003454 0.5649640560150146
# selftapering orallysublingually 0.6854205 0.34981197118759155
# not mentioned selftapering 0.51455206 0.08121693879365921
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# 11 23 23
# tapering event-specific-arguments type 0.478260869563138 0.478260869563138 0.478260869513138
# suboxone buprenorphine suboxone 0.7985409 0.7826735973358154
# suboxone buprenorphine and naloxone suboxone with naloxone 0.92291707 0.8505367040634155
# diphenhydramine diphenhydramine 0.99999994 1.0
# kratom kratom 1.0 1.0
# subs suboxone 0.6372401 0.35214412212371826
# suboxone suboxone 1.0 1.0
# suboxone 12 mg suboxone 0.84559774 0.8359251022338867
# subs suboxone suboxone 0.83840406 0.9045768976211548
# subs subs 1.0000001 1.0000001192092896
# subutex subutex 1.0 0.9999999403953552
# suboxone suboxone 1.0 1.0
# kratom kratom 1.0 1.0
# klonopin opiates 0.5946475 0.36202454566955566
# klonopin benzos 0.6045177 0.39171215891838074
# klonopin klonopin 1.0000001 1.000000238418579
# hydrocodone opiates 0.67385316 0.3780198097229004
# hydrocodone benzos 0.71292114 0.34992164373397827
# hydrocodone tramadol 0.5765358 0.3896998465061188
# tramadol opiates 0.5933637 0.5089721083641052
# tramadol benzos 0.6400131 0.3269318640232086
# tramadol tramadol 1.0 1.0
# suboxone kratomif required 0.5883638 0.20361903309822083
# suboxone subs 0.6372401 0.35214412212371826
# kratom kratomif required 0.7104471 0.6404950618743896
# kratom subs 0.64132977 0.1125117763876915
# fake roxies suboxone 0.50735426 0.2370310127735138
# suboxone strips suboxone 0.9251065 0.7823392152786255
# suboxone suboxone 1.0 1.0
# 8mg suboxone suboxone 0.86884505 0.8512595295906067
# 16 21 22
# tapering event-specific-arguments taper-medications 0.7619047619011339 0.7272727272694215 0.7441860464581938
# 05mg 05 mg 0.880277 0.9393645524978638
# 82mg 82mg 1.0 1.0
# 24 mg 24mg 0.69979584 0.9446220397949219
# 12 mg 12mg 0.7176265 0.9395279884338379
# not specified 5 0.654174 0.31135204434394836
# 6mg 6 mg 0.7363535 0.9401638507843018
# 5 10 10
# tapering event-specific-arguments initial-dosage 0.499999999995 0.499999999995 0.499999999945
# 2mg every 3 days 2mg every 3 days 1.0 1.0000001192092896
# 025mg 025 mg 0.8418047 0.9452039003372192
# 05mg 0mg 0.8156203 0.8032786250114441
# 6mg 6mg 1.0000001 1.0000001192092896
# 3 mg 3mg 0.79855776 0.9231275320053101
# 0 mg since thursd 0mg 0.6629463 0.7180406451225281
# 24 mg 0 mg 0.88468564 0.7035747766494751
# 125 0125 mg 0.59258527 0.43671947717666626
# 1mg daily 1 mg 0.71297705 0.7789731025695801
# 25 2530 0.6907172 0.3331565260887146
# 34 mg 34 mg 1.0 1.0000001192092896
# 2mg day or less 2mgday 0.6295312 0.7984532117843628
# 24mg day 24mg 0.62442833 0.8364930152893066
# 10 15 15
# tapering event-specific-arguments current-dosage 0.6666666666622222 0.6666666666622222 0.6666666666122222
# low 05mg day 0.61634433 0.20055121183395386
# 0mg 0mg 0.9999999 1.0
# 0 mg 0mg 0.77785414 0.8933465480804443
# quit quit or 0mg 0.7008754 0.6119225025177002
# 0 25 0.7471872 0.41191017627716064
# none 0 mg 0.6587009 0.36292019486427307
# none wants to get off 0 mg 0.44393852 0.22667744755744934
# 0mg 0mg 0.9999999 1.0
# 0mg 0mg 0.9999999 1.0
# 4 21 21
# tapering event-specific-arguments goal-dosage 0.19047619047528347 0.19047619047528347 0.19047619042528346
# 0 5 5
# tapering event-specific-arguments target-duration 0.0 0.0 0.0
# 40 years old 40 0.6004745 0.7096229195594788
# 0 1 1
# tapering subject-effect-arguments age 0.0 0.0 0.0
# 0 2 2
# tapering subject-effect-arguments gender 0.0 0.0 0.0
# opiates declining health issues 0.6510039 0.22552402317523956
# declining health issues declining health issues 0.9999999 1.0
# 1 8 7
# tapering subject-effect-arguments conditions 0.1249999999984375 0.14285714285510204 0.13333333328177777
# restless leg syndrome rls restless leg syndrome 0.88198984 0.8841315507888794
# sneezing fits sneezing fits 0.99999994 1.0
# higher bioavailability feeling ill 0.47464108 0.08477810025215149
# catch lil buzz feeling ill 0.50680137 0.21086697280406952
# anxiety physical dependency to kratom 0.54255617 0.10782419890165329
# anxiety ruined liver 0.7657228 0.13003987073898315
# insomnia physical dependency to kratom 0.38628227 0.11516478657722473
# rls physical dependency to kratom 0.47179967 -0.0384705513715744
# runny nose runny nose 1.0 0.9999999403953552
# nose running sick 0.70986927 0.2573973536491394
# nose running nose running 1.0 1.0000001192092896
# colder than usual sick 0.60894454 0.29008057713508606
# colder than usual colder 0.58117485 0.7775408625602722
# sneezing sneezing 1.0 1.0
# sneezing insomnia 0.6283476 0.3201625943183899
# yawning yawning 1.0000001 0.9999999403953552
# insomnia insomnia 1.0 1.0
# headache headache and neck pain 0.55612093 0.7251729965209961
# neck pain headache and neck pain 0.8885516 0.8624625205993652
# stomachbladder pain stomachbladder pains 0.95150214 0.9770182967185974
# withdrawal symptoms withdrawal 0.7734773 0.6977071166038513
# brain fog clear mind 0.7532581 0.5141074657440186
# 13 28 23
# tapering subject-effect-arguments side-effects 0.46428571428405613 0.5652173913018904 0.5098039215171088
# not severe low 0.7906569 0.336137592792511
# mild low 0.8565934 0.4009329080581665
# not specified low 0.7009091 0.3522552251815796
# worst worst insomnia 0.55987954 0.4867556095123291
# bad medium 0.7855164 0.23999541997909546
# 3 8 8
# tapering subject-effect-arguments severity 0.3749999999953125 0.3749999999953125 0.3749999999453125
# today today 0.9999999 1.0000001192092896
# 3 days ago since friday 0.6802856 0.47684794664382935
# third day three days ago 0.68611664 0.6287094950675964
# 5 or so days into dropping dose to 1mg 5 days of dropping to 1 mg 0.8749809 0.8681458234786987
# 1220 hours after last dose 1220 hours from last dose 0.97444254 0.93866366147995
# 3 6 6
# tapering subject-effect-arguments start-time 0.49999999999166667 0.49999999999166667 0.49999999994166666
# kratom wd 17 days 17 days 0.6812723 0.5373233556747437
# paws up to 90 days 17 days 0.6819083 0.5286399722099304
# suboxone wd 627 days 17 days 0.58344966 0.43643292784690857
# paws up to 90 days 17 days 0.6819083 0.5286399722099304
# 0 6 3
# tapering subject-effect-arguments side-effect-duration 0.0 0.0 0.0
# tapering down dose give taper two weeks to stabalize 0.61740065 0.5233173370361328
# reducing 4mg day give taper two weeks to stabalize 0.53541434 0.18930821120738983
# potential increase if unstable give taper two weeks to stabalize 0.49404377 0.1051100641489029
# tapering suggested to make 2mg last 4 0.58152455 0.1409151554107666
# taper when below 05mg day quitting suboxone and snorting 0.46968594 0.23712798953056335
# never touch diphenhydramine its in most otc sleep aids diphenhydramine 0.7497941 0.6347187757492065
# kratom not recommended due to potential for physical dependence and liver damage taking caution using kratom 0.648054 0.6969785094261169
# exercise taking 6mg suboxone or exercising 0.47797182 0.3661678433418274
# sleeping medicine phenibutweedbenzos 0.5797764 0.26168760657310486
# weed phenibutweedbenzos 0.46687335 0.46319228410720825
# benzos phenibutweedbenzos 0.61737937 0.33730703592300415
# phenibut phenibutweedbenzos 0.73460704 0.66236412525177
# try netty pot netty pot and ibuprofenacetaminophen before dosing 0.34206513 0.5323173999786377
# take ibuprofen or acetaminophen before dosing netty pot and ibuprofenacetaminophen before dosing 0.93710226 0.6707631945610046
# kratom kratom and benzos 0.6973778 0.6569421291351318
# benzos kratom and benzos 0.7997323 0.6879101395606995
# used kratom to get off suboxone habit used kratom to get off suboxone 0.9516077 0.9341610670089722
# using low dose opiatesbenzos for worst of withdrawal symptoms tramadol 0.3479594 0.3093891143798828
# using low dose opiatesbenzos for worst of withdrawal symptoms exercise 0.29543594 0.06405241042375565
# using low dose opiatesbenzos for worst of withdrawal symptoms natural sleep aid 0.6470047 0.08790579438209534
# using low dose opiatesbenzos for worst of withdrawal symptoms vitamins 0.44522458 0.048738859593868256
# natural sleep aids tramadol 0.6417817 0.1556248664855957
# natural sleep aids exercise 0.71934897 0.1240176111459732
# natural sleep aids natural sleep aid 0.92738754 0.9280279278755188
# vitamins tramadol 0.5397529 0.13178053498268127
# vitamins exercise 0.6969115 0.16704267263412476
# vitamins vitamins 1.0 1.0
# has some kratom get off subsgo to program 0.6441596 0.04300466924905777
# shot getting shot 0.7292588 0.8225644826889038
# 7 25 16
# tapering subject-effect-arguments intervention 0.27999999999888003 0.4374999999972657 0.34146341458488993
# individual getting suboxone script individual quitting percs 0.6641189 0.04081165790557861
# 22 22 years old male addicted to fentanyl 0.32030344 0.1809222549200058
# 22 wants to start bernese method 0.43843022 0.06483078002929688
# male 22 years old male addicted to fentanyl 0.4493934 0.20113049447536469
# male wants to start bernese method 0.38148925 0.09436795115470886
# 110115lbs 22 years old male addicted to fentanyl 0.4916427 0.1162964403629303
# 110115lbs wants to start bernese method 0.49265254 0.017210453748703003
# individual on opiates and benzos for 10 years individual relapsed on with multiple substances 0.71979207 0.5583513975143433
# individual who was on 8 mg suboxone daily for year individual asking for timing to take subs after relapse 0.71090275 0.3296716809272766
# individual using bupe patches individual eager to enjoy relapsing on bupe patches 0.7644112 0.7449805736541748
# individual taking oxycodone and suboxone individual relapses with oxycodone and percocet 0.8505413 0.6592695713043213
# individual switching back and forth between h and subs person quitting h with support group help 0.63394684 0.34046682715415955
# tomorrow morning i start subs individual who wants to start subs 0.6506923 0.677299439907074
# from over 100gpd of kratom im scared individual who wants to start subs 0.59937483 0.006288360804319382
# but it is what it is i have been trapped in this cycle of addiction for 5 yearsi am done currently high dosing thc individual who wants to start subs 0.5176373 0.06878630071878433
# waiting with 2mg of subs in my bedside table individual who wants to start subs 0.5533536 0.34985095262527466
# individual switching clinics individual relapsed with beers and wants to taper with subacade 0.47034717 0.3356744647026062
# individual taking kratom indivdual took kratom during withdrawal treatment 0.64146405 0.7578970193862915
# individual indivdual trying to switch from heroin to suboxone 0.30620584 0.045751944184303284
# individual who has been on suboxone for about year and relapsed individual who relapsed after being on suboxone for past year 0.9428459 0.9735729098320007
# individual currently doing fentanyl individual quitting fentanyl 0.8604451 0.7815741300582886
# individual taking suboxone individual asking about using opioid after suboxone 0.8364326 0.7310514450073242
# individual off subs for 7 days individual restarting subs 0.7334243 0.5598219633102417
# individual who was on kratom for over year individual quitting cold turkey for kratom dependency 0.6941061 0.5874190330505371
# post author indivdual who snorted suboxone in fear of overdosing 0.3732586 0.05855109542608261
# first time posting here person struggling to get back to subs after relapse 0.60730535 0.14504024386405945
# been on suboxone since august 2021 person struggling to get back to subs after relapse 0.65480644 0.2862432599067688
# i individual who relapsed on fentanyl 30 0.23373847 0.052765749394893646
# individual on suboxone individual on suboxone who used to use weed but now uses fentanyl for insomnia 0.6894098 0.5330531001091003
# individual trying to get off fent individual trying to quit fent 0.8226493 0.8590712547302246
# individual experiencing relapse individual relapsed on heroin for 34 days and aims to resume moud 0.7064583 0.5699085593223572
# individual asking about drinking while taking suboxone patient asking about drinking on suboxone 0.9506289 0.9348424673080444
# post authors boy with prescription for 75 pink percs individual switching from fent to subs using oxy 0.64391255 0.09683089703321457
# individual experiencing relapse patient whose use of suboxone blocks cocaine high 0.62642485 0.24858389794826508
# individual currently on 12 blues n 2 bars day individual taking substances and wants to start suboxone 0.6376746 0.14331567287445068
# individual who went through quickmd individual anticipating precipitated withdrawal 0.5927754 0.24756282567977905
# friend individual wondering if kratom helps with withdrawals 0.3962314 0.03697720915079117
# individual taking subs for dirty 30 withdrawals individual wants to quit from 75mg suboxone 0.5963242 0.4791923761367798
# individual trying to taperjump from suboxone individual intending to use kratom to taper and avoid side effects 0.78395957 0.4807010293006897
# individual seeking help after taking heroin individual starting intake after last heroin dose 0.73866844 0.6480556726455688
# individual on subutex for 3 years individual who uses subutex but relapsed on heroin 0.6607913 0.5945070385932922
# individual on pregabalin individual relapses with lots of medications 0.47043082 0.1540803164243698
# buprenophine individual relapses with lots of medications 0.5051869 0.2523214519023895
# and clonazepam individual relapses with lots of medications 0.6138563 0.2197217345237732
# post author indivdual in pain planning to use kratom 0.47343734 0.009207522496581078
# 9 43 36
# relapse main-arguments subject/patient 0.20930232558090858 0.24999999999930556 0.22784810121563853
# using around 1015 strong pressed 30’s daily fentanyl using around 1015 strong pressed 30’s daily 0.87294334 0.6698306202888489
# relapsed on xanax taking kratom 0.51246905 0.1834067404270172
# relapsed on xanax subs 0.38385797 0.005540374666452408
# relapsed on xanax oxy 0.38716033 0.10675416886806488
# relapsed on xanax diluadin 0.48888218 0.10273940116167068
# kratom taking kratom 0.8840753 0.8093277215957642
# kratom oxy 0.61343443 0.1606535166501999
# kratom diluadin 0.68895537 0.20705321431159973
# subs subs 1.0000001 1.0000001192092896
# subs diluadin 0.6078126 0.13063856959342957
# oxy oxy 1.0000001 1.0
# dilaudid diluadin 0.8165421 0.5455842018127441
# used about gram of fent over 3 days relapse to fent and percs 0.5915847 0.27368277311325073
# took 4 15 mg percs after last suboxone use relapse to fent and percs 0.6850153 0.407478392124176
# using bupe patches and planning to use morphine relapsing with morphine soon 0.656156 0.6573412418365479
# took 20 mg oxycodone and 2 mg suboxone 20mg oxycodone this morning 0.8358068 0.8091910481452942
# been trying to induce subs for few weeks now back and forth between h and subs 0.57275677 0.3846527338027954
# start subs high dosing thc 0.498958 0.06938516348600388
# from over 100gpd of kratom high dosing thc 0.54540896 0.2257796823978424
# high dosing thc high dosing thc 1.0000001 1.0000001192092896
# had few beers on father’s day relapsed with beer on fathers day 0.7704927 0.8157170414924622
# took about 3g of kratom around 80 hr mark took 3g of kratom 0.8827203 0.8668026924133301
# teeter tottering on edge between h and subs taking heroin 0.4636634 -0.04783908277750015
# took addictive substances on friday night havent taken suboxone since friday 0.6960818 0.49974989891052246
# taking fentanyl relapsing on fent after cold turkey withdrawal 0.4502415 0.44118204712867737
# using opioid using opioids after last dose of suboxone 0.7174612 0.6680659651756287
# resumed taking h and fent for year h and fent 0.7503851 0.6664292216300964
# snorted 8mg of subconscious snorted 8mg suboxone 0.6784321 0.7518087029457092
# screwed up bad few weeks ago took oxy 30sfentanyl 0.38915867 0.17685745656490326
# doing oxy 30s took oxy 30sfentanyl 0.69313705 0.6906275153160095
# relapsed on fent 30’s for few days relapsed at 1130pm last night 0.73594946 0.5344027280807495
# using fent for sleep use fentanyl for sleep 0.7170678 0.783244252204895
# relapsed on heroin for under week relapse on heroin for 34 days 0.9046024 0.8542301058769226
# drinking while taking suboxone drinking on suboxone 0.86603534 0.9566577076911926
# ...
# percs percocet 0.6829824 0.5684541463851929
# fentanyl pressed 30s 0.30653974 0.10178772360086441
# kratom kratom 1.0 1.0
# kratom diluadin 0.68895537 0.20705321431159973
# subs oxy 0.59775823 0.24639689922332764
# subs diluadin 0.6078126 0.13063856959342957
# oxy oxy 1.0000001 1.0
# dilaudid diluadin 0.8165421 0.5455842018127441
# fent fent and percs 0.72123665 0.659132719039917
# about gram over 3 days fent and percs 0.5597452 0.03209776058793068
# morphine morphine 1.0 1.0
# oxycodone oxycodone and percocet 0.9128873 0.8080217838287354
# heroin likely replaced by fentanyl heroin 0.5804326 0.6209135055541992
# heroin likely replaced by fentanyl fentynal 0.47093856 0.38625457882881165
# kratom thc 0.6397693 0.19885066151618958
# beers alcohol 0.8363154 0.7118188142776489
# kratom kratom 1.0 1.0
# dirty 30s dirty 30s 1.0 1.0
# heroin heroin 1.0 0.9999999403953552
# kratom fent 0.70474863 0.26116204261779785
# opioids opioid 0.873849 0.9370911121368408
# heroin h and fent 0.5421461 0.2558823823928833
# fentanyl h and fent 0.40444225 0.4101540446281433
# subconscious suboxone 0.6113368 0.12764541804790497
# oxy 30s likely fentanyl oxy 30s fentanyl 0.9713684 0.9595780372619629
# fentanyl fentanyl 30 0.9129855 0.8508608341217041
# fentanyl fentanyl 0.9999999 1.0
# suboxone fentanyl 0.6496843 0.4136883616447449
# heroin heroin 1.0 0.9999999403953552
# alcohol alcohol 1.0000001 1.0
# cocaine cocaine 0.9999999 1.0
# ice blues 0.82112545 0.35587579011917114
# ice bars 0.82578266 0.30492788553237915
# ice meth 0.559489 0.2605893313884735
# ice ice 1.0000001 1.000000238418579
# h kratom 0.606806 0.15433502197265625
# h h 1.0 1.0000001192092896
# kratom kratom 1.0 1.0
# kratom kratom 1.0 1.0
# kratom kratom 1.0 1.0
# heroin heroin 1.0 0.9999999403953552
# heroin heroin 1.0 0.9999999403953552
# heroin clonazepam and pregabalin 0.40234783 0.19952215254306793
# kratom kratom 1.0 1.0
# 18 37 41
# relapse event-specific-arguments relapse-substance 0.4864864864851716 0.43902439024283163 0.46153846148740957
# last use was about 5 days ago 3 days 0.5618235 0.41853228211402893
# not specified two days 0.64060736 0.2881278991699219
# 1 week one day 0.6573183 0.6308224201202393
# 2 days yesterday and today 0.6538601 0.4147115647792816
# 1 year one year 0.8527212 0.9410743713378906
# few days several days 0.9084104 0.8521144390106201
# 3 to 4 days 34 days 0.7676211 0.7021538019180298
# 15 g per day for most of last 6 months 6 months 0.56525457 0.274250328540802
# over week two days last night 0.604715 0.5252272486686707
# over week this morning 0.7391086 0.5595139265060425
# 0 11 12
# relapse event-specific-arguments relapse-duration 0.0 0.0 0.0
# hot soaks started taking suboxone 0.515602 0.009623666293919086
# imodium started taking suboxone 0.5877016 0.2481502890586853
# distractions started taking suboxone 0.5323041 0.09424546360969543
# walks started taking suboxone 0.47172728 0.01051896158605814
# bernese method with suboxone bernese method 0.74154985 0.754558265209198
# wait at least another 24 hours switching back to suboxone 0.5147039 0.17270585894584656
# start with 1mg suboxon switching back to suboxone 0.69840366 0.5923092365264893
# take 1 mg or less of suboxone taking suboxone again 0.8251423 0.7760499715805054
# support group quitting with support group help 0.6587281 0.6805720329284668
# reentry program wants to start subacade 0.55229163 0.15360543131828308
# reentry program switching clinics 0.66724926 0.1479446440935135
# waiting time wants to start subacade 0.53312707 0.17140240967273712
# waiting time switching clinics 0.7005687 0.13003067672252655
# continue with suboxone continue taking subs 0.65768015 0.5127124190330505
# bernese method bernese method 0.9999999 1.0000001192092896
# advised not to use suboxone subs 0.38620913 0.16452656686306
# bernese method or endure wd trying to switch back to suboxone 0.5653184 0.06194661930203438
# increased buprenorphine dosage taking more subs 0.5248447 0.21324101090431213
# trying otc sleep meds use sleep meds 0.8393017 0.7001569867134094
# trying otc sleep meds ambien 0.47231385 0.4264157712459564
# trying otc sleep meds benzos 0.5242017 0.184784933924675
# ambien use sleep meds 0.5061209 0.39984118938446045
# ambien ambien 1.0 1.0
# or any benzo use sleep meds 0.6433239 0.20586493611335754
# or any benzo benzos 0.75727725 0.7507415413856506
# telehealth using suboxone 0.43143275 0.0007769204676151276
# google doctors in area using suboxone 0.5487669 -0.07184669375419617
# start at no more than 24mg suboxone wants to start moud 0.47973877 0.253462016582489
# start at no more than 24mg suboxone start at 24mg 0.5439719 0.7915372848510742
# start at no more than 24mg suboxone no meth 0.51788497 0.24335314333438873
# wait as long as possible between doses wants to start moud 0.5178473 0.17849308252334595
# wait as long as possible between doses start at 24mg 0.5130738 0.5185701847076416
# wait as long as possible between doses no meth 0.4398619 0.20063117146492004
# fighting withdrawal for year quickmd 0.57679784 0.06742909550666809
# fighting withdrawal for year buprenorphine 0.39571828 0.15534290671348572
# plan to get on methadone plan to use methadone 0.79439336 0.953679621219635
# 2 28 25
# relapse event-specific-arguments relapse-intervention 0.07142857142831634 0.07999999999968001 0.07547169806308295
# need to wait for suboxone script 36 hours 0.4668563 0.10613884031772614
# 26 hours after last fent use 26 hours after last fent 0.8895881 0.9303451776504517
# 26 hours after last fent use 1 hour after percs 0.7747797 0.37768352031707764
# 1 hour after last percs use 26 hours after last fent 0.8339156 0.3949061632156372
# 1 hour after last percs use 1 hour after percs 0.8733733 0.9148663282394409
# 3 weeks one week 0.7962649 0.7498917579650879
# 1 week one week 0.81216425 0.9525753855705261
# 3 days after last fentanyl dose three days 0.44913343 0.4425133466720581
# at least 72 hours 72 hours 0.83975184 0.8102807998657227
# 7 days after last dos 7 days 0.7430383 0.6468496322631836
# last used at 1130 pm 7hrs 0.507933 0.4045807123184204
# woke up at 6 7hrs 0.52246284 0.3644060492515564
# not specified wait until in ed enough 0.5611861 0.04633346199989319
# not waited after last dose 24 hours 0.5589911 0.21478280425071716
# 20 hours after last dose of heroin 20 hours 0.59536946 0.45410841703414917
# zero withdrawal symptoms couple hours last night 0.54561955 0.10057646036148071
# zero withdrawal symptoms this morning 0.57059425 0.06950856000185013
# 0 14 13
# relapse event-specific-arguments waiting-time 0.0 0.0 0.0
# 22 22 0.9999999 1.0
# 33yo 33 0.7993945 0.7458442449569702
# 1 2 2
# relapse subject-effect-arguments age 0.499999999975 0.499999999975 0.499999999925
# male male 1.0 1.0
# 1 3 3
# relapse subject-effect-arguments gender 0.3333333333222222 0.3333333333222222 0.3333333332722222
# using around 1015 strong pressed 30s daily fentanyl fentanyl addiction 0.6484387 0.5631889700889587
# kratom addiction for 5 years kratom and thc addict 0.7563815 0.7564525604248047
# opioid use disorder insomnia 0.71804094 0.17857250571250916
# opioid use disorder substance dependence 0.7338582 0.5216964483261108
# insomnia insomnia 1.0 1.0
# arthritis in hips arthritis in hips 0.9999999 1.0
# 2 15 14
# relapse subject-effect-arguments conditions 0.13333333333244443 0.14285714285612244 0.13793103443186683
# withdrawals withdrawal symptoms 0.75209516 0.6750657558441162
# fear withdrawal symptoms 0.7030247 0.1048804372549057
# unfunctional withdrawal 0.44826767 0.15143314003944397
# sick of kratom withdrawal 0.4452847 0.17651543021202087
# feeling too good feeling good 0.80115825 0.8202781677246094
# relapse precipitated withdrawal 0.5426168 0.3682243824005127
# not taking suboxone precipitated withdrawal 0.4630503 0.3093410134315491
# fentanyl withdrawal cold turkey withdrawal 0.52909786 0.5295060276985168
# precipitated withdrawal cold turkey withdrawal 0.59179324 0.5898809432983398
# withdrawal symptoms wd symptoms 0.65804297 0.4162028431892395
# withdrawals from kratom withdrawals 0.7093189 0.6106459498405457
# snorted 8mg of subconscious throw up and nod out 0.59481335 0.314416766166687
# barely no tolerance throw up and nod out 0.58495015 0.2257523536682129
# threw up throw up and nod out 0.7345935 0.5913294553756714
# nod out throw up and nod out 0.76754016 0.7563759088516235
# knees aching and hurting sickness 0.5217454 0.20780140161514282
# knees aching and hurting achy knees 0.6863962 0.5760393142700195
# sick sickness 0.9061254 0.548497200012207
# sick achy knees 0.57605666 0.26234662532806396
# difficulty sleeping insomnia 0.70646447 0.5945719480514526
# precipitated withdrawals precipitated withdrawals 0.99999994 1.0
# get drunk while taking suboxone more alcohol to get drunk 0.7445796 0.5247657299041748
# get drunk while taking suboxone less enjoyable drunkness 0.673196 0.47325050830841064
# suboxone blocks cocaine high cant feel cocaine high 0.5753611 0.5640384554862976
# precipitated withdrawal lack of sleep 0.5473531 0.2216104120016098
# sweaty sweaty 1.0000001 1.0
# sweaty cant sit still 0.51109606 0.3057635426521301
# skin crawling skin crawling 1.0 1.0000001192092896
# cant sit still cant sit still 1.0 0.9999999403953552
# pain pain 1.0000001 1.0000001192092896
# 5 29 24
# relapse subject-effect-arguments side-effects 0.17241379310285376 0.2083333333324653 0.18867924523275187
# benzo withdrawal high 0.49206275 0.17466482520103455
# severe too much 0.5845253 0.30459412932395935
# not relieved by 10mg of sub high 0.4440508 0.16892759501934052
# high continued fentanyl use for sleep medium 0.3277786 0.0029176599346101284
# significantly more alcohol required low 0.59553105 0.1691042184829712
# less enjoyable drunkness low 0.5767942 0.1650511920452118
# out of mind high 0.56948704 0.202500581741333
# bad high 0.76385975 0.32130658626556396
# 0 10 9
# relapse subject-effect-arguments severity 0.0 0.0 0.0
# around 80 hr mark 80 hours ago 0.7225863 0.5233258008956909
# last used at 1130 last night hour ago 0.55588436 0.43190526962280273
# few months on suboxone few months ago 0.67216295 0.31241387128829956
# 0 6 6
# relapse subject-effect-arguments start-time 0.0 0.0 0.0
# not specified 3 days 0.67965317 0.29527783393859863
# past hour 1 hour 0.757102 0.5367929935455322
# difficulty sleeping for few months months 0.61193323 0.261955589056015
# 0 5 5
# relapse subject-effect-arguments side-effect-duration 0.0 0.0 0.0
# suboxone hot soaks 0.45465937 0.16297966241836548
# suboxone imodium 0.7388188 0.4052111506462097
# suboxone distractions 0.5708691 0.1513395458459854
# suboxone walks 0.6196765 0.10680311173200607
# hot soaks hot soaks 0.99999994 1.0
# hot soaks distractions 0.59362084 0.08781875669956207
# hot soaks walks 0.43657553 0.07946085184812546
# imodium imodium 1.0 1.0000001192092896
# imodium walks 0.48289353 0.17693763971328735
# distractions distractions 0.9999999 1.0
# walks walks 1.0 1.0000001192092896
# bernese method bernese method 0.9999999 1.0000001192092896
# starting with super small dose of subs gradual increase of subs 0.6550927 0.5553480982780457
# increasing daily gradual increase of subs 0.67132866 0.4676301181316376
# stopping blues at 16mg per day gradual increase of subs 0.4994389 0.10845750570297241
# then t gradual increase of subs 0.5114485 0.1255132406949997
# taper down benzos suboxone 0.69190377 0.23231200873851776
# taper down benzos oxycodone 0.58856446 0.28187623620033264
# taper down benzos diliduan 0.38512367 0.16343817114830017
# bridged gap for 24 hours with 4 15 mg percs pharma wait 24 hours 0.57913417 0.2823752164840698
# bridged gap for 24 hours with 4 15 mg percs pharma start off with 1 mg 0.5968578 0.4211242198944092
# wait 5 days for morphine to have chance of working wait 5 days for morphine to work 0.9204092 0.971997857093811
# trying to induce subs for few weeks now quitting with support group help 0.675693 0.16021253168582916
# used to switch back and forth quitting with support group help 0.4938149 0.03744480758905411
# made up mind to quit with support group help quitting with support group help 0.77663314 0.8887020349502563
# starting suboxone treatment need more than 2mg of subs 0.60212976 0.42225000262260437
# high dosing thc need more than 2mg of subs 0.56884557 0.29119598865509033
# and planning to take 2mg suboxone need more than 2mg of subs 0.6699392 0.5530003309249878
# waiting for week to start new program switching clinics 0.5322579 0.19701240956783295
# using subs for taper schedule regular supply of subs 0.59367585 0.43958204984664917
# continue with suboxone planning to change subs dose 0.6433245 0.39252638816833496
# change dose planning to change subs dose 0.7555872 0.6800514459609985
# waiting 3 days bernese method 0.5829608 -0.013134213164448738
# taking suboxone bernese method 0.54978144 0.10320813208818436
# bernese method bernese method 0.9999999 1.0000001192092896
# quitting kratom cold turkey quitting cold turkey 0.86057323 0.6756768226623535
# using suboxone for kratom dependency quitting cold turkey 0.51849145 -0.0358051061630249
# narcan on hand suggested to use narcan 0.5848933 0.8518672585487366
# increased sub dosage more subs 0.67649424 0.3871464431285858
# increased sub dosage comfort meds 0.68521637 0.18905360996723175
# comfort meds more subs 0.61931044 0.080501489341259
# comfort meds comfort meds 1.0000001 1.0
# otc sleep meds take sleep meds 0.81830573 0.6619113683700562
# otc sleep meds ambien 0.5215544 0.4475407898426056
# otc sleep meds benzo 0.5030761 0.16665324568748474
# ambien take sleep meds 0.5594879 0.39291852712631226
# ambien ambien 1.0 1.0
# benzo take sleep meds 0.5987935 0.1261572539806366
# benzo benzo 0.9999999 1.0000001192092896
# suboxone in morning take sleep meds 0.5500113 0.36892709136009216
# no caffeine take sleep meds 0.67883676 0.33447831869125366
# google doctors in area get suboxone from doctors in area 0.688167 0.40472304821014404
# use telehealth for prescriptions get suboxone from doctors in area 0.6023534 0.3787076473236084
# read about complete withdrawal before taking subs get suboxone from doctors in area 0.5876317 0.284504771232605
# should start at no more than 24mg suboxone take 24mg for first month 0.6993112 0.6147851347923279
# should start at no more than 24mg suboxone then 8mg or less 0.70202374 0.5624587535858154
# should start at no more than 24mg suboxone alcohol can help but no meth 0.70414895 0.2998310923576355
# wait as long as possible between doses take 24mg for first month 0.6110204 0.5008329153060913
# wait as long as possible between doses then 8mg or less 0.57966524 0.4177795946598053
# wait as long as possible between doses alcohol can help but no meth 0.5998437 0.27033913135528564
# try to get script for benzos take 24mg for first month 0.697184 0.11746372282505035
# try to get script for benzos then 8mg or less 0.5515297 0.13108637928962708
# try to get script for benzos alcohol can help but no meth 0.6339019 0.21419627964496613
# alcohol can hold over but better under medical supervision take 24mg for first month 0.5937883 0.006701625883579254
# alcohol can hold over but better under medical supervision then 8mg or less 0.56556803 0.14714428782463074
# alcohol can hold over but better under medical supervision alcohol can help but no meth 0.8056424 0.4978989362716675
# meth is off table take 24mg for first month 0.58621573 0.18893948197364807
# meth is off table then 8mg or less 0.56732553 0.25055018067359924
# meth is off table alcohol can help but no meth 0.7473797 0.602861762046814
# wait 24 hours after last opiate use wait 24 hours after last opiate use 1.0000001 1.0000001192092896
# used kratom to get off of subs use kratom 0.66291314 0.639115035533905
# took first 2mg dose of medication moud intake 0.5141071 0.15156468749046326
# plans to get on methadone planning to use methadone 0.7861218 0.9114653468132019
# suboxone kratom while on suboxone 0.7228825 0.6629152297973633
# kratom ordered kratom while on suboxone 0.69978225 0.5373191833496094
# 10 53 36
# relapse subject-effect-arguments intervention 0.18867924528266286 0.2777777777770062 0.22471910107491477
# results-Mixtral-8x7B-Instructbatch_question_guided_0.99.json
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Results/2-new-results-Mixtral-8x7B-Instruct.json
# CPU times: user 2h 27min 2s, sys: 12min 56s, total: 2h 39min 59s
# Wall time: 7h 38min 35s

# %% [markdown]
# printing to understanding the nesting in the results dict

# %%
print(results_dict.keys())
print(results_dict['batch_description_guided_0.749'].keys())
print(results_dict['batch_description_guided_0.749']['tapering'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments']['effects'])
# Out:
# dict_keys(['batch_description_guided_0.749', 'batch_description_guided_0.99', 'batch_question_guided_0.749', 'batch_question_guided_0.99', 'isolated_description_guided_0.749', 'isolated_description_guided_0.99', 'isolated_question_guided_0.749', 'isolated_question_guided_0.99'])
# dict_keys(['taking-moud', 'tapering', 'relapse'])
# dict_keys(['main-arguments', 'event-specific-arguments', 'subject-effect-arguments'])
# dict_keys(['subject/patient', 'effects', 'tapering-event'])
# [[0.4583333333314236, 0.54999999999725, 0.49999999994814043], [11, 24, 20]]
