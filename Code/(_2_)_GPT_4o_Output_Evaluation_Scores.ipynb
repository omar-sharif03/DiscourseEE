# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
# !pip install transformers # If you are using collab, "!" is required to download
# !pip install bert-score
# !pip install -U sentence-transformers

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer

# Download NLTK resources
nltk.download('punkt')
nltk.download('wordnet')

# %%
import os, json
import numpy as np
from argparse import ArgumentParser
from tqdm import tqdm
from collections import defaultdict
import pandas as pd
from pprint import pprint
import re, string
from google.colab import files

from transformers import BertTokenizer, BertModel
from sentence_transformers import SentenceTransformer, util
import torch
import copy

# %% [markdown]
# ## Calculating evaluation scores

# %%
def read_json_file(name):
    with open(name, 'r') as f:
        data = json.load(f)
        return data

def save_json(json_data, file_name):
    json_data = json.dumps(json_data)
    print(file_name)
    with open(file_name, "w") as json_file:
          json_file.write(json_data)

# %%
# def perform_lemmatization(text):

#     # Tokenize the text into words
#     words = word_tokenize(text)
#     lemmatizer = WordNetLemmatizer()
#     stemmer = PorterStemmer()
#     lemmatized_and_stemmed_words = [(lemmatizer.lemmatize(word), stemmer.stem(word)) for word in words]

#     lemmatized_words, stemmed_words = zip(*lemmatized_and_stemmed_words)
#     lemmatized_text = ' '.join(lemmatized_words)
#     stemmed_text = ' '.join(stemmed_words)

#     # print("Original text:", text)
#     # print("Lemmatized text:", lemmatized_text)
#     # print("Stemmed text:", stemmed_text)
#     return stemmed_text

def clac_sbert_score(text1, text2):
    model = SentenceTransformer("all-MiniLM-L6-v2")

    embeddings1 = model.encode(text1, convert_to_tensor=True)
    embeddings2 = model.encode(text2, convert_to_tensor=True)

    cosine_score = util.cos_sim(embeddings1, embeddings2)
    #print(cosine_score.item())
    return cosine_score.item()

def calc_cosine_similarity(text1, text2):

    tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
    model = BertModel.from_pretrained("bert-base-uncased")

    # text1 = perform_lemmatization(text1)
    # text2 = perform_lemmatization(text2)

    inputs1 = tokenizer(text1, return_tensors="pt", padding=True, truncation=True)
    inputs2 = tokenizer(text2, return_tensors="pt", padding=True, truncation=True)

    outputs1 = model(**inputs1)
    outputs2 = model(**inputs2)

    embeddings1 = outputs1.last_hidden_state.mean(dim=1).detach().numpy()
    embeddings2 = outputs2.last_hidden_state.mean(dim=1).detach().numpy()

    #Calculate cosine similarity
    similarity = np.dot(embeddings1, embeddings2.T) / (np.linalg.norm(embeddings1) * np.linalg.norm(embeddings2))

    #print("Similarity between the texts:", similarity)
    return similarity[0][0]

# %%
def is_null_or_empty(string):
    return string is None or string.strip().lower() == 'null' or string.strip() == ''

def normalize_string(s):
      def remove_articles(text):
          regex = re.compile(r'\b(a|an|the)\b', re.UNICODE)
          return re.sub(regex, ' ', text)
      def white_space_fix(text):
          return ' '.join(text.split())
      def remove_punc(text):
          exclude = set(string.punctuation)
          return ''.join(ch for ch in text if ch not in exclude)
      def lower(text):
          return text.lower()
      return white_space_fix(remove_articles(remove_punc(lower(s))))


def calculate_score(predictions, ground_truth_labels, similarity_threshold):
    true_pos, pred_count, gtruth_count = 0, len(predictions), len(ground_truth_labels)

    if ((len(ground_truth_labels)==1 and is_null_or_empty(ground_truth_labels[0]))): #only not calculating when ground-truth is null
        #print("xxx ", predictions, labels) #(len(predictions)==1 and is_null_or_empty(predictions[0]))
        return 0, 0, 0 #skipping this sample
    else:
        actual_labels = copy.deepcopy(ground_truth_labels)
        # print(predictions, actual_labels)
        # print(len(predictions), len(actual_labels))
        for p in predictions:
            for g in actual_labels:
                if(g.strip() == ''): gtruth_count -=1 ## if any ground-truth is empty reducing that count.
                if(is_null_or_empty(p) or is_null_or_empty(g)): continue ##if prediction/ground-truth is null then skip
                np, ng = normalize_string(p), normalize_string(g)
                sim_value = calc_cosine_similarity(np,ng)
                sbert_score = clac_sbert_score(np, ng)
                print(np, ng, sim_value, sbert_score)
                if(sim_value>similarity_threshold or sbert_score>similarity_threshold):
                    true_pos += 1
                    actual_labels.remove(g)
        # print(predictions, labels)
        # print(true_pos, pred_count, gtruth_count)
        return true_pos, pred_count, gtruth_count

def calc_precision_recall_f1(true_pos, pred_count, gtruth_count):
    print(true_pos, pred_count, gtruth_count)
    precision = true_pos/(pred_count + 1e-10)
    recall = true_pos/(gtruth_count + 1e-10)
    f1 = 2 * precision * recall / (precision + recall + 1e-10)
    return precision, recall, f1

# %%
def select_event_specific_data(event, data):
    ev_data = []
    for dt in data:
        if event==dt['label']:
            ev_data.append(dt)
    return ev_data

def calc_results(all_data, event_types, arg_types, events_roles, pred_name, gtruth_name, similarity_threshold):
    results = {}
    for event in event_types:
        results[event] = {}
        for arg_type in arg_types:
            results[event][arg_type] = {}
            arguments = list(events_roles[event][arg_type].keys())
            for arg in arguments:
                tp, pc, gc = 0, 0, 0 #initialize the true_positive, pred_count, ground_truth-count for each arguments
                event_specifc_data = select_event_specific_data(event, all_data) ##geting the data for a specific event type.
                for dt in event_specifc_data:
                    label = dt['label']
                    pred_list = dt[pred_name][arg_type][arg] #predictions
                    gtruth_list = dt[gtruth_name][arg_type][arg] #ground-truth arguments
                    #print(pred_list, gtruth_list)
                    true_pos, pred_count, gtruth_count = 0, 0, 0
                    try:
                       true_pos, pred_count, gtruth_count = calculate_score(pred_list,
                                                                         gtruth_list, similarity_threshold)
                    except:
                        print(event, arg_type, arg)
                        print(pred_list, gtruth_list)
                        print("Error occured at", dt['doc_id'])

                    tp+= true_pos
                    pc+= pred_count
                    gc+= gtruth_count
                if(gc==0):
                    continue #skiping those values, where we do not have any ground truth.

                precision, recall, f1 = calc_precision_recall_f1(tp, pc, gc)
                print(event, arg_type, arg, precision, recall, f1)
                #saving the values in two items is a list
                #first item has (precision, recall, f1 scores) #second item has (true_pos, pred_count, ground_truth_count values)
                results[event][arg_type][arg]= [[precision, recall, f1], [tp, pc, gc]]

    return results

# %%
# %%time

events_roles = read_json_file('/role_definitions.json')

prompt_types = ['batch'] #['batch', 'isolated']
exp_types = ['description_guided', 'question_guided']
event_types = ['taking-moud', 'tapering', 'relapse']
arg_types = ['main-arguments', 'event-specific-arguments', 'subject-effect-arguments']
similarity_threshold = [0.749, 0.99]

number = '1'
name = 'gpt-4o'
folder_path = '/content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Predictions'
file_name = f'{number}-processed-{name}_test_100_predictions.json'
print(os.path.join(folder_path, file_name))
all_data = read_json_file(os.path.join(folder_path, file_name))

print(all_data[0].keys())
print(len(all_data))
# Out:
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Predictions/1-processed-gpt-4o_test_100_predictions.json
# dict_keys(['doc_id', 'id', 'text1', 'text2', 'label', 'thread-length', 'ground-truth-arguments', 'raw-batch_description_guided-predictions', 'raw-batch_question_guided-predictions', 'processed-batch_description_guided-predictions', 'processed-batch_question_guided-predictions'])
# 100
# CPU times: user 17.1 ms, sys: 863 µs, total: 18 ms
# Wall time: 53.7 ms

# %%
# %%time
numbers = ['0', '1', '2']

for number in numbers:
    file_name = f'{number}-processed-{name}_test_100_predictions.json'
    all_data = read_json_file(os.path.join(folder_path, file_name))

    results_dict = {}
    for p_type in prompt_types:
          for e_type in exp_types:
              g_name = 'ground-truth-arguments'
              p_name = f'processed-{p_type}_{e_type}-predictions'
              for s_t in similarity_threshold:
                  print(p_type, e_type, s_t)
                  results = calc_results(all_data, event_types, arg_types, events_roles,
                            p_name, g_name, s_t)
                  save_json(results, f'results-{name}{p_type}_{e_type}_{s_t}.json')
                  results_dict[f'{p_type}_{e_type}_{s_t}']=results


    result_folder_path = 'Argument-Extraction-Results'
    save_json(results_dict, os.path.join(result_folder_path,f'{number}-new-results-{name}.json'))
# Out:
# Streaming output truncated to the last 5000 lines.
# relapse subject-effect-arguments start-time 0.33333333332777776 0.33333333332777776 0.33333333327777775
# 3 days 3 days 1.0 1.0
# one hour 1 hour 0.872048 0.9373786449432373
# few months months 0.84018826 0.8346091508865356
# since first 2mg dose 20 hours 0.5700777 0.1807672083377838
# 1 5 5
# relapse subject-effect-arguments side-effect-duration 0.199999999996 0.199999999996 0.19999999994599998
# hot soaks hot soaks 0.99999994 1.0
# hot soaks distractions 0.59362084 0.08781875669956207
# hot soaks walks 0.43657553 0.07946085184812546
# imodium imodium 1.0 1.0000001192092896
# imodium walks 0.48289353 0.17693763971328735
# distractions distractions 0.9999999 1.0
# walks walks 1.0 1.0000001192092896
# bernese method bernese method 0.9999999 1.0000001192092896
# seeing doctor suboxone 0.57754636 0.15080329775810242
# seeing doctor oxycodone 0.34507257 0.2534951865673065
# seeing doctor diliduan 0.42350814 0.12483415007591248
# tapering benzos suboxone 0.73948014 0.2528429925441742
# tapering benzos oxycodone 0.61454177 0.2598046660423279
# tapering benzos diliduan 0.37527746 0.17208699882030487
# ashton method suboxone 0.6513914 0.09844682365655899
# ashton method oxycodone 0.3779421 0.049360040575265884
# ashton method diliduan 0.39035955 0.09212271124124527
# wait 24 hours wait 24 hours 1.0000001 1.000000238418579
# start with 1mg suboxone start off with 1 mg 0.7264841 0.7187755107879639
# wait 5 days for morphine to work wait 5 days for morphine to work 1.0 1.0
# take 1 mg of subs and assess taking less subs and observing how you feel 0.73603636 0.5167878270149231
# support group help quitting with support group help 0.78422713 0.7726240158081055
# starting subs need more than 2mg of subs 0.62121487 0.48585712909698486
# high dosing thc need more than 2mg of subs 0.56884557 0.29119598865509033
# switching clinics due to missed appointment and alcohol consumption switching clinics 0.5284319 0.7349203824996948
# sub taper regular supply of subs 0.6030479 0.3462325930595398
# gabapentin regular supply of subs 0.41867593 -0.03480628877878189
# xanax regular supply of subs 0.39334264 0.00525769405066967
# muscle relaxers regular supply of subs 0.52024114 0.04813764989376068
# considering continuing suboxone planning to change subs dose 0.7086966 0.46671849489212036
# bernese method bernese method 0.9999999 1.0000001192092896
# suboxone induction quitting cold turkey 0.57896096 0.04205338656902313
# narcan suggested to use narcan 0.72465396 0.796481728553772
# suboxone bernese method 0.60902154 0.11415667831897736
# bernese method bernese method 0.9999999 1.0000001192092896
# took 10mg suboxone more subs 0.5813159 0.19068410992622375
# took 10mg suboxone comfort meds 0.5467729 0.22808937728405
# no relief more subs 0.70760375 0.16077905893325806
# no relief comfort meds 0.59390616 0.27932867407798767
# melatonin take sleep meds 0.6136921 0.46572136878967285
# melatonin ambien 0.48718134 0.41122889518737793
# melatonin benzo 0.59550923 0.321643590927124
# seroquel take sleep meds 0.52792275 0.2404874861240387
# seroquel ambien 0.6153807 0.3988839089870453
# seroquel benzo 0.721472 0.5294622182846069
# trazadone take sleep meds 0.52715224 0.08362098038196564
# trazadone ambien 0.5880398 0.3745473623275757
# trazadone benzo 0.7220043 0.4754028916358948
# zoloft take sleep meds 0.5147469 0.2398744821548462
# zoloft ambien 0.50608253 0.397222101688385
# zoloft benzo 0.5713928 0.39603668451309204
# weed take sleep meds 0.5502763 0.10839378088712692
# weed ambien 0.5207935 0.3316512703895569
# weed benzo 0.81156623 0.45555102825164795
# otc sleep meds take sleep meds 0.81830573 0.6619113683700562
# otc sleep meds ambien 0.5215544 0.4475407898426056
# otc sleep meds benzo 0.5030761 0.16665324568748474
# ambien take sleep meds 0.5594879 0.39291852712631226
# ambien ambien 1.0 1.0
# benzo take sleep meds 0.5987935 0.1261572539806366
# benzo benzo 0.9999999 1.0000001192092896
# use telehealth or local doctors for prescriptions get suboxone from doctors in area 0.64862716 0.47955989837646484
# suboxone take 24mg for first month 0.5320632 0.2031819373369217
# suboxone then 8mg or less 0.5540387 0.3140409588813782
# suboxone alcohol can help but no meth 0.56491053 0.2543223798274994
# valium take 24mg for first month 0.47436917 0.16241802275180817
# valium then 8mg or less 0.5217112 0.28426429629325867
# valium alcohol can help but no meth 0.4932614 0.18756544589996338
# medical supervision take 24mg for first month 0.48090476 -0.042847875505685806
# medical supervision then 8mg or less 0.46499828 0.011021867394447327
# medical supervision alcohol can help but no meth 0.536569 0.07626968622207642
# considering buprenorphine wait 24 hours after last opiate use 0.61133635 0.4479561448097229
# advised to wait 24 hours after last opiate use wait 24 hours after last opiate use 0.91128105 0.9743276834487915
# used kratom to get off subs use kratom 0.6836226 0.6203441023826599
# took 2mg dose moud intake 0.6216197 0.1650998890399933
# plan to switch to methadone planning to use methadone 0.9023744 0.910962700843811
# ordered kratom kratom while on suboxone 0.75805044 0.5358110666275024
# 11 47 36
# relapse subject-effect-arguments intervention 0.2340425531909914 0.30555555555470676 0.2650602409140949
# results-gpt-4obatch_question_guided_0.99.json
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Results/1-new-results-gpt-4o.json
# batch description_guided 0.749
# individual experiencing severe morning anxiety individual altered treatment due to withdrawals 0.756458 0.2932260036468506
# individual reducing medication use individual seeking advice on splitting tablets 0.7565003 0.39854753017425537
# person on suboxone strips individual hating taste of strips asking about snorting 0.7054585 0.36223772168159485
# individual with tooth infection needing extraction individual seeking information on tramadol and suboxone use 0.5966453 0.1101042851805687
# individual with past opioid experience individual wants to start taking suboxone 0.6485219 0.3821284770965576
# currently clean individual wants to start taking suboxone 0.4774387 0.0034832730889320374
# individual switching from methadone to suboxone individual switching from methadone to subs 0.9253169 0.9115846753120422
# individual cutting 2 mg film strips individual asking about cutting strips 0.74142396 0.6584281921386719
# individual with poor memory individual who accidentally double dosed 0.68990135 0.36965733766555786
# friend and poster individual asking for difference between strips and pills 0.54508185 0.05423898622393608
# individual considering alternative administration method individual considering boofing bupe 0.6830379 0.14910832047462463
# individual quitting percs and starting suboxone indivudal who just quit percs fearing suboxone treatment 0.80927163 0.8093626499176025
# young individual taking 90mg addys 0.47676635 -0.024622054770588875
# 155 lbs individual taking 90mg addys 0.5620976 0.10847145318984985
# fast metabolism individual taking 90mg addys 0.5276619 0.20254306495189667
# individual switching from methadone to suboxone individual switching from methadone to suboxone 0.9999999 1.0
# individual taking suboxone individual who got high from suboxone and wants to take more 0.77076674 0.838104784488678
# individual experiencing side effects from naloxone in suboxone individual willing to remove nalaxone from suboxone to avoid withdrawals 0.9172302 0.7288783192634583
# individual struggling with medication dosage individual who always wants to take thier subs 0.5732315 0.18829011917114258
# individual tapering down medication dosage individual tapering medication dosage 0.96060985 0.950525164604187
# individual on subutex experiencing reduced dose duration individuals dose not lasting 0.8209795 0.4050690829753876
# individual taking bupe indivdual wondering if they get full dose of suboxone 0.5533825 0.27189791202545166
# individual on 8 mg suboxone daily for year individual previously on 8mg suboxone daily 0.84488875 0.9166861772537231
# individual prescribed 4mg subs daily person feeling better with lower doses 0.6202606 0.4483620524406433
# individual detoxing from substance use individual who took suboxone after 11 days of quitting 0.78836477 0.4661129117012024
# individual on suboxone and subutex for 3 years individual on suboxone and subutex trying to find better brand 0.7965661 0.7508561611175537
# individual trying to quit fentanyl patient want to take kratom to get off of fent 0.59830886 0.521324872970581
# individual on 8mg day indivdual addicted to treatment seeking advice 0.48010054 0.25576186180114746
# individual breaking from opiates using suboxone person using sub as break from opiates 0.7913823 0.776462197303772
# individual with fentanyl habit individual who started suboxone to quit fentanyl 0.76071274 0.7076629400253296
# individual experiencing irregular sleep patterns indivdual taking film daily and having irregular sleeping issues 0.73252314 0.622320294380188
# individual relapsed on pain meds individual taking 8mg twice daily experiencing anorgasmia 0.7281132 0.3350194990634918
# now on suboxone individual taking 8mg twice daily experiencing anorgasmia 0.4863938 0.2694663405418396
# individual experiencing anxiety indivdual seeking advice on when to take dosage after sublinimal 0.5735201 0.030361559242010117
# individual on suboxone for years individual wondering when to take subs 0.62485975 0.2988143563270569
# individual taking 20mg oxys for 2 years indivdual taking different kinds of opioids looking for information on using suboxone 0.7200052 0.4504106640815735
# individual switching from fentanyl to suboxone individual wondering how long to wait to switch from fentanyl to suboxone 0.8840529 0.8179015517234802
# individual transitioning from street fentanyl to suboxonesubutex individual considering bernese micro induction 0.5989457 0.01312850322574377
# author and their wife individual trying to quit fentanyl by taking subs and sub shots 0.41275635 0.05146825313568115
# individual tapering off drugs using sublocade individual aiming to taper by using sublocade 0.8067366 0.5604449510574341
# individual on heroin detox individual who relapsed on heroin after taking subutex 0.7609677 0.6773508191108704
# individual on suboxone and vyvanse for 4 years individual was on suboxone for 4 years 0.85941064 0.8237736225128174
# 18 44 43
# taking-moud main-arguments subject/patient 0.4090909090899793 0.41860465116181717 0.41379310339733116
# splitting dose 12 hours apart timing dose later 0.8320564 0.4102519154548645
# 4mg daily reduced dosage 0.5131533 0.576230525970459
# 2mg twice daily reduced dosage 0.5557442 0.4547179043292999
# snorting suboxone strips mixed with warm water on subs strips 0.56459194 0.31274646520614624
# smoking sub strip strips 0.71243125 0.5613628625869751
# suboxone and tramadol suboxone for 15 years 0.80523455 0.5666167736053467
# 8mg film of unspecified medication 8mg suboxone 0.7226118 0.5612844228744507
# methadone 30 mg of methadone 0.80504376 0.7230253219604492
# cutting 2 mg film strips to 66 mg cutting 2 mg film into smaller doses066 0.8770746 0.8355286717414856
# 8mg daily dose 16mg every day since october 0.614342 0.7764925956726074
# buprenorphine tablets taking buprenorphine 0.89699763 0.8674102425575256
# pills and strips used strips instead of pills 0.7773319 0.8740984797477722
# buprenorphine 1mg taking bupe 0.5207339 0.498086541891098
# 15 doses left taking bupe 0.63633966 0.280245304107666
# suboxone script starting on friday suboxone prescription 0.5279971 0.6079266667366028
# 90 mg of insta mg addys split out substance 0.54277015 0.0990789607167244
# somas split out substance 0.59699625 0.11095031350851059
# methadone suboxone for three days after methadone for twelve years 0.7143343 0.6396826505661011
# suboxone home induction suboxone for three days after methadone for twelve years 0.7033069 0.45966583490371704
# 8mg of suboxone 8mg suboxone 0.9107016 0.9689099788665771
# suboxone containing naloxone and buprenorphine suboxone 0.6971723 0.6817725300788879
# 8mg daily medication taking 8mg subs daily 0.7037148 0.7279543280601501
# reducing dosage from 16mg to 8mg daily 16mg unnamed medication daily 0.75868106 0.7236713171005249
# subutex 14mg suboxone daily 0.4787009 0.3532755374908447
# previously 6mg or above 14mg suboxone daily 0.55076426 0.49144917726516724
# now 14mg 14mg suboxone daily 0.4936954 0.5959996581077576
# letting pill dissolve in mouth taking oral buprenorphine 0.64304054 0.4370769262313843
# 8 mg suboxone 8 mg sub daily for year 0.75091404 0.6195499897003174
# 2mg subs between gums and lip switching from 4 mg subs to 2 mg 0.6322322 0.4965711832046509
# 05mg of sub strip after 11 days took 05mg of suboxone 0.6474284 0.5832232236862183
# suboxone suboxone and subutex for 3 years and 3 months 0.7084362 0.6554979085922241
# subutex suboxone and subutex for 3 years and 3 months 0.5794887 0.5021260976791382
# various generic bupe brands suboxone and subutex for 3 years and 3 months 0.6434096 0.08867551386356354
# fentanyl take subs after 2436 hours 0.373247 0.04318937286734581
# suboxone take subs after 2436 hours 0.5366366 0.3152124881744385
# considering kratom take subs after 2436 hours 0.65027195 0.0839414969086647
# 8mg daily dose trying to maintain 8 mgs dose daily 0.8017972 0.8480379581451416
# quarter of 8mg bup2mg naloxone sub 8mg bup2mg naloxene sub 0.92950875 0.7776798009872437
# tapentadol 5 100 mg tapentadol day for week 0.6802507 0.6159013509750366
# suboxone reducing dosage to 1mg then 5mg 0.5732195 0.2685561180114746
# kratom reducing dosage to 1mg then 5mg 0.5554937 0.14430594444274902
# lyrica reducing dosage to 1mg then 5mg 0.36632407 0.024919543415308
# 2 8mg films of unspecified medication 8mg films 2x daily 0.691921 0.7619835734367371
# suboxone 8mg suboxone twice daily 0.67958647 0.6649523973464966
# 8mg twice day 8mg suboxone twice daily 0.70176226 0.7652012705802917
# 2mg bar taking 82 suboxone 0.50668776 0.22612960636615753
# 82 suboxone taking 82 suboxone 0.86525357 0.899935245513916
# suboxone taking suboxone 0.8523089 0.8706018924713135
# switching from fentanyl to suboxone switching to suboxone 0.8462912 0.8003681898117065
# bernese method microdosing with suboxone and subutex suboxone and subutex 0.80887926 0.6103082299232483
# 14 8mg subs and 6day weekend detox taking 14 8mg subs 0.73417467 0.7750042676925659
# sublocade shots every month for 34 months monthly shots of sublocade 0.7878923 0.8630322217941284
# 24mg of subutex 24mg subutex 0.88057125 0.9644767642021179
# suboxone and vyvanse for 25 weeks after relapse suboxone 0.56638926 0.4898359179496765
# 21 62 41
# taking-moud main-arguments treatment 0.33870967741880853 0.5121951219499702 0.4077669902425487
# morning anxiety until hour after dose withdrawals in mornings 0.6196185 0.5536742210388184
# friends with no tolerance vomited all night potentially getting sick 0.58169484 0.271199494600296
# possible headache or extra tiredness headache 0.5117027 0.666000247001648
# possible headache or extra tiredness tiredness 0.74520296 0.7159783840179443
# sore stomach from oral bupe potential stomach soreness 0.8024587 0.6530046463012695
# levels were off levels were off 1.0 1.0
# felt great initially feeling impaired 0.7570576 0.29389315843582153
# impaired on third day possible methadone hangover 0.5279116 0.2940487861633301
# no more euphoria after 8mg getting high 0.5508297 0.2883169651031494
# naloxone headaches and other side affects 0.44345972 0.141246497631073
# desire for higher dose addiction 0.60437083 0.4537345767021179
# difficulty managing dosage addiction 0.5416743 0.24623538553714752
# dose lasts 20hrs waking up early with aching legs 0.4584892 0.033912479877471924
# waking up with aching legs waking up early with aching legs 0.95050746 0.9405796527862549
# feels warm and fuzzy feeling warm and fuzzy like kratom 0.7723752 0.7988665103912354
# concern about resetting detox progress worrying about detox 0.7979338 0.75467449426651
# gets sick if suboxone taken too soon mixing kratom and subs may not work 0.60283804 0.24918565154075623
# desire for higher dose cravings 0.7398308 0.3848775327205658
# difficulty managing cravings 0.6652419 0.1296962946653366
# worried about high tolerance probably high tolerance 0.8243742 0.7160516381263733
# struggles with withdrawal addicted to subs 0.68429095 0.24134105443954468
# struggles with withdrawal cant quit 0.55792034 0.564516007900238
# struggles with withdrawal withdrawal 0.5882875 0.8300855159759521
# panic disorder addicted to subs 0.61343765 0.23407334089279175
# panic disorder cant quit 0.60146356 0.22789064049720764
# irregular sleep patterns with 2 films wake up every hour 0.58437 0.348055362701416
# improved sleep with 1 film wake up every hour 0.5699709 0.3636285364627838
# inability to reach orgasm anorgasmia 0.57113284 0.29114508628845215
# frustration anorgasmia 0.44440034 0.1490626186132431
# potential for precipitated withdrawal if not timed correctly withdrawal symptoms 0.5537573 0.49860960245132446
# feeling hopeless pain from shots 0.68380207 0.12366491556167603
# jobs and bills hindering detox pain from shots 0.6470357 0.06444258987903595
# slipped and used heroin withdrawal 0.52431035 0.37490540742874146
# seeking advice on next dose withdrawal 0.5899808 0.32019931077957153
# suboxone and vyvanse cause zombielike state dependency 0.34759423 0.030751284211874008
# suboxone and vyvanse cause zombielike state zombielike state 0.6057097 0.47218847274780273
# suboxone and vyvanse cause zombielike state depression 0.3732242 0.1568681001663208
# suboxone and vyvanse cause zombielike state chronic fatigue 0.39479023 0.2012965977191925
# dependency concerns dependency 0.80442995 0.8527538180351257
# dependency concerns depression 0.8013619 0.16486380994319916
# 10 35 30
# taking-moud main-arguments effects 0.28571428571346935 0.33333333333222226 0.3076923076416568
# 8mg tablets subs 0.50333 0.11483585834503174
# subs suboxone strips subs strips 0.7907496 0.7362526655197144
# sub strip strips 0.8239224 0.6805564165115356
# suboxone suboxone 1.0 1.0
# opioids suboxone 0.60296845 0.4491247832775116
# methadone methadone 0.99999994 1.0000001192092896
# suboxone subs 0.6372401 0.35214412212371826
# kratom subs 0.64132977 0.1125117763876915
# buprenorphine buprenorphine 1.0 1.0
# strips and pills pillsstrips 0.7163038 0.6056178212165833
# bupe bupe 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# insta mg addys naloxone 0.61595535 0.1815844178199768
# somas naloxone 0.40551126 0.16784532368183136
# methadone suboxone 0.65222186 0.5160515308380127
# suboxone suboxone 1.0 1.0
# suboxone subxone 0.7989681 0.6358637809753418
# suboxone suboxone 1.0 1.0
# unspecified subs 0.68605614 0.13735194504261017
# subutex suboxone 0.6977222 0.5441408753395081
# bupe buprenorphine 0.5045616 0.46576303243637085
# suboxone sub 0.6590155 0.37370967864990234
# fentanyl sub 0.39865744 0.10299507528543472
# percs sub 0.7056707 0.25468647480010986
# sub strip suboxone 0.6527379 0.3806406855583191
# suboxone subs 0.6372401 0.35214412212371826
# suboxone subutex 0.6977222 0.5441408753395081
# subutex subs 0.6642213 0.46839064359664917
# subutex subutex 1.0 0.9999999403953552
# bupe with and without naloxone subs 0.3672733 0.0416281521320343
# fentanyl suboxone 0.6496843 0.4136883616447449
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# tapentadol tapentadol 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# suboxone lyrica 0.59350383 0.16887173056602478
# kratom kratom 1.0 1.0
# lyrica lyrica 0.9999999 1.0
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# subutex subutex 1.0 0.9999999403953552
# fentanyl suboxone 0.6496843 0.4136883616447449
# fentanyl sub shots 0.41706717 0.1306094229221344
# subs suboxone 0.6372401 0.35214412212371826
# subs sub shots 0.71003705 0.6661813855171204
# sublocade sublocade 1.0000001 1.0000001192092896
# subutex subutex 1.0 0.9999999403953552
# subutex diamorphine 0.6222972 0.30106088519096375
# suboxone suboxone 1.0 1.0
# 27 56 43
# taking-moud event-specific-arguments medications 0.4821428571419962 0.6279069767427258 0.5454545454043056
# 4mg 2mg twice daily 4mg 0.6582561 0.7057464122772217
# 8mg film 8mg 0.7070693 0.7368299961090088
# 30 mg methadone 30 mg methadone to 2 times sub 0.8441977 0.8846293687820435
# 066 mg selfcut from 2 mg strip 066 0.62972945 0.24639840424060822
# 8mg 16mg 0.9197054 0.884972095489502
# 1mg 1mg 0.9999999 1.0000001192092896
# methadone 7mg 1 mg on monday 0.54180276 0.505648672580719
# methadone 7mg 050 mg on tuesday and wednesday 0.5321252 0.3718450963497162
# suboxone 1mg 1 mg on monday 0.6242591 0.49748849868774414
# suboxone 1mg 050 mg on tuesday and wednesday 0.53589576 0.41048821806907654
# 050mg 1 mg on monday 0.5316282 0.5292379260063171
# 050mg 050 mg on tuesday and wednesday 0.51686794 0.7667455673217773
# 025mg 1 mg on monday 0.57817876 0.5333375334739685
# 8mg 8mg 1.0000001 1.0000001192092896
# 8mg day 8mg 0.670252 0.8178383708000183
# 16mg tapering to 8mg 16mg day 0.6375032 0.7145423293113708
# 16mg tapering to 8mg tapering to 8mg 0.924966 0.9487036466598511
# 14mg 14mg 1.0 1.0
# 8 mg suboxone 8 mg 0.7552063 0.7055898904800415
# 2mg 2 mg 0.775154 0.924899697303772
# 05mg 05mg 1.0 1.0000001192092896
# 8mg 8mg 1.0000001 1.0000001192092896
# 2mg naloxone 8mg bup2mg naloxene sub 0.76234674 0.6333893537521362
# 8mg buprenorphine five 100mg tapentadol 0.7532113 0.49131011962890625
# 16mg 4mg to 2mg 0.6773108 0.7483353018760681
# tapered to 4mg2mg 4mg to 2mg 0.83135414 0.8180712461471558
# 16mg 8mg 0.9197054 0.884972095489502
# 8mg twice day 16mg 0.6245318 0.6177785992622375
# 82 82 1.0000001 1.0000001192092896
# half gram each day 8mg 0.5060951 0.3806265592575073
# 8mg subs 8mg 0.7254593 0.7709270715713501
# 24mg 24mg 1.0 1.0
# 19 36 26
# taking-moud event-specific-arguments dosage 0.5277777777763117 0.7307692307664202 0.6129032257557753
# 15 years of suboxone 15 years 0.6759801 0.4796617329120636
# 6 months on suboxone 6 months 0.6932487 0.5372717976570129
# since october since october 1.0 0.9999998807907104
# methadone 12 years 3 days 0.5393196 0.3046717345714569
# suboxone for year one year 0.54127675 0.2812344431877136
# fentanyl for 3 days one year 0.515389 0.08451899886131287
# 11 days 11 days 0.9999999 1.0
# 3 years and 3 months 3 years and 3 months 1.0 1.000000238418579
# week on tapentadol week 0.61074996 0.6189277172088623
# about year about year 0.99999994 1.0
# several months last several months 0.81528795 0.747855544090271
# 4 days 4 days 1.0 1.0
# 4 years 4 years 1.0 1.0
# 7 14 12
# taking-moud event-specific-arguments treatment-duration 0.4999999999964286 0.5833333333284723 0.5384615384076923
# snorting sublingual 0.56614715 0.22496460378170013
# orally ublingually 0.4481609 0.3885100185871124
# sublingually ublingually 0.6110104 0.5239776372909546
# buccal ublingually 0.40869236 0.2609722912311554
# orally orally 1.0000001 1.0000001192092896
# orally dissolve in water and use syringe 0.474258 0.22746142745018005
# considering rectal dissolve in water and use syringe 0.46082556 0.1291373372077942
# sublingually oralsublingual 0.69377863 0.5491251349449158
# sublingually orally 0.5655492 0.4410631060600281
# between gums and lip between gumslipsplugged 0.5926855 0.6308022737503052
# plugged between gumslipsplugged 0.54462254 0.18662717938423157
# orally orally 1.0000001 1.0000001192092896
# orally orally 1.0000001 1.0000001192092896
# orally orally 1.0000001 1.0000001192092896
# orally orally 1.0000001 1.0000001192092896
# orally orally 1.0000001 1.0000001192092896
# injections injections 1.0 1.0
# orally orally 1.0000001 1.0000001192092896
# 8 24 21
# taking-moud event-specific-arguments manner 0.3333333333319445 0.38095238095056694 0.35555555550419754
# splitting dose 12 hrs apart 2024hr 0.5440899 0.1798941045999527
# splitting dose 12 hrs apart sometimes 12hr 0.6412381 0.381997287273407
# twice daily per day 0.6378631 0.6076984405517578
# 2 times day for suboxone per day 0.47417486 0.3796159029006958
# everyday per day 0.6610172 0.5975142121315002
# daily dailyl 0.78056276 0.8439570665359497
# day daily 0.7962242 0.7196713089942932
# daily for suboxone daily 0.47493416 0.4577665328979492
# over 3 days for fentanyl daily 0.42712754 0.1339290738105774
# daily per day 0.7259106 0.6831240653991699
# daily daily 1.0000001 1.0
# five times day for tapentadol sub twice day 0.7278382 0.32789748907089233
# five times day for tapentadol tap 5 times day 0.7427642 0.578471839427948
# daily daily 1.0000001 1.0
# daily twice daily 0.7982776 0.6609534025192261
# twice day twice daily 0.79796565 0.8787471055984497
# oxys daily daily 0.6519659 0.5203788876533508
# hydromorphone and percocet on nonoxy days daily 0.32629788 0.19183224439620972
# monthly monthly 1.0 1.000000238418579
# 7 22 22
# taking-moud event-specific-arguments frequency 0.31818181818037194 0.31818181818037194 0.31818181813037194
# morning at 530am morning 0.62143195 0.7730607986450195
# around 1011 am morning 0.5510551 0.3950033187866211
# 1 3 3
# taking-moud event-specific-arguments timing 0.3333333333222222 0.3333333333222222 0.3333333332722222
# manage withdrawal symptoms avoiding withdrawals 0.6324204 0.7310316562652588
# reduce clinic visits helping cravings 0.6741067 0.07484285533428192
# manage cravings helping cravings 0.8579752 0.8817541599273682
# quit percs to quit percs 0.9376684 0.9334163069725037
# euphoria withdrawl symptoms 0.48756167 0.08445000648498535
# unspecified to manage addiction 0.5995361 0.1029110848903656
# detox detox 1.0000001 0.9999998807907104
# to get off fentanyl get off of fent 0.6640847 0.5785146951675415
# breaking from opiates to break from opiates 0.9195859 0.8977413773536682
# stay off fentanyl to quit fentanyl 0.8684599 0.8620558381080627
# manage wd manage withdrawal symptoms 0.5429974 0.17918093502521515
# anxiety help withdrawl symptoms 0.6016385 0.25883176922798157
# manage withdrawal from oxys to manage withdrawal symptoms 0.6794718 0.6462711095809937
# switching from fentanyl to suboxone to quit fentanyl 0.811955 0.6057815551757812
# get off street fentanyl getting off street fent 0.794674 0.7040325403213501
# quitting fentanyl to quit fentanyl 0.92959505 0.9094991087913513
# taper off completely to taper off completely 0.8000242 0.9207198619842529
# heroin detox to quit heroin 0.67933553 0.686715304851532
# combat depression and cfs fight relapse 0.4902253 0.405520498752594
# 9 24 23
# taking-moud event-specific-arguments purpose 0.3749999999984375 0.39130434782438567 0.3829787233526483
# 0 1 1
# taking-moud subject-effect-arguments gender 0.0 0.0 0.0
# tooth infection tooth extraction 0.79748327 0.5939548015594482
# percocet withdrawal percocet addiction 0.6630217 0.7266290187835693
# addiction spinal fusion 0.6234046 0.050034284591674805
# addiction denied pain management 0.6095259 0.21591508388519287
# postspinal fusion pain spinal fusion 0.69412893 0.5780994892120361
# postspinal fusion pain denied pain management 0.6678977 0.47382527589797974
# opiate use opiate addiction 0.8085058 0.8521778583526611
# relapsed on pain meds relapsed on pain meds 0.99999994 1.0000001192092896
# opioid dependence opioid dependence 0.9999999 1.0000001192092896
# heroin addiction heroin addiction 1.0000001 1.0000001192092896
# depression depression 1.0 1.0
# chronic fatigue syndrome chronic fatigue syndrome 1.0 0.9999999403953552
# 7 12 11
# taking-moud subject-effect-arguments conditions 0.5833333333284723 0.6363636363578512 0.6086956521187145
# butterflies withdrawals 0.7078919 0.22499287128448486
# anxiety withdrawals 0.7142197 0.34046870470046997
# nausea potentially getting sick 0.6112255 0.5923236012458801
# vomiting potentially getting sick 0.6374553 0.5675185918807983
# more side effects from suboxone brink of relapse 0.52629906 0.09193873405456543
# headache or extra tired headache 0.6594987 0.7208731174468994
# headache or extra tired tiredness 0.71288204 0.7001703977584839
# sore stomach sore stomach 1.0000001 1.0
# potential precipitated withdrawals illness from precipated withdrawls 0.7374924 0.8127599954605103
# impaired feeling feeling impaired 0.87273026 0.949336051940918
# headaches and other side effects headaches 0.7240221 0.7140218019485474
# aching legs waking up early with aching legs 0.7142076 0.6700297594070435
# discomfort waking up early with aching legs 0.40094188 0.27506664395332336
# sickness after 8 hours bluezz 0.5785785 0.14884310960769653
# sickness after 8 hours sick 0.63302356 0.41128385066986084
# irregular sleep patterns sleeping difficulty 0.7557668 0.6548538208007812
# inability to reach orgasm anorgasmia 0.57113284 0.29114508628845215
# anxiety anxiety 0.9999999 1.000000238418579
# feeling like zombie physical withdrawal symptoms 0.586502 0.305852472782135
# lack of enjoyment physical withdrawal symptoms 0.6923773 0.22933219373226166
# 5 29 27
# taking-moud subject-effect-arguments side-effects 0.17241379310285376 0.18518518518449933 0.1785714285208546
# severe worst 0.83378404 0.36650174856185913
# beyond frustrating medium 0.73642296 0.18486347794532776
# 1 13 13
# taking-moud subject-effect-arguments severity 0.0769230769224852 0.0769230769224852 0.0769230768724852
# every morning in morning 0.8219979 0.7553573846817017
# wednesday wednesday 1.0000001 1.0
# past year 1 year ago 0.6773194 0.7446972131729126
# 2 6 6
# taking-moud subject-effect-arguments start-time 0.33333333332777776 0.33333333332777776 0.33333333327777775
# past year 1 year 0.6409646 0.5226761698722839
# 0 3 3
# taking-moud subject-effect-arguments side-effect-duration 0.0 0.0 0.0
# splitting dose splitting dosage and changing frequency 0.67345303 0.7002115845680237
# timing dose later splitting dosage and changing frequency 0.771561 0.35685643553733826
# used kratom for week methadone 0.42291334 0.23774342238903046
# used strips instead of pills proper use of strip 0.6898938 0.5707630515098572
# dissolve in water dissolve it in water and syringe it 0.6618236 0.607402503490448
# use syringe dissolve it in water and syringe it 0.8120824 0.7170507907867432
# suboxone script starting with low dosage of suboxone 0.5335071 0.6022379994392395
# low dosage starting with low dosage of suboxone 0.75503194 0.6860544681549072
# spit to avoid naloxone absorption spit instead of swallow 0.6236039 0.6485116481781006
# soak in mouth avoid swallowing sub 0.62467325 0.409424364566803
# soak in mouth rinse with water 0.69699293 0.4188059866428375
# spit avoid swallowing sub 0.6855276 0.42875200510025024
# spit rinse with water 0.576218 0.24649107456207275
# rinse with water avoid swallowing sub 0.66263777 0.20432747900485992
# rinse with water rinse with water 1.0 1.0000001192092896
# maintain daily dose ignore addict brain 0.6284719 0.21599209308624268
# ignore addict brain ignore addict brain 1.0 1.0
# tapering down dose gradually micro cuts and stay stable 0.6892873 0.3129737973213196
# spitting instead of swallowing spitting out after dissolving in mouth 0.65774304 0.7056077718734741
# wait 24 hours switching back to suboxone 0.55662394 0.1411660611629486
# start with 1mg switching back to suboxone 0.5781634 0.2387056052684784
# suboxone treatment suboxone treatment 0.9999999 1.0
# previously tried subutex detox aa 0.41011348 -0.00032156333327293396
# considering kratom to manage withdrawal take kratom to wait 2436 hours before subs 0.75964546 0.5009734630584717
# using suboxone to break from opiates suboxone 0.69684464 0.7366102933883667
# kratom and lyrica for withdrawal drop to 1mg for month then 5mg for month then jump 0.50585365 0.37143945693969727
# reduced dosage to 1 film taking less prescription 0.58525246 0.33661118149757385
# hoping body adjusts try cutting dose suggested to cut dose 0.56968594 0.58660489320755
# consult doctor for nonaddictive treatments taking 2mg bar 0.3967693 0.13716493546962738
# take suboxone around 1011 am take subs around 1011am 0.7570637 0.562116801738739
# using cows scale to determine withdrawal stage suggested to use cows scale 0.6683567 0.6821502447128296
# wait at least 48 hours wait 48 hours 0.80297405 0.9047876000404358
# using suboxone or subutex for bernese method stay on suboxone 0.7296292 0.544684112071991
# wait 36 hours before next dose wait 36 hours 0.7852194 0.6660666465759277
# 10 31 26
# taking-moud subject-effect-arguments intervention 0.32258064516024976 0.3846153846139054 0.3508771929316098
# individual on 32mg daily dose individual going down daily dose of 32mg 0.89813745 0.8600322008132935
# individual tapering off suboxone individual trying to taper off sub usage 0.6969567 0.47189298272132874
# individual tapering from 05mg to 025mg individual expecting discomfort for tapering 0.66330016 0.4040900468826294
# friend of poster individual who snorted suboxone with naloxone to quit 0.42077565 0.20627745985984802
# individual and his girlfriend individual and their girlfriend suffering from anxiety after tapering 0.7316031 0.27774250507354736
# individual on subs for 56 years individual needs help tapering 0.5772956 0.13846707344055176
# individual tapering off suboxone indivdual wanting to taper from suboxone 0.8153797 0.8502393364906311
# 40 years old 40yearold who quit subutex for 20 years 0.5594724 0.38015586137771606
# in really good shape 40yearold who quit subutex for 20 years 0.4328511 0.12061061710119247
# individual who stopped taking suboxone and opioids individual just quit suboxone 0.67823064 0.7247337102890015
# individual on 1020 mg of oxys daily for 5 years individual wanting to do rapid taper to quit oxy 0.7107467 0.5216033458709717
# individual considering treatment for opioid addiction indivdual seeking infromation on when they can quit suboxone 0.73400337 0.31543684005737305
# individual on 24 mg of subs daily patient going cold turkey 0.56893235 0.16981062293052673
# individual tapering off medication patient quitting opioid 0.6818249 0.35376685857772827
# individual tapering off subutex individual tapering off subutex and struggling from side effects 0.71079135 0.7841033339500427
# individual tapering off suboxone individual tapering off suboxone experiencing side effects 0.8124594 0.8173181414604187
# individual with 7year suboxone habit individual using kratom to taper suboxone 0.80134296 0.45329123735427856
# individual tapering off sub and other opiates individual looking for advice to taper subs and opiates 0.78780794 0.7865616083145142
# brother on methadone individual suggesting vitadone for those going through withdrawals or quitting 0.61314255 0.18498092889785767
# poster on sublocade individual suggesting vitadone for those going through withdrawals or quitting 0.5025813 0.014661811292171478
# individual taking subs for dirty 30 withdrawals individual tapering on subs 0.59982145 0.3084362745285034
# single mom single mom 1.0 1.0
# fulltime worker who works full time 0.72106063 0.8524551391601562
# individual hooked on fake roxies individual tapering off suboxone after relapse 0.56639916 0.13012179732322693
# clean for four years individual tapering off suboxone after relapse 0.42544326 0.13961975276470184
# individual tapering off suboxone individual tapering suboxone and feeling well 0.7911377 0.8162401914596558
# individual tired of being on subs for 3 years individual on suboxone for 2 years plans to quit 0.7729399 0.3970798850059509
# 10 29 25
# tapering main-arguments subject/patient 0.3448275862057075 0.3999999999984 0.370370370319273
# rls on 3rd night restless leg syndrome 0.47214663 0.1816103160381317
# sneezing fits sneezing fits 0.99999994 1.0
# expecting some discomfort discomfort expected 0.80063975 0.8476206064224243
# quitting after month able to quit suboxone 0.642773 0.42374956607818604
# no withdrawal able to quit suboxone 0.48127452 0.4190690517425537
# potential sinus issues able to quit suboxone 0.55807394 0.1200033500790596
# increased anxiety insomnia and anxiety 0.81108487 0.629741907119751
# runny nose runny nose 1.0 0.9999999403953552
# withdrawal starts on third day sick 0.45604485 0.03875751793384552
# withdrawal starts on third day little nose running 0.45975167 0.012453127652406693
# withdrawal starts on third day little colder 0.49307913 0.029689883813261986
# runny nose sick 0.6075543 0.37302088737487793
# runny nose little nose running 0.7636706 0.6934186220169067
# feeling colder sick 0.8100213 0.36309629678726196
# sneezing sneezing 1.0 1.0
# sneezing insomnia 0.6283476 0.3201625943183899
# yawning yawning 1.0000001 0.9999999403953552
# insomnia insomnia 1.0 1.0
# headache and neck pain after dosing headache and neck pain 0.82159 0.8058207035064697
# stomachbladder pain after 1220 hours from last dose stomachbladder pain 0.73779017 0.7137284278869629
# relief from withdrawal symptoms awakeness 0.6667207 0.20728269219398499
# relief from withdrawal symptoms restless legs 0.6587069 0.2650645971298218
# relief from withdrawal symptoms discomfort 0.5640913 0.2752014994621277
# improved sleep awakeness 0.73350066 0.543204665184021
# improved sleep restless legs 0.70835936 0.3715824782848358
# improved sleep discomfort 0.64256936 0.15411627292633057
# concerns about potential withdrawal symptoms possible withdrawal 0.6766515 0.6965858340263367
# anxiety loss of anxiety 0.7574646 0.7712886333465576
# brain fog less brain fog 0.8458333 0.8699550628662109
# 12 26 20
# tapering main-arguments effects 0.46153846153668643 0.599999999997 0.521739130383365
# considering cutting by 4mg daily going down from 32mg 0.6989391 0.5498250722885132
# considering cutting by 4mg daily wants to cut by 4mg day 0.8405895 0.8803473114967346
# 2mg every 3 days reducing subs dosage from 2mg every 3 days to 05mg daily 0.6606837 0.6822448968887329
# tried 1mg every 2 days reducing subs dosage from 2mg every 3 days to 05mg daily 0.7622791 0.5310482978820801
# drop from 05mg to 025mg drop from 05 mg to 025 mg 0.88707066 0.9511096477508545
# snorting 14 of 82mg suboxone twice daily snorting suboxone to quit 0.83961076 0.7354209423065186
# quitting suboxone quit suboxone 0.92424107 0.978075385093689
# lowest dose daily starting with 6mg 0.5990468 0.5259404182434082
# 2 pills left starting with 6mg 0.58821636 0.42813360691070557
# started at 24 mg went from 24mg suboxone to 3mg 0.4676716 0.6601473093032837
# now at 3 mg went from 24mg suboxone to 3mg 0.7889754 0.5933607816696167
# subutex for 20 years 7 months clean 0.6505288 0.28770023584365845
# now quit 7 months clean 0.5759131 0.220701664686203
# stopped 12 mg suboxone since thursday from 12mg to 0mg 0.629296 0.4323827028274536
# last opioid on friday from 12mg to 0mg 0.4317041 0.21912531554698944
# considering ct or rapid sub taper planning either rapid sub taper or just quitting 0.7222559 0.6305068135261536
# doctors recommend tapering slowly over year or two looking for tapering schedule 0.6112861 0.43445467948913574
# cold turkey stop from 24 mg cold turkey from 24 mg daily 0.72754824 0.8603368401527405
# current dosage at 125 attempting 0125 mg to 0 mg 0.6770051 0.3809535801410675
# trying to stop completely attempting 0125 mg to 0 mg 0.52751374 0.2564375102519989
# subutex tapering off subutex on 1 mgday 0.5504501 0.5505602955818176
# 1mg daily tapering off subutex on 1 mgday 0.47797483 0.5292086601257324
# started 5 days ago tapering off subutex on 1 mgday 0.5706494 0.11813956499099731
# suboxone tapering from 5 to 25 over 4 days from 5mg suboxone to 30mg 0.8162659 0.5832474231719971
# used kratom for 56 weeks to quit suboxone used kratom to quit suboxone 0.9298409 0.9495456218719482
# starting taper off sub taking subs and wants to quit 0.6831178 0.520115852355957
# using low dose opiatesbenzos for severe symptoms taking subs and wants to quit 0.47926298 0.1638932228088379
# started at 6mgday 6 mg day to 34 mg in 4 days 0.55176455 0.611894428730011
# reduced to 34 mg in 4 days 6 mg day to 34 mg in 4 days 0.8616739 0.8499488830566406
# started suboxone strips attempting to taper suboxone for 4 months 0.6768634 0.6898393630981445
# goal to be off within month attempting to taper suboxone for 4 months 0.56250453 0.16289274394512177
# down to 2mg day or less going down to 2mg suboxone 0.7642104 0.6188060641288757
# taking 24mgday for 2 years looking to use 90 8mgs to taper off 0.67284924 0.3945866823196411
# plans to taper with 90 8mg looking to use 90 8mgs to taper off 0.8274847 0.8834786415100098
# 12 35 25
# tapering main-arguments tapering-event 0.34285714285616326 0.47999999999808 0.39999999995005553
# on subs daily for 5 to 6 years taking 6mg of subs 0.6392057 0.47389185428619385
# on subutex for 20 years on suboxone for last 20 years 0.80192155 0.6669870018959045
# feeling fine subject was taking 12 mg of suboxone and opioids 0.37798142 0.17115625739097595
# runny nose subject was taking 12 mg of suboxone and opioids 0.3912909 0.14892388880252838
# 810 functioning subject was taking 12 mg of suboxone and opioids 0.37774602 0.09949143975973129
# 5 years of 1020 mg of oxys daily taking 1020mg of oxy daily for 5 years 0.8868379 0.8999642133712769
# dirty 30 withdrawals taking subs for dirty 30 withdrawals for 4 days 0.7252771 0.7228090763092041
# single mom single mother who is working full time 0.577055 0.7752017974853516
# declining health issues took fake roxies after being off opiates for 4 years 0.48693687 0.14156493544578552
# hooked on fake roxies took fake roxies after being off opiates for 4 years 0.7154262 0.6733118295669556
# brain fog felt ill 0.7176233 0.2979666590690613
# anxiety felt ill 0.7437947 0.40579360723495483
# existential changes felt ill 0.55969095 0.19189101457595825
# tired of being on subs been on subs for 3 years 0.73591185 0.7079406976699829
# 3 17 10
# tapering event-specific-arguments condition 0.17647058823425607 0.299999999997 0.2222222221739369
# desire to get clean and minimize withdrawals wanting to quit oxy 0.58042973 0.524300754070282
# appointment for opioid addiction treatment just beginning suboxone 0.56514263 0.22819401323795319
# desire to quit suboxone suboxone taper 0.67057407 0.49543648958206177
# desire to get off sub and opiates desire to quit opiates 0.84083873 0.8499115109443665
# accidentally got hooked on fake roxies wanting to stay off medication after relapse 0.6581858 0.16037002205848694
# almost 3 years since last use tired of being on subs 0.6294853 0.13450869917869568
# 1 7 7
# tapering event-specific-arguments trigger 0.14285714285510204 0.14285714285510204 0.14285714280510203
# thursday thursday 1.0000001 1.0000001192092896
# not specified trying tapering to 25 for 4 days 0.470424 0.06006079912185669
# not specified 90 days ago 0.583481 0.22432969510555267
# 4 days ago 4 days ago 1.0 0.9999999403953552
# four months ago 4 months ago 0.87474024 0.9858983159065247
# 3 7 7
# tapering event-specific-arguments start-time 0.4285714285653061 0.4285714285653061 0.4285714285153061
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# prescribed tapering selftaper 0.6050787 0.10614556819200516
# cold turkey selftapering 0.56016 0.1841450035572052
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering self tapering 0.7003454 0.5649640560150146
# selftapering orallysublingually 0.6854205 0.34981197118759155
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# 12 23 23
# tapering event-specific-arguments type 0.5217391304325142 0.5217391304325142 0.5217391303825142
# suboxone subs suboxone 0.8490589 0.8830626010894775
# suboxone with naloxone suboxone with naloxone 0.99999994 1.0
# subs suboxone 0.6372401 0.35214412212371826
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# considering subs suboxone 0.6710433 0.28657951951026917
# subs subs 1.0000001 1.0000001192092896
# subutex subutex 1.0 0.9999999403953552
# suboxone suboxone 1.0 1.0
# kratom kratom 1.0 1.0
# short acting opiates 0.5749772 0.16647794842720032
# short acting benzos 0.60384595 0.13525059819221497
# short acting klonopin 0.45828867 0.07597152888774872
# short acting tramadol 0.62126434 0.15805673599243164
# low dose opiatebenzos opiates 0.72128433 0.6063441038131714
# low dose opiatebenzos benzos 0.6394495 0.3424534797668457
# low dose opiatebenzos klonopin 0.61255485 0.2618115544319153
# low dose opiatebenzos tramadol 0.47220933 0.35578322410583496
# subs kratomif required 0.523713 0.03508678451180458
# subs subs 1.0000001 1.0000001192092896
# kratom kratomif required 0.7104471 0.6404950618743896
# suboxone strips suboxone 0.9251065 0.7823392152786255
# suboxone suboxone 1.0 1.0
# subs suboxone 0.6372401 0.35214412212371826
# 11 19 22
# tapering event-specific-arguments taper-medications 0.5789473684180056 0.4999999999977273 0.5365853658013088
# 32mg 32mg 1.0 1.000000238418579
# 07mg and 14mg alternating days 05 mg 0.54975456 0.5677751302719116
# 82mg suboxone 82mg 0.5762192 0.7108813524246216
# less than qt 6mg 0.48948017 0.18883009254932404
# 24 mg 24mg 0.69979584 0.9446220397949219
# 12 mg 12mg 0.7176265 0.9395279884338379
# 24 mg 24 mg 1.0 1.0
# not specified 5 0.654174 0.31135204434394836
# 6mg subs 6 mg 0.6340047 0.70354163646698
# 24mg day 24mg 0.62442833 0.8364930152893066
# 5 10 10
# tapering event-specific-arguments initial-dosage 0.499999999995 0.499999999995 0.499999999945
# 2mg every 3 days 2mg every 3 days 1.0 1.0000001192092896
# 025mg 025 mg 0.8418047 0.9452039003372192
# 14 in morning and evening 0mg 0.424416 0.126189723610878
# 3 mg 3mg 0.79855776 0.9231275320053101
# 0 mg 0mg 0.77785414 0.8933465480804443
# 0125 or so 0125 mg 0.7089184 0.6484886407852173
# 1mg daily 1 mg 0.71297705 0.7789731025695801
# 025 to 035 2530 0.7261024 0.45595622062683105
# not specified 0 0.67997205 0.270704984664917
# 34 mg subs 34 mg 0.7763587 0.7803698778152466
# 2mg or less 2mgday 0.5625923 0.6834417581558228
# 24mg day 24mg 0.62442833 0.8364930152893066
# 7 15 15
# tapering event-specific-arguments current-dosage 0.46666666666355555 0.46666666666355555 0.46666666661355555
# 05mg day 05mg day 0.99999994 1.0
# as low as possible before stopping 0mg 0.3576171 0.26865917444229126
# not specified 0 mg 0.6092585 0.29779237508773804
# 025 25 0.7498439 0.36804813146591187
# quit suboxone and kratom 0 0.3989196 0.01022452674806118
# completely off sub and opiates quit all opiates 0.67019904 0.7500295639038086
# not specified 0 mg 0.6092585 0.29779237508773804
# off suboxone within month 0mg 0.47988415 0.17534145712852478
# 3 21 21
# tapering event-specific-arguments goal-dosage 0.1428571428564626 0.1428571428564626 0.14285714280646258
# two weeks to stabilize two weeks 0.8297093 0.6660865545272827
# one month 1 month 0.85923046 0.9508345127105713
# 56 weeks for kratom 56 weeks 0.6862372 0.6267278790473938
# first couple weeks within few weeks 0.7970005 0.6057178974151611
# 3 5 5
# tapering event-specific-arguments target-duration 0.599999999988 0.599999999988 0.599999999938
# 40 years old 40 0.6004745 0.7096229195594788
# 0 1 1
# tapering subject-effect-arguments age 0.0 0.0 0.0
# 0 2 2
# tapering subject-effect-arguments gender 0.0 0.0 0.0
# anxiety after quitting suboxone recovering from suboxone kratom 0.77094585 0.5358579754829407
# been on subutex for 20 years subutex dependence 0.5429935 0.5547785758972168
# 5 years of 1020 mg oxys daily oxys addiction 0.5068802 0.585854172706604
# 7 year suboxone habit 7 year suboxone habit 1.0 1.0000001192092896
# opiate dependence opiate addiction 0.79603213 0.8304844498634338
# declining health issues declining health issues 0.9999999 1.0
# 4 7 7
# tapering subject-effect-arguments conditions 0.5714285714204081 0.5714285714204081 0.5714285713704081
# sneezing fits sneezing fits 0.99999994 1.0
# gummy junk in sinuses feeling ill 0.52842915 0.12432816624641418
# increased anxiety physical dependency to kratom 0.5010794 0.11994966119527817
# increased anxiety ruined liver 0.6150944 0.10033521056175232
# insomnia physical dependency to kratom 0.38628227 0.11516478657722473
# insomnia ruined liver 0.44794568 0.1440296173095703
# expected withdrawal symptoms detox 0.6390791 0.2516285181045532
# runny nose runny nose 1.0 0.9999999403953552
# nose running sick 0.70986927 0.2573973536491394
# nose running nose running 1.0 1.0000001192092896
# feeling colder sick 0.8100213 0.36309629678726196
# sneezing sneezing 1.0 1.0
# sneezing insomnia 0.6283476 0.3201625943183899
# yawning yawning 1.0000001 0.9999999403953552
# insomnia insomnia 1.0 1.0
# headache and neck pain headache and neck pain 0.99999994 1.0
# stomachbladder pain stomachbladder pains 0.95150214 0.9770182967185974
# physical withdrawal physical withdrawals 0.89083487 0.9802550673484802
# restless legs insomnia 0.5620499 0.3650832772254944
# restless legs restless legs 1.0 1.0000001192092896
# sleeplessness insomnia 0.6568797 0.6756699085235596
# sleeplessness discomfort 0.7030364 0.3450937867164612
# ...
# 0 13 13
# relapse event-specific-arguments trigger 0.0 0.0 0.0
# methadone and clonazepam suboxone 0.45848858 0.3817923069000244
# 8 mg suboxone sub 0.49955484 0.25438541173934937
# bupe patches bupe patch 0.94221675 0.9494718313217163
# suboxone suboxone 1.0 1.0
# suboxone subs 0.6372401 0.35214412212371826
# thc subs 0.6120343 0.2553676962852478
# suboxone suboxone 1.0 1.0
# gabapentin subs 0.40028292 0.01751042529940605
# gabapentin gabapentin 1.0 1.000000238418579
# gabapentin muscle relaxers 0.6194408 0.3376624584197998
# xanax subs 0.41115862 0.18329769372940063
# xanax xanax 1.0000001 0.9999999403953552
# muscle relaxers subs 0.4536728 0.08415370434522629
# muscle relaxers muscle relaxers 0.99999994 1.0000001192092896
# suboxone subs suboxone 0.8490589 0.8830626010894775
# suboxone 812mg suboxone 0.82027054 0.8272020816802979
# not specified subs 0.62804216 0.17477627098560333
# suboxone suboxone 1.0 1.0
# 20mg subs daily for 6 months subs 0.57434475 0.34437862038612366
# suboxone subs 0.6372401 0.35214412212371826
# suboxone suboxone 1.0 1.0
# suboxone sub subs 0.66229314 0.5203598737716675
# suboxone suboxone 1.0 1.0
# suboxone ambien 0.55143833 0.34220874309539795
# suboxone benzos 0.80525124 0.35993492603302
# melatonin sleep meds 0.66349703 0.5298508405685425
# melatonin ambien 0.48718134 0.41122889518737793
# melatonin benzos 0.66165876 0.34236329793930054
# seroquel sleep meds 0.5072389 0.4387243688106537
# seroquel ambien 0.6153807 0.3988839089870453
# seroquel benzos 0.62147266 0.5341174006462097
# trazadone sleep meds 0.50972646 0.26407840847969055
# trazadone ambien 0.5880398 0.3745473623275757
# trazadone benzos 0.6399053 0.4405853748321533
# zoloft sleep meds 0.48349583 0.4093518555164337
# zoloft ambien 0.50608253 0.397222101688385
# zoloft benzos 0.50769734 0.3898359537124634
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# kratom buprenorphine 0.5088206 0.3298738896846771
# subs suboxone 0.6372401 0.35214412212371826
# suboxone suboxone 1.0 1.0
# subutex subutex 1.0 0.9999999403953552
# pregabalin buprenophine 0.5730175 0.3878892660140991
# buprenophine buprenophine 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# 14 38 36
# relapse event-specific-arguments existing/current-medications 0.3684210526306094 0.38888888888780865 0.37837837832739224
# xanax kratom 0.44039977 0.24177370965480804
# xanax oxy 0.46933532 0.24391794204711914
# xanax diluadin 0.45660466 0.27574270963668823
# kratom kratom 1.0 1.0
# kratom diluadin 0.68895537 0.20705321431159973
# oxy oxy 1.0000001 1.0
# diluadin diluadin 1.0000001 1.0000001192092896
# fentanyl fent and percs 0.38965976 0.3566676080226898
# morphine morphine 1.0 1.0
# oxycodone oxycodone and percocet 0.9128873 0.8080217838287354
# heroin heroin 1.0 0.9999999403953552
# beers alcohol 0.8363154 0.7118188142776489
# kratom kratom 1.0 1.0
# heroin heroin 1.0 0.9999999403953552
# not specified fent 0.6140821 0.1985778510570526
# opioid opioid 1.0000001 1.0
# h and fent h and fent 1.0 1.0000001192092896
# suboxone suboxone 1.0 1.0
# oxycodone possibly fentanyl oxy 30s fentanyl 0.9105338 0.7933205366134644
# fentanyl fent 30’s fentanyl 30 0.83338434 0.91582190990448
# fentanyl fentanyl 0.9999999 1.0
# heroin heroin 1.0 0.9999999403953552
# alcohol alcohol 1.0000001 1.0
# cocaine cocaine 0.9999999 1.0
# not specified blues 0.6777408 0.23095852136611938
# not specified bars 0.7157611 0.2518199384212494
# not specified meth 0.537873 0.20565445721149445
# not specified ice 0.70291424 0.30314427614212036
# heroin h kratom 0.6687667 0.2110651284456253
# heroin h h 0.743425 0.5561653971672058
# heroin heroin 1.0 0.9999999403953552
# heroin heroin 1.0 0.9999999403953552
# buprenophine clonazepam and pregabalin 0.730559 0.39739489555358887
# pregabalin clonazepam and pregabalin 0.55544525 0.6074113845825195
# clonazepam clonazepam and pregabalin 0.9102965 0.7634062170982361
# kratom kratom 1.0 1.0
# 17 37 41
# relapse event-specific-arguments relapse-substance 0.45945945945821765 0.4146341463404521 0.43589743584644974
# 3 days 3 days 1.0 1.0
# last night and this morning two days 0.57860297 0.3116229176521301
# few weeks few weeks 1.0000001 0.9999999403953552
# 2 days yesterday and today 0.6538601 0.4147115647792816
# year one year 0.65159154 0.6878727674484253
# few days several days 0.9084104 0.8521144390106201
# 3 to 4 days 34 days 0.7676211 0.7021538019180298
# 6 months 6 months 1.0 1.0
# 3 11 12
# relapse event-specific-arguments relapse-duration 0.2727272727247934 0.24999999999791667 0.26086956516521737
# suboxone started taking suboxone 0.7546374 0.7723934650421143
# hot soaks started taking suboxone 0.515602 0.009623666293919086
# imodium started taking suboxone 0.5877016 0.2481502890586853
# distractions started taking suboxone 0.5323041 0.09424546360969543
# walks started taking suboxone 0.47172728 0.01051896158605814
# bernese method bernese method 0.9999999 1.0000001192092896
# 15 mg percocet for 24 hours switching back to suboxone 0.5536718 0.2097223997116089
# taking suboxone taking suboxone again 0.9086514 0.8979825973510742
# support group quitting with support group help 0.6587281 0.6805720329284668
# switching clinics wants to start subacade 0.5470891 0.1312413513660431
# switching clinics switching clinics 1.0 1.000000238418579
# suboxone before sublocade wants to start subacade 0.5346194 0.3231889009475708
# inducing subs taking suboxone 0.59268653 0.19693395495414734
# bernese method bernese method 0.9999999 1.0000001192092896
# suboxone subs 0.6372401 0.35214412212371826
# narcan suggested to use narcan 0.72465396 0.796481728553772
# bernese method trying to switch back to suboxone 0.5538796 0.058536577969789505
# endure withdrawal days trying to switch back to suboxone 0.5899262 0.21915698051452637
# took suboxone taking more subs 0.6807616 0.37929993867874146
# comfort meds in detox taking more subs 0.5240588 0.04227149486541748
# otc sleep meds use sleep meds 0.85235035 0.7227606773376465
# otc sleep meds ambien 0.5215544 0.4475407898426056
# otc sleep meds benzos 0.5582797 0.21580716967582703
# ambien use sleep meds 0.5061209 0.39984118938446045
# ambien ambien 1.0 1.0
# benzo use sleep meds 0.5771302 0.1353808343410492
# benzo benzos 0.88812697 0.9173188209533691
# suboxone using suboxone 0.8965359 0.881891131401062
# suboxone wants to start moud 0.503704 0.11781229078769684
# suboxone start at 24mg 0.44956347 0.2660320997238159
# suboxone no meth 0.57974595 0.3174009323120117
# valium wants to start moud 0.44181716 0.12471888959407806
# valium start at 24mg 0.41463885 0.22677713632583618
# valium no meth 0.6305466 0.2605013847351074
# medical supervision wants to start moud 0.49961168 0.1396143138408661
# medical supervision start at 24mg 0.48163503 0.045766495168209076
# medical supervision no meth 0.61036766 0.10694469511508942
# buprenorphine tablets quickmd 0.36389077 0.21807792782783508
# buprenorphine tablets buprenorphine 0.9171645 0.8741745948791504
# 8mg twice day quickmd 0.61548984 0.2382374107837677
# 8mg twice day buprenorphine 0.4577958 0.3107043504714966
# 2mg of unspecified medication 2 mg moud 0.7242625 0.6087028980255127
# plan to switch to methadone plan to use methadone 0.91216415 0.9169703125953674
# 4 32 25
# relapse event-specific-arguments relapse-intervention 0.12499999999960937 0.15999999999936002 0.14035087714324404
# 36 hours 36 hours 0.9999999 1.000000238418579
# 26 hours 26 hours after last fent 0.6962218 0.5916523933410645
# 26 hours 1 hour after percs 0.71561867 0.3625604510307312
# one week one week 1.0 1.0000001192092896
# 3 days three days 0.88923156 0.9686784148216248
# 72 hours 72 hours 1.0000001 0.9999998807907104
# 7 hours 7hrs 0.7660037 0.8327016830444336
# complete withdrawal before taking suboxone wait until in ed enough 0.4702924 0.18118911981582642
# 24 hours after last opiate use 24 hours 0.5739997 0.4558643102645874
# 20 hours 20 hours 1.0000001 0.9999999403953552
# 4 11 13
# relapse event-specific-arguments waiting-time 0.36363636363305785 0.3076923076899408 0.33333333328090275
# 33 33 1.0 1.0000001192092896
# 1 2 2
# relapse subject-effect-arguments age 0.499999999975 0.499999999975 0.499999999925
# male male 1.0 1.0
# 1 3 3
# relapse subject-effect-arguments gender 0.3333333333222222 0.3333333333222222 0.3333333332722222
# percocet addiction percocet addiction 1.0000001 0.9999998807907104
# fentanyl addiction fentanyl addiction 1.0000001 1.0
# addiction to kratom for 5 years kratom and thc addict 0.71734357 0.7772393226623535
# habit of taking 13 dirty 30s daily for 7 months habit of using dirty 30s 0.83096755 0.6664528846740723
# relapsed on fentanyl fentanyl addiction 0.77568656 0.7567408680915833
# insomnia insomnia 1.0 1.0
# substance use substance dependence 0.8125821 0.8064932823181152
# fentanyl addiction fentanyl addiction 1.0000001 1.0
# chronic pain from car accident in 2015 chronic pain from car accident 0.9355651 0.9501826763153076
# dirty 30 withdrawals dirty 30 withdrawals 1.0000001 1.000000238418579
# arthritis in hips arthritis in hips 0.9999999 1.0
# addiction heroin addiction 0.696967 0.8215042948722839
# heroin withdrawal heroin addiction 0.935006 0.8125661015510559
# 6 15 14
# relapse subject-effect-arguments conditions 0.3999999999973333 0.42857142856836733 0.4137931033954816
# withdrawal symptoms withdrawal symptoms 1.0000001 0.9999999403953552
# unfunctional due to benzo withdrawal withdrawal 0.38818026 0.5805103778839111
# precipitated withdrawal cold turkey withdrawal 0.59179324 0.5898809432983398
# uncomfortable withdrawal symptoms wd symptoms 0.60863316 0.4199312925338745
# potential precipitated withdrawal withdrawals 0.59464014 0.6456559896469116
# throw up and nod out throw up and nod out 1.0000001 0.9999998807907104
# withdrawal symptoms normal withdrawal symptoms 0.9092207 0.9262498617172241
# knees aching and hurting sickness 0.5217454 0.20780140161514282
# knees aching and hurting achy knees 0.6863962 0.5760393142700195
# inability to sleep insomnia 0.7043235 0.6255664825439453
# precipitated withdrawals precipitated withdrawals 0.99999994 1.0
# increased alcohol tolerance more alcohol to get drunk 0.7057335 0.6675313711166382
# increased alcohol tolerance less enjoyable drunkness 0.75569963 0.593930184841156
# less enjoyable drunkenness more alcohol to get drunk 0.7422893 0.7678059339523315
# less enjoyable drunkenness less enjoyable drunkness 0.9579918 0.9742516279220581
# neutralizing or nullifying interaction with cocaine cant feel cocaine high 0.5808535 0.544441282749176
# potential precipitated withdrawals lack of sleep 0.5996989 0.2476460188627243
# sweaty sweaty 1.0000001 1.0
# sweaty cant sit still 0.51109606 0.3057635426521301
# skin crawling skin crawling 1.0 1.0000001192092896
# cant sit still cant sit still 1.0 0.9999999403953552
# pain pain 1.0000001 1.0000001192092896
# 7 22 24
# relapse subject-effect-arguments side-effects 0.31818181818037194 0.29166666666545144 0.3043478260357278
# worse than normal cold turkey withdrawal too much 0.46618462 0.18522615730762482
# severe high 0.75680393 0.47459423542022705
# severe medium 0.8324311 0.3668097257614136
# high high 0.9999999 1.0000001192092896
# severe high 0.75680393 0.47459423542022705
# 1 9 9
# relapse subject-effect-arguments severity 0.11111111110987654 0.11111111110987654 0.11111111105987652
# few weeks ago few weeks ago 1.0000001 1.0000001192092896
# past hour hour ago 0.8322508 0.8047308921813965
# few months ago few months ago 1.0000001 1.0
# day 2 of bernese method today 0.48782465 0.2746352553367615
# 2 6 6
# relapse subject-effect-arguments start-time 0.33333333332777776 0.33333333332777776 0.33333333327777775
# past hour 1 hour 0.757102 0.5367929935455322
# few months months 0.84018826 0.8346091508865356
# since starting intake 20 hours 0.62250143 0.17741093039512634
# 0 5 5
# relapse subject-effect-arguments side-effect-duration 0.0 0.0 0.0
# hot soaks hot soaks 0.99999994 1.0
# hot soaks distractions 0.59362084 0.08781875669956207
# hot soaks walks 0.43657553 0.07946085184812546
# imodium imodium 1.0 1.0000001192092896
# imodium walks 0.48289353 0.17693763971328735
# distractions distractions 0.9999999 1.0
# walks walks 1.0 1.0000001192092896
# bernese method bernese method 0.9999999 1.0000001192092896
# seeing doctor suboxone 0.57754636 0.15080329775810242
# seeing doctor oxycodone 0.34507257 0.2534951865673065
# seeing doctor diliduan 0.42350814 0.12483415007591248
# tapering benzos suboxone 0.73948014 0.2528429925441742
# tapering benzos oxycodone 0.61454177 0.2598046660423279
# tapering benzos diliduan 0.37527746 0.17208699882030487
# wait 24 hours before starting 1mg suboxone wait 24 hours 0.66443235 0.5172722935676575
# wait 24 hours before starting 1mg suboxone start off with 1 mg 0.7042102 0.5339540839195251
# wait 5 days for morphine to work wait 5 days for morphine to work 1.0 1.0
# take 1 mg of subs and assess taking less subs and observing how you feel 0.73603636 0.5167878270149231
# support group help quitting with support group help 0.78422713 0.7726240158081055
# high dosing thc need more than 2mg of subs 0.56884557 0.29119598865509033
# starting subs need more than 2mg of subs 0.62121487 0.48585712909698486
# switching clinics due to missed appointment and alcohol consumption switching clinics 0.5284319 0.7349203824996948
# sub taper regular supply of subs 0.6030479 0.3462325930595398
# gabapentin regular supply of subs 0.41867593 -0.03480628877878189
# xanax regular supply of subs 0.39334264 0.00525769405066967
# muscle relaxers regular supply of subs 0.52024114 0.04813764989376068
# considering continuing suboxone planning to change subs dose 0.7086966 0.46671849489212036
# taper off fentanyl with suboxone using bernese method bernese method 0.53585255 0.41397932171821594
# suboxone induction quitting cold turkey 0.57896096 0.04205338656902313
# narcan suggested to use narcan 0.72465396 0.796481728553772
# suboxone bernese method 0.60902154 0.11415667831897736
# bernese method bernese method 0.9999999 1.0000001192092896
# took 10mg suboxone more subs 0.5813159 0.19068410992622375
# took 10mg suboxone comfort meds 0.5467729 0.22808937728405
# no relief more subs 0.70760375 0.16077905893325806
# no relief comfort meds 0.59390616 0.27932867407798767
# melatonin take sleep meds 0.6136921 0.46572136878967285
# melatonin ambien 0.48718134 0.41122889518737793
# melatonin benzo 0.59550923 0.321643590927124
# seroquel take sleep meds 0.52792275 0.2404874861240387
# seroquel ambien 0.6153807 0.3988839089870453
# seroquel benzo 0.721472 0.5294622182846069
# trazadone take sleep meds 0.52715224 0.08362098038196564
# trazadone ambien 0.5880398 0.3745473623275757
# trazadone benzo 0.7220043 0.4754028916358948
# zoloft take sleep meds 0.5147469 0.2398744821548462
# zoloft ambien 0.50608253 0.397222101688385
# zoloft benzo 0.5713928 0.39603668451309204
# weed take sleep meds 0.5502763 0.10839378088712692
# weed ambien 0.5207935 0.3316512703895569
# weed benzo 0.81156623 0.45555102825164795
# use telehealth or local doctors for prescriptions get suboxone from doctors in area 0.64862716 0.47955989837646484
# suboxone take 24mg for first month 0.5320632 0.2031819373369217
# suboxone then 8mg or less 0.5540387 0.3140409588813782
# suboxone alcohol can help but no meth 0.56491053 0.2543223798274994
# valium take 24mg for first month 0.47436917 0.16241802275180817
# valium then 8mg or less 0.5217112 0.28426429629325867
# valium alcohol can help but no meth 0.4932614 0.18756544589996338
# medical supervision take 24mg for first month 0.48090476 -0.042847875505685806
# medical supervision then 8mg or less 0.46499828 0.011021867394447327
# medical supervision alcohol can help but no meth 0.536569 0.07626968622207642
# considering dissolving buprenorphine under tongue wait 24 hours after last opiate use 0.6621902 0.3739853501319885
# used kratom to get off subs use kratom 0.6836226 0.6203441023826599
# took 2mg dose moud intake 0.6216197 0.1650998890399933
# plan to switch to methadone planning to use methadone 0.9023744 0.910962700843811
# ordered kratom kratom while on suboxone 0.75805044 0.5358110666275024
# 7 40 36
# relapse subject-effect-arguments intervention 0.1749999999995625 0.19444444444390432 0.18421052626544324
# results-gpt-4obatch_question_guided_0.99.json
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Results/2-new-results-gpt-4o.json
# CPU times: user 2h 22min 4s, sys: 13min 33s, total: 2h 35min 37s
# Wall time: 5h 41min 52s

# %% [markdown]
# printing to understanding the nesting in the results dict

# %%
print(results_dict.keys())
print(results_dict['batch_description_guided_0.749'].keys())
print(results_dict['batch_description_guided_0.749']['tapering'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments']['effects'])
# Out:
# dict_keys(['batch_description_guided_0.749', 'batch_description_guided_0.99', 'batch_question_guided_0.749', 'batch_question_guided_0.99', 'isolated_description_guided_0.749', 'isolated_description_guided_0.99', 'isolated_question_guided_0.749', 'isolated_question_guided_0.99'])
# dict_keys(['taking-moud', 'tapering', 'relapse'])
# dict_keys(['main-arguments', 'event-specific-arguments', 'subject-effect-arguments'])
# dict_keys(['subject/patient', 'effects', 'tapering-event'])
# [[0.4583333333314236, 0.54999999999725, 0.49999999994814043], [11, 24, 20]]
