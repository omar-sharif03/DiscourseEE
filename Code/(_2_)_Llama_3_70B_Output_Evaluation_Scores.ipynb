# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %%capture
# !pip install transformers # If you are using collab, "!" is required to download
# !pip install bert-score
# !pip install -U sentence-transformers

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer

# Download NLTK resources
nltk.download('punkt')
nltk.download('wordnet')

# %%
import os, json
import numpy as np
from argparse import ArgumentParser
from tqdm import tqdm
from collections import defaultdict
import pandas as pd
from pprint import pprint
import re, string
from google.colab import files

from transformers import BertTokenizer, BertModel
from sentence_transformers import SentenceTransformer, util
import torch
import copy

# %% [markdown]
# ## Calculating evaluation scores

# %%
def read_json_file(name):
    with open(name, 'r') as f:
        data = json.load(f)
        return data

def save_json(json_data, file_name):
    json_data = json.dumps(json_data)
    print(file_name)
    with open(file_name, "w") as json_file:
          json_file.write(json_data)

# %%
# def perform_lemmatization(text):

#     # Tokenize the text into words
#     words = word_tokenize(text)
#     lemmatizer = WordNetLemmatizer()
#     stemmer = PorterStemmer()
#     lemmatized_and_stemmed_words = [(lemmatizer.lemmatize(word), stemmer.stem(word)) for word in words]

#     lemmatized_words, stemmed_words = zip(*lemmatized_and_stemmed_words)
#     lemmatized_text = ' '.join(lemmatized_words)
#     stemmed_text = ' '.join(stemmed_words)

#     # print("Original text:", text)
#     # print("Lemmatized text:", lemmatized_text)
#     # print("Stemmed text:", stemmed_text)
#     return stemmed_text

def clac_sbert_score(text1, text2):
    model = SentenceTransformer("all-MiniLM-L6-v2")

    embeddings1 = model.encode(text1, convert_to_tensor=True)
    embeddings2 = model.encode(text2, convert_to_tensor=True)

    cosine_score = util.cos_sim(embeddings1, embeddings2)
    #print(cosine_score.item())
    return cosine_score.item()

def calc_cosine_similarity(text1, text2):

    tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
    model = BertModel.from_pretrained("bert-base-uncased")

    # text1 = perform_lemmatization(text1)
    # text2 = perform_lemmatization(text2)

    inputs1 = tokenizer(text1, return_tensors="pt", padding=True, truncation=True)
    inputs2 = tokenizer(text2, return_tensors="pt", padding=True, truncation=True)

    outputs1 = model(**inputs1)
    outputs2 = model(**inputs2)

    embeddings1 = outputs1.last_hidden_state.mean(dim=1).detach().numpy()
    embeddings2 = outputs2.last_hidden_state.mean(dim=1).detach().numpy()

    #Calculate cosine similarity
    similarity = np.dot(embeddings1, embeddings2.T) / (np.linalg.norm(embeddings1) * np.linalg.norm(embeddings2))

    #print("Similarity between the texts:", similarity)
    return similarity[0][0]

# %%
def is_null_or_empty(string):
    return string is None or string.strip().lower() == 'null' or string.strip() == ''

def normalize_string(s):
      def remove_articles(text):
          regex = re.compile(r'\b(a|an|the)\b', re.UNICODE)
          return re.sub(regex, ' ', text)
      def white_space_fix(text):
          return ' '.join(text.split())
      def remove_punc(text):
          exclude = set(string.punctuation)
          return ''.join(ch for ch in text if ch not in exclude)
      def lower(text):
          return text.lower()
      return white_space_fix(remove_articles(remove_punc(lower(s))))


def calculate_score(predictions, ground_truth_labels, similarity_threshold):
    true_pos, pred_count, gtruth_count = 0, len(predictions), len(ground_truth_labels)

    if ((len(ground_truth_labels)==1 and is_null_or_empty(ground_truth_labels[0]))): #only not calculating when ground-truth is null
        #print("xxx ", predictions, labels) #(len(predictions)==1 and is_null_or_empty(predictions[0]))
        return 0, 0, 0 #skipping this sample
    else:
        actual_labels = copy.deepcopy(ground_truth_labels)
        # print(predictions, actual_labels)
        # print(len(predictions), len(actual_labels))
        for p in predictions:
            for g in actual_labels:
                if(g.strip() == ''): gtruth_count -=1 ## if any ground-truth is empty reducing that count.
                if(is_null_or_empty(p) or is_null_or_empty(g)): continue ##if prediction/ground-truth is null then skip
                np, ng = normalize_string(p), normalize_string(g)
                sim_value = calc_cosine_similarity(np,ng)
                sbert_score = clac_sbert_score(np, ng)
                print(np, ng, sim_value, sbert_score)
                if(sim_value>similarity_threshold or sbert_score>similarity_threshold):
                    true_pos += 1
                    actual_labels.remove(g)
        # print(predictions, labels)
        # print(true_pos, pred_count, gtruth_count)
        return true_pos, pred_count, gtruth_count

def calc_precision_recall_f1(true_pos, pred_count, gtruth_count):
    print(true_pos, pred_count, gtruth_count)
    precision = true_pos/(pred_count + 1e-10)
    recall = true_pos/(gtruth_count + 1e-10)
    f1 = 2 * precision * recall / (precision + recall + 1e-10)
    return precision, recall, f1

# %%
def select_event_specific_data(event, data):
    ev_data = []
    for dt in data:
        if event==dt['label']:
            ev_data.append(dt)
    return ev_data

def calc_results(all_data, event_types, arg_types, events_roles, pred_name, gtruth_name, similarity_threshold):
    results = {}
    for event in event_types:
        results[event] = {}
        for arg_type in arg_types:
            results[event][arg_type] = {}
            arguments = list(events_roles[event][arg_type].keys())
            for arg in arguments:
                tp, pc, gc = 0, 0, 0 #initialize the true_positive, pred_count, ground_truth-count for each arguments
                event_specifc_data = select_event_specific_data(event, all_data) ##geting the data for a specific event type.
                for dt in event_specifc_data:
                    label = dt['label']
                    pred_list = dt[pred_name][arg_type][arg] #predictions
                    gtruth_list = dt[gtruth_name][arg_type][arg] #ground-truth arguments
                    #print(pred_list, gtruth_list)
                    true_pos, pred_count, gtruth_count = 0, 0, 0
                    try:
                       true_pos, pred_count, gtruth_count = calculate_score(pred_list,
                                                                         gtruth_list, similarity_threshold)
                    except:
                        print(event, arg_type, arg)
                        print(pred_list, gtruth_list)
                        print("Error occured at", dt['doc_id'])

                    tp+= true_pos
                    pc+= pred_count
                    gc+= gtruth_count
                if(gc==0):
                    continue #skiping those values, where we do not have any ground truth.

                precision, recall, f1 = calc_precision_recall_f1(tp, pc, gc)
                print(event, arg_type, arg, precision, recall, f1)
                #saving the values in two items is a list
                #first item has (precision, recall, f1 scores) #second item has (true_pos, pred_count, ground_truth_count values)
                results[event][arg_type][arg]= [[precision, recall, f1], [tp, pc, gc]]

    return results

# %%
# %%time

events_roles = read_json_file('role_definitions.json')

prompt_types = ['batch'] #['batch', 'isolated']
exp_types = ['description_guided', 'question_guided']
event_types = ['taking-moud', 'tapering', 'relapse']
arg_types = ['main-arguments', 'event-specific-arguments', 'subject-effect-arguments']
similarity_threshold = [0.749, 0.99]

number = '1'
name = 'Llama-3-70B-Instruct'
folder_path = 'Argument-Extraction-Predictions'
file_name = f'{number}-processed-{name}_test_100_predictions.json'
print(os.path.join(folder_path, file_name))
all_data = read_json_file(os.path.join(folder_path, file_name))

print(all_data[0].keys())
print(len(all_data))
# Out:
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Predictions/1-processed-Llama-3-70B-Instruct_test_100_predictions.json
# dict_keys(['doc_id', 'id', 'text1', 'text2', 'label', 'thread-length', 'ground-truth-arguments', 'raw-batch_description_guided-predictions', 'raw-batch_question_guided-predictions', 'processed-batch_description_guided-predictions', 'processed-batch_question_guided-predictions'])
# 100
# CPU times: user 24.4 ms, sys: 1.05 ms, total: 25.5 ms
# Wall time: 47.6 ms

# %%
# %%time
numbers = ['0', '1', '2']

for number in numbers:
    file_name = f'{number}-processed-{name}_test_100_predictions.json'
    all_data = read_json_file(os.path.join(folder_path, file_name))

    results_dict = {}
    for p_type in prompt_types:
          for e_type in exp_types:
              g_name = 'ground-truth-arguments'
              p_name = f'processed-{p_type}_{e_type}-predictions'
              for s_t in similarity_threshold:
                  print(p_type, e_type, s_t)
                  results = calc_results(all_data, event_types, arg_types, events_roles,
                            p_name, g_name, s_t)
                  save_json(results, f'results-{name}{p_type}_{e_type}_{s_t}.json')
                  results_dict[f'{p_type}_{e_type}_{s_t}']=results


    result_folder_path = 'Argument-Extraction-Results'
    save_json(results_dict, os.path.join(result_folder_path,f'{number}-new-results-{name}.json'))
# Out:
# Streaming output truncated to the last 5000 lines.
# taking 4 15mg percs to make first 24 hours bearable switching back to suboxone 0.54973227 0.20765113830566406
# suboxone treatment suboxone treatment 0.9999999 1.0
# taking kratom take kratom to wait 2436 hours before subs 0.7136269 0.598589301109314
# taking suboxene to break from opiates suboxone 0.687457 0.6044920086860657
# suboxone drop to 1mg for month then 5mg for month then jump 0.42704242 0.25034868717193604
# kratom drop to 1mg for month then 5mg for month then jump 0.53103393 0.17643824219703674
# lyrica drop to 1mg for month then 5mg for month then jump 0.27201435 0.08596278727054596
# taking less medicine taking less prescription 0.9476387 0.769248366355896
# cutting dose suggested to cut dose 0.742306 0.8273707032203674
# nonaddictive treatments taking 2mg bar 0.47950366 0.11422313749790192
# taking suboxone at 1011 am take subs around 1011am 0.6790487 0.5191552639007568
# taking suboxone suggested to use cows scale 0.54751086 -0.023711657151579857
# suboxone wait 48 hours 0.539999 0.15827156603336334
# use suboxone instead of subutex stay on suboxone 0.79850394 0.7146060466766357
# subutex detox wait 36 hours 0.49605623 0.09530917555093765
# subutex detox get diamorphine 0.6127255 0.272098571062088
# wait 36 hours wait 36 hours 1.0 1.0000001192092896
# 3 30 26
# taking-moud subject-effect-arguments intervention 0.09999999999966667 0.11538461538417161 0.1071428570927296
# individual on 32mg daily dose individual going down daily dose of 32mg 0.89813745 0.8600322008132935
# suboxone user individual trying to taper off sub usage 0.5849505 0.35378915071487427
# kratom user individual expecting discomfort for tapering 0.54174113 0.04144669696688652
# friend of poster individual who snorted suboxone with naloxone to quit 0.42077565 0.20627745985984802
# individual jumping off medication individual looking for medication to ease quitting 0.6152182 0.6081004738807678
# individual quitting suboxone and girlfriend individual and their girlfriend suffering from anxiety after tapering 0.7837944 0.4047319293022156
# individual trying to get off subs individual needs help tapering 0.6083519 0.25959378480911255
# individual trying to taper off suboxone indivdual wanting to taper from suboxone 0.819082 0.8732509613037109
# 40yearold in good shape 40yearold who quit subutex for 20 years 0.73091274 0.3838005065917969
# individual taking suboxone individual just quit suboxone 0.820944 0.7770487666130066
# individual taking 1020mg oxys daily for 5 years individual wanting to do rapid taper to quit oxy 0.71569 0.5451819896697998
# opioid addicted individual indivdual seeking infromation on when they can quit suboxone 0.6614674 0.3614572286605835
# individual taking 24 mg of subs daily patient going cold turkey 0.5874384 0.16959747672080994
# individual going through withdrawal patient quitting opioid 0.55408823 0.47343915700912476
# individual tapering off subutex individual tapering off subutex and struggling from side effects 0.71079135 0.7841033339500427
# suboxone user individual tapering off suboxone experiencing side effects 0.5189265 0.5324903726577759
# kratom user individual using kratom to taper suboxone 0.6688691 0.4601067900657654
# individual tapering off suboxone individual looking for advice to taper subs and opiates 0.6512977 0.4312416911125183
# brother on methadone individual suggesting vitadone for those going through withdrawals or quitting 0.61314255 0.18498092889785767
# poster on sublocade individual suggesting vitadone for those going through withdrawals or quitting 0.5025813 0.014661811292171478
# individual who took subs for 4 days individual tapering on subs 0.41750014 0.3052171468734741
# single mom with fulltime job single mom 0.6736572 0.7661320567131042
# single mom with fulltime job who works full time 0.7641779 0.54792320728302
# accidental opioid user with health issues individual tapering off suboxone after relapse 0.6690002 0.24991649389266968
# individual struggling with suboxone individual tapering suboxone and feeling well 0.7841847 0.7075735330581665
# individual tired of being on subs individual on suboxone for 2 years plans to quit 0.71532255 0.2624962329864502
# 0 25 25
# tapering main-arguments subject/patient 0.0 0.0 0.0
# rls restless leg syndrome 0.4732038 0.17667126655578613
# sleep restless leg syndrome 0.45840803 0.2560451626777649
# sneezing fits sneezing fits 0.99999994 1.0
# discomfort discomfort expected 0.8433965 0.8306369781494141
# no withdrawal able to quit suboxone 0.48127452 0.4190690517425537
# no high able to quit suboxone 0.4946102 0.1241607517004013
# anxiety insomnia and anxiety 0.680119 0.641838550567627
# sleep issues insomnia and anxiety 0.7865113 0.6402814388275146
# physical dependence insomnia and anxiety 0.5216094 0.09280271083116531
# liver damage insomnia and anxiety 0.6409262 -0.011060670018196106
# runny nose runny nose 1.0 0.9999999403953552
# withdrawal symptoms sick 0.68286186 0.13097764551639557
# withdrawal symptoms little nose running 0.5340622 0.05779806151986122
# withdrawal symptoms little colder 0.56592363 0.15387341380119324
# insomnia sneezing 0.6283476 0.3201625943183899
# insomnia yawning 0.5628356 0.4672143757343292
# insomnia insomnia 1.0 1.0
# sneezing sneezing 1.0 1.0
# yawning yawning 1.0000001 0.9999999403953552
# headache and neck pain headache and neck pain 0.99999994 1.0
# stomachbladder pain stomachbladder pain 0.9999999 1.0000001192092896
# relief from withdrawal symptoms awakeness 0.6667207 0.20728269219398499
# relief from withdrawal symptoms restless legs 0.6587069 0.2650645971298218
# relief from withdrawal symptoms discomfort 0.5640913 0.2752014994621277
# anxiety loss of anxiety 0.7574646 0.7712886333465576
# anxiety less brain fog 0.7215859 0.3052471876144409
# brain fog loss of anxiety 0.6139928 0.28423982858657837
# brain fog less brain fog 0.8458333 0.8699550628662109
# existential crisis loss of anxiety 0.6643655 0.18383720517158508
# existential crisis less brain fog 0.6036177 0.1326882690191269
# 7 23 20
# tapering main-arguments effects 0.30434782608563327 0.34999999999825004 0.32558139529756625
# cut by 4mg day going down from 32mg 0.6766583 0.6160313487052917
# cut by 4mg day wants to cut by 4mg day 0.8960263 0.9592858552932739
# 2mg every 3 days to 1mg every 2 days reducing subs dosage from 2mg every 3 days to 05mg daily 0.73389286 0.7334529161453247
# 05mg to 025mg drop from 05 mg to 025 mg 0.73367196 0.8020231127738953
# 14 82mg morning snorting suboxone to quit 0.49526033 0.20474642515182495
# 14 82mg evening for month snorting suboxone to quit 0.5902484 0.21090969443321228
# taking lowest dose of meds daily starting with 6mg 0.4931535 0.477019727230072
# tapering from 24mg to 3mg suboxone went from 24mg suboxone to 3mg 0.87444884 0.7763809561729431
# stopped 12mg suboxone on thursday from 12mg to 0mg 0.6281194 0.46159911155700684
# rapid taper of subs or ct planning either rapid sub taper or just quitting 0.7084448 0.6297214031219482
# dropping dose to 1mg daily tapering off subutex on 1 mgday 0.7859422 0.5731691122055054
# suboxone taper from 05 to 025 from 5mg suboxone to 30mg 0.8180297 0.5105080604553223
# suboxone taper from 05 to 025 attempting to jump to 25mg 0.5095485 0.21186424791812897
# using low dose opiatebenzos for short term taking subs and wants to quit 0.54139835 0.135374054312706
# 6mg to 34 mg in 4 days 6 mg day to 34 mg in 4 days 0.929011 0.9608604907989502
# 2mg day or less going down to 2mg suboxone 0.6835206 0.5641146898269653
# 7th attempt going down to 2mg suboxone 0.39288273 0.1320813000202179
# 8 years going down to 2mg suboxone 0.49447986 0.03786435350775719
# 90 8mg to taper off in unknown duration looking to use 90 8mgs to taper off 0.84392947 0.8171600699424744
# 0 25 25
# tapering main-arguments tapering-event 0.0 0.0 0.0
# taking lowest dose of meds daily taking 6mg of subs 0.646734 0.4144737422466278
# addicted to suboxone taking 24 mg of suboxone 0.8352133 0.6673924922943115
# 40 years old on suboxone for last 20 years 0.50739485 0.258594810962677
# in good shape on suboxone for last 20 years 0.44900113 0.17569634318351746
# opioid dependence subject was taking 12 mg of suboxone and opioids 0.58841413 0.5849416255950928
# 5 years of 1020 mg of oxys daily taking 1020mg of oxy daily for 5 years 0.8868379 0.8999642133712769
# addicted to subs taking subs for dirty 30 withdrawals for 4 days 0.6485033 0.43664291501045227
# single mom single mother who is working full time 0.577055 0.7752017974853516
# fulltime worker single mother who is working full time 0.6300183 0.592735230922699
# little support single mother who is working full time 0.53589493 0.1664288491010666
# declining health issues took fake roxies after being off opiates for 4 years 0.48693687 0.14156493544578552
# brain and body chemistry jacked up felt ill 0.43795592 0.22550570964813232
# tired of being on subs been on subs for 3 years 0.73591185 0.7079406976699829
# 0 13 10
# tapering event-specific-arguments condition 0.0 0.0 0.0
# want to get clean wanting to quit oxy 0.7425206 0.24784910678863525
# appointment just beginning suboxone 0.5560217 0.14074625074863434
# accidental addiction to fake roxies wanting to stay off medication after relapse 0.7087938 0.28513580560684204
# tired of everything tired of being on subs 0.75578654 0.5128617882728577
# 0 7 7
# tapering event-specific-arguments trigger 0.0 0.0 0.0
# today today 0.9999999 1.0000001192092896
# thursday thursday 1.0000001 1.0000001192092896
# 4 days ago 4 days ago 1.0 0.9999999403953552
# 3 7 7
# tapering event-specific-arguments start-time 0.4285714285653061 0.4285714285653061 0.4285714285153061
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# prescribed tapering selftaper 0.6050787 0.10614556819200516
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering selftapering 0.99999994 1.0
# selftapering self tapering 0.7003454 0.5649640560150146
# selftapering orallysublingually 0.6854205 0.34981197118759155
# selftapering selftapering 0.99999994 1.0
# 10 23 23
# tapering event-specific-arguments type 0.43478260869376184 0.43478260869376184 0.43478260864376184
# sub suboxone 0.6590155 0.37370967864990234
# suboxone suboxone with naloxone 0.6666468 0.7104830741882324
# diphenhydramine diphenhydramine 0.99999994 1.0
# suboxone kratom 0.68420106 0.28886210918426514
# subs suboxone 0.6372401 0.35214412212371826
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# subs suboxone 0.6372401 0.35214412212371826
# subs subs 1.0000001 1.0000001192092896
# subutex subutex 1.0 0.9999999403953552
# suboxone suboxone 1.0 1.0
# kratom kratom 1.0 1.0
# short acting opiatesbenzos opiates 0.6988112 0.6967483758926392
# short acting opiatesbenzos benzos 0.62766063 0.3553750514984131
# short acting opiatesbenzos klonopin 0.62556183 0.3247937858104706
# short acting opiatesbenzos tramadol 0.6395189 0.3970520496368408
# subs and kratom kratomif required 0.7175107 0.5299122333526611
# subs and kratom subs 0.7501419 0.5256063938140869
# suboxone strips suboxone 0.9251065 0.7823392152786255
# suboxone suboxone 1.0 1.0
# subs suboxone 0.6372401 0.35214412212371826
# 8 17 22
# tapering event-specific-arguments taper-medications 0.4705882352913495 0.36363636363471075 0.4102564102051282
# 32mg 32mg 1.0 1.000000238418579
# 05mg 05 mg 0.880277 0.9393645524978638
# 82mg 82mg 1.0 1.0
# 24 mg 24mg 0.69979584 0.9446220397949219
# 12 mg 12mg 0.7176265 0.9395279884338379
# 24 mg 24 mg 1.0 1.0
# 6mg 6 mg 0.7363535 0.9401638507843018
# 3 10 10
# tapering event-specific-arguments initial-dosage 0.299999999997 0.299999999997 0.299999999947
# 2mg every 3 days 2mg every 3 days 1.0 1.0000001192092896
# 025mg 025 mg 0.8418047 0.9452039003372192
# 14 in morning and 14 in evening 0mg 0.3596726 0.13369961082935333
# less than qt 6mg 0.48948017 0.18883009254932404
# 3 mg 3mg 0.79855776 0.9231275320053101
# 0 mg 0mg 0.77785414 0.8933465480804443
# 125 0125 mg 0.59258527 0.43671947717666626
# 1mg daily 1 mg 0.71297705 0.7789731025695801
# 5 2530 0.6668451 0.2851101756095886
# 34 mg 34 mg 1.0 1.0000001192092896
# 2mg day or less 2mgday 0.6295312 0.7984532117843628
# 24mg day 24mg 0.62442833 0.8364930152893066
# 2 15 15
# tapering event-specific-arguments current-dosage 0.13333333333244443 0.13333333333244443 0.13333333328244443
# 0 mg 0mg 0.77785414 0.8933465480804443
# 25 25 1.0 1.0
# completely off sub and opiates quit all opiates 0.67019904 0.7500295639038086
# 0mg 0 mg 0.77785414 0.8933465480804443
# 0mg 0mg 0.9999999 1.0
# 2 21 21
# tapering event-specific-arguments goal-dosage 0.09523809523764173 0.09523809523764173 0.09523809518764173
# 1 month 1 month 0.99999994 1.0000001192092896
# 56 weeks 56 weeks 0.9999999 1.0000001192092896
# 2 5 5
# tapering event-specific-arguments target-duration 0.399999999992 0.399999999992 0.399999999942
# 40 years old 40 0.6004745 0.7096229195594788
# 0 1 1
# tapering subject-effect-arguments age 0.0 0.0 0.0
# 0 2 2
# tapering subject-effect-arguments gender 0.0 0.0 0.0
# anxiety recovering from suboxone kratom 0.4439094 0.09377489984035492
# insomnia recovering from suboxone kratom 0.4502163 0.1118309497833252
# rls recovering from suboxone kratom 0.3836287 -0.057238854467868805
# suboxone habit 7 year suboxone habit 0.80629134 0.8659151792526245
# declining health issues declining health issues 0.9999999 1.0
# 1 9 7
# tapering subject-effect-arguments conditions 0.11111111110987654 0.14285714285510204 0.12499999994921873
# rls restless leg syndrome 0.4732038 0.17667126655578613
# sneezing fits sneezing fits 0.99999994 1.0
# anxiety physical dependency to kratom 0.54255617 0.10782419890165329
# anxiety ruined liver 0.7657228 0.13003987073898315
# insomnia physical dependency to kratom 0.38628227 0.11516478657722473
# insomnia ruined liver 0.44794568 0.1440296173095703
# physical dependence physical dependency to kratom 0.73169297 0.3704431354999542
# physical dependence ruined liver 0.71987724 0.011055909097194672
# liver damage physical dependency to kratom 0.49583304 0.16131481528282166
# liver damage ruined liver 0.7208392 0.7890904545783997
# withdrawal symptoms detox 0.66396064 0.3056602478027344
# runny nose runny nose 1.0 0.9999999403953552
# nose running sick 0.70986927 0.2573973536491394
# nose running nose running 1.0 1.0000001192092896
# feeling cold sick 0.78628653 0.4801843464374542
# feeling cold colder 0.726741 0.7001147270202637
# sneezing sneezing 1.0 1.0
# sneezing insomnia 0.6283476 0.3201625943183899
# yawning yawning 1.0000001 0.9999999403953552
# insomnia insomnia 1.0 1.0
# headache and neck pain headache and neck pain 0.99999994 1.0
# stomachbladder pain stomachbladder pains 0.95150214 0.9770182967185974
# physical wd physical withdrawals 0.60085183 0.2757628858089447
# paws physical withdrawals 0.57845336 0.02653597667813301
# restless legs insomnia 0.5620499 0.3650832772254944
# restless legs restless legs 1.0 1.0000001192092896
# uncomfortable insomnia 0.46314827 0.3835887908935547
# uncomfortable discomfort 0.94587183 0.7927004098892212
# withdrawal withdrawal 1.0 1.0
# anxiety clear mind 0.7319052 0.37460383772850037
# brain fog clear mind 0.7532581 0.5141074657440186
# haze clear mind 0.7148604 0.42057108879089355
# 9 25 23
# tapering subject-effect-arguments side-effects 0.35999999999856 0.39130434782438567 0.37499999994852434
# 810 low 0.67481446 0.335293710231781
# bad low 0.82090497 0.3673636317253113
# horrible horrible 0.9999999 1.0000001192092896
# really bad medium 0.6405029 0.22509530186653137
# 1 8 8
# tapering subject-effect-arguments severity 0.1249999999984375 0.1249999999984375 0.1249999999484375
# third day three days ago 0.68611664 0.6287094950675964
# 5 days into dropping dose 5 days of dropping to 1 mg 0.86433727 0.8435409069061279
# 1220 hours from last dose 1220 hours from last dose 0.9999999 1.0
# 1 6 6
# tapering subject-effect-arguments start-time 0.16666666666388888 0.16666666666388888 0.16666666661388888
# 17 days 17 days 1.0 1.0
# 1 4 3
# tapering subject-effect-arguments side-effect-duration 0.24999999999375 0.3333333333222222 0.2857142856571428
# tapering dose by 4mg day give taper two weeks to stabalize 0.7245973 0.39732620120048523
# tapering sub usage suggested to make 2mg last 4 0.6730852 0.13480305671691895
# snorting suboxone to taper quitting suboxone and snorting 0.84046423 0.701798677444458
# avoid diphenhydramine diphenhydramine 0.93628436 0.8750292658805847
# kratom taking caution using kratom 0.6896595 0.7595901489257812
# quitting suboxone taking caution using kratom 0.57493585 0.1678326576948166
# exercise taking 6mg suboxone or exercising 0.47797182 0.3661678433418274
# sleeping medicine phenibutweedbenzos 0.5797764 0.26168760657310486
# weed phenibutweedbenzos 0.46687335 0.46319228410720825
# benzos phenibutweedbenzos 0.61737937 0.33730703592300415
# phenibut phenibutweedbenzos 0.73460704 0.66236412525177
# sinus meds netty pot and ibuprofenacetaminophen before dosing 0.5201631 0.17810463905334473
# netty pot netty pot and ibuprofenacetaminophen before dosing 0.31423795 0.5950645208358765
# ibuprofen netty pot and ibuprofenacetaminophen before dosing 0.82105726 0.5495097637176514
# acetaminophen netty pot and ibuprofenacetaminophen before dosing 0.84830356 0.43996360898017883
# electrolytes netty pot and ibuprofenacetaminophen before dosing 0.39946085 0.005573533475399017
# diet netty pot and ibuprofenacetaminophen before dosing 0.30796003 -0.07942956686019897
# kratom kratom and benzos 0.6973778 0.6569421291351318
# benzos kratom and benzos 0.7997323 0.6879101395606995
# kratom used kratom to get off suboxone 0.7065066 0.5597350001335144
# taper used kratom to get off suboxone 0.5595312 -0.006891131401062012
# after care used kratom to get off suboxone 0.5463975 0.026041824370622635
# exercise tramadol 0.6425554 0.2787035405635834
# exercise exercise 0.9999999 1.0
# exercise vitamins 0.6969115 0.16704267263412476
# short acting opiates tramadol 0.5843437 0.4223693311214447
# short acting opiates natural sleep aid 0.7073952 0.14397895336151123
# short acting opiates vitamins 0.66768026 0.1366157978773117
# benzos tramadol 0.6400131 0.3269318640232086
# benzos natural sleep aid 0.6432519 0.1357472538948059
# benzos vitamins 0.665114 0.32710427045822144
# natural sleep aids tramadol 0.6417817 0.1556248664855957
# natural sleep aids natural sleep aid 0.92738754 0.9280279278755188
# natural sleep aids vitamins 0.6801343 0.1871732920408249
# vitamins tramadol 0.5397529 0.13178053498268127
# vitamins natural sleep aid 0.6733579 0.1948312669992447
# vitamins vitamins 1.0 1.0
# kratom get off subsgo to program 0.66832143 0.10457468032836914
# getting shot getting shot 0.9999999 1.0
# 3 29 16
# tapering subject-effect-arguments intervention 0.10344827586171225 0.18749999999882816 0.1333333332869136
# individual quitting percocet individual quitting percs 0.77939594 0.8005167841911316
# 22yearold male 22 years old male addicted to fentanyl 0.50828004 0.27136462926864624
# 22yearold male wants to start bernese method 0.54084355 0.06923206150531769
# 110115lbs 22 years old male addicted to fentanyl 0.4916427 0.1162964403629303
# 110115lbs wants to start bernese method 0.49265254 0.017210453748703003
# 33yearold former opiate and benzo user individual relapsed on with multiple substances 0.6761906 0.44491690397262573
# individual relapsing after year of suboxone use individual asking for timing to take subs after relapse 0.78569895 0.47618329524993896
# individual using bupe patches individual eager to enjoy relapsing on bupe patches 0.7644112 0.7449805736541748
# individual taking oxycodone and suboxone individual relapses with oxycodone and percocet 0.8505413 0.6592695713043213
# individual struggling with addiction person quitting h with support group help 0.6933149 0.33964210748672485
# kratom addict wanting to quit individual who wants to start subs 0.7568786 0.19499842822551727
# missed appointment individual relapsed with beers and wants to taper with subacade 0.49009606 0.12870380282402039
# relapsed individual individual relapsed with beers and wants to taper with subacade 0.6329418 0.5512025356292725
# kratom user indivdual took kratom during withdrawal treatment 0.6763268 0.5083115100860596
# individual with 7month 13 day habit individual aiming to taper dirty 30s 0.68634033 0.10457921028137207
# individual teetering on edge indivdual trying to switch from heroin to suboxone 0.5855687 -0.03269501402974129
# individual on suboxone treatment individual who relapsed after being on suboxone for past year 0.73298305 0.7369418144226074
# fentanyl user seeking help individual quitting fentanyl 0.84571 0.6872409582138062
# individual on suboxone treatment individual asking about using opioid after suboxone 0.82486534 0.6552375555038452
# individual who relapsed after 7 days individual restarting subs 0.38399172 0.21374118328094482
# kratom dependent individual individual quitting cold turkey for kratom dependency 0.69068104 0.6431697607040405
# scared individual with low tolerance indivdual who snorted suboxone in fear of overdosing 0.6371016 0.35788288712501526
# individual on suboxone treatment person struggling to get back to subs after relapse 0.6107748 0.3012656569480896
# individual experiencing fentanyl relapse individual who relapsed on fentanyl 30 0.8867957 0.8324462175369263
# individual on suboxone with sleep issues individual on suboxone who used to use weed but now uses fentanyl for insomnia 0.8447129 0.6454743146896362
# individual trying to get off fentanyl individual trying to quit fent 0.69350815 0.743405818939209
# individual who relapsed on heroin individual relapsed on heroin for 34 days and aims to resume moud 0.7848024 0.7474297285079956
# individual taking suboxone patient asking about drinking on suboxone 0.8628464 0.74540114402771
# individual with fentanyl addiction individual switching from fent to subs using oxy 0.6038597 0.26440978050231934
# individual trying to get off fentanyl patient whose use of suboxone blocks cocaine high 0.68715775 0.4524248242378235
# addicted individual seeking suboxone and methadone individual taking substances and wants to start suboxone 0.7707979 0.6163798570632935
# individual with chronic pain and addiction individual anticipating precipitated withdrawal 0.57417005 0.3058772683143616
# individual who used kratom to get off subs individual wondering if kratom helps with withdrawals 0.7025996 0.5398160219192505
# naive individual taking subs for dirty 30 individual wants to quit from 75mg suboxone 0.707992 0.22344344854354858
# individual trying to taperjump from suboxone individual intending to use kratom to taper and avoid side effects 0.78395957 0.4807010293006897
# heroin addict in withdrawal individual starting intake after last heroin dose 0.7070901 0.6546945571899414
# individual relapsing after 3 years of subutex individual who uses subutex but relapsed on heroin 0.7241058 0.545830249786377
# unresponsible addict individual relapses with lots of medications 0.5073139 0.4055541753768921
# individual experiencing pain and taking suboxone indivdual in pain planning to use kratom 0.71784014 0.4076172709465027
# 0 37 36
# relapse main-arguments subject/patient 0.0 0.0 0.0
# using 1015 strong pressed 30’s daily using around 1015 strong pressed 30’s daily 0.939497 0.9548003673553467
# relapsed taking kratom taking kratom 0.6701439 0.7927641868591309
# relapsed taking kratom subs 0.43951574 -0.07402314990758896
# relapsed taking kratom oxy 0.37714994 0.0044407956302165985
# relapsed taking kratom diluadin 0.49525604 0.06775069236755371
# subs taking kratom 0.6155656 -0.0010812776163220406
# subs subs 1.0000001 1.0000001192092896
# subs diluadin 0.6078126 0.13063856959342957
# oxy taking kratom 0.5818191 0.05702944099903107
# oxy oxy 1.0000001 1.0
# diluadin taking kratom 0.66988105 0.13743895292282104
# diluadin diluadin 1.0000001 1.0000001192092896
# used fent over 3 days relapse to fent and percs 0.63317966 0.4451867640018463
# bridged with percs relapse to fent and percs 0.6890818 0.4931720495223999
# taking morphine prescription relapsing with morphine soon 0.8175445 0.7550477981567383
# taking 20 mg oxycodone this morning 20mg oxycodone this morning 0.92687446 0.9464397430419922
# taking 20 mg oxycodone this morning percs last night and this morning 0.5766558 0.20639488101005554
# teeter tottering between h and subs back and forth between h and subs 0.8384409 0.5859134793281555
# high dosing thc high dosing thc 1.0000001 1.0000001192092896
# had few beers on fathers day relapsed with beer on fathers day 0.8114983 0.844465434551239
# taking 3g of kratom took 3g of kratom 0.8901355 0.9194754958152771
# trying to induce subs taking heroin 0.5733168 0.17863628268241882
# taking addictive substances after period havent taken suboxone since friday 0.6457154 0.36738812923431396
# taking fentanyl relapsing on fent after cold turkey withdrawal 0.4502415 0.44118204712867737
# taking opioids after suboxone using opioids after last dose of suboxone 0.89071894 0.9330275058746338
# taking kratom h and fent 0.6518251 0.12799488008022308
# snorting 8mg of subconscious snorted 8mg suboxone 0.68583846 0.6655799746513367
# taking oxy 30s with fentanyl took oxy 30sfentanyl 0.77561426 0.6722396016120911
# taking fent 30’s for few days relapsed at 1130pm last night 0.46094954 0.2310543656349182
# taking fent for sleep use fentanyl for sleep 0.5510204 0.7807689905166626
# brief short relapse relapse on heroin for 34 days 0.78158814 0.5948329567909241
# drinking while taking suboxone drinking on suboxone 0.86603534 0.9566577076911926
# taking cocaine despite suboxone treatment used coke and adderole while on suboxone 0.69866383 0.7735215425491333
# taking blues and bars without ice taking blues 0.74329734 0.6676996946334839
# taking blues and bars without ice bars 0.5632384 0.44133564829826355
# taking blues and bars without ice and ice 0.6899344 0.40075790882110596
# taking h after kratom kratom 0.7795013 0.5807822942733765
# taking h after kratom h 0.5423478 0.36036401987075806
# taking subs without research dirty 30s and potential use of kratom if needed 0.59233165 0.0659349262714386
# took 2mg after 20 hours patient relapsing on heroin 0.53331494 0.26835736632347107
# taking 15g heroin per day for 6 months relapsed 6 months ago 0.62446564 0.32587122917175293
# taking 15g heroin per day for 6 months using 15 g herion per day 0.80542505 0.5888408422470093
# taking multiple medications 3mg clonazepam 0.5086938 0.3891594707965851
# taking multiple medications 2mg buprenophine 0.5660494 0.356874942779541
# taking multiple medications 300mg pregabalin 0.49334124 0.32569923996925354
# 4 33 39
# relapse main-arguments relapse-event 0.1212121212117539 0.10256410256383958 0.11111111106114968
# getting suboxone script getting suboxone 0.82896143 0.7875547409057617
# starting bernese method wants to start bernese method 0.8384502 0.9484626054763794
# seeking doctors help for benzo taper hoping to get more help than suboxone to quit benzos 0.80619186 0.5239879488945007
# waiting to take subs after last perc subs 0.5305668 0.4274625778198242
# taking 2 mg suboxone taking 1mg or less of suboxone and gaging feeling before taking other 1mg 0.86147964 0.7280718088150024
# trying to induce subs subs 0.62240905 0.599237322807312
# taking subs starting subs tomorrow morning 0.77933604 0.5724046230316162
# switching clinics planing to take subacade 0.5267621 0.20437748730182648
# trying sublocade planing to take subacade 0.66317916 0.29757124185562134
# tapering off using subs regular use of subs 0.71785647 0.5353065133094788
# taking suboxone dose after relapse continuing suboxone 0.49288478 0.6932477951049805
# taking kratom and suboxone bernese method with sub 0.5398868 0.20994433760643005
# start with 4mg am plans to start subs with 4mg am 0.67594486 0.7987590432167053
# start with 4mg am 4pm 0.6115187 0.33069759607315063
# 4pm and adjust up carefully plans to start subs with 4mg am 0.5891988 0.33517736196517944
# 4pm and adjust up carefully 4pm 0.6985549 0.6852388381958008
# getting on suboxone subs after year 0.569469 0.24338310956954956
# taking full dose of 22mg suboxone suboxone 0.6288332 0.6680805683135986
# taking sub and more subs throughout day took sub at 630am 0.64978725 0.56952965259552
# trying otc sleep meds taking suboxone while relapsing 0.74253666 0.19257692992687225
# ambien taking suboxone while relapsing 0.47216377 0.24572263658046722
# or benzo taking suboxone while relapsing 0.58061194 0.1513139307498932
# getting suboxone prescription wants to start suboxone 0.7306127 0.7394982576370239
# taking small piece considering taking small piece of moud 0.7544725 0.5100789070129395
# seeking to start suboxone and methadone wants to start moud 0.5149154 0.3737320899963379
# taking buprenorphine tablets buprenorphine tablets 0.9331839 0.9401603937149048
# took first dose moud intake after waiting for 20 hours 0.61488473 0.2965540289878845
# intends to get on methadone at clinic plans to use methadone 0.73523974 0.8394404649734497
# ordering kratom plans to continue treatment 0.54945624 0.07782143354415894
# 0 31 27
# relapse main-arguments resuming-moud-after-relapse 0.0 0.0 0.0
# sweating and wds possible sweating and withdrawal symptoms if dose is too high 0.5057706 0.539512038230896
# benzo wd leaves me totally unfunctional feeling very sick from kratom 0.60681957 0.3204055428504944
# precipitated withdrawal cold turkey withdrawal 0.59179324 0.5898809432983398
# throwing up and nodding out possible overdose 0.5373269 0.30023983120918274
# withdrawal symptoms still present normal withdrawal symptoms despite full dose 0.73844606 0.8231574296951294
# knees aching and hurting so bad sickness 0.4478871 0.22966887056827545
# knees aching and hurting so bad achy knees 0.5912007 0.5688540935516357
# stress sleep troubles 0.805203 0.17063474655151367
# inability to sleep sleep troubles 0.71351594 0.789370059967041
# precipitated withdrawals precipitated withdrawals 0.99999994 1.0
# reduced enjoyment of drunkenness requires more alcohol to get drunk 0.74552274 0.6539421081542969
# reduced enjoyment of drunkenness less enjoyable 0.5074953 0.5632807016372681
# not feeling cocaine high due to suboxone cant feel cocaine high 0.7126242 0.7072287201881409
# precipitated withdrawals and chronic pain possible precipitated withdrawal 0.77688694 0.7469480633735657
# extremely easy withdrawal withdrawals 0.5642449 0.7398164868354797
# paws might have paws from dirty 30s 0.41697723 0.5687928199768066
# withdrawal symptoms might have paws from dirty 30s 0.4027827 -0.007077317219227552
# sweaty sweaty 1.0000001 1.0
# sweaty cannot sit still 0.57161814 0.281718909740448
# skin crawling skin crawling 1.0 1.0000001192092896
# cant sit still cannot sit still 0.7429808 0.9561108946800232
# sickness and arthritis in hips experiencing sickness 0.5825036 0.5005788803100586
# no withdrawal symptoms zero wd symptoms 0.6008471 0.4272141754627228
# suboxone may block kratom effects suboxone may block effects of kratom 0.96378946 0.9869282245635986
# 3 22 22
# relapse main-arguments effects 0.13636363636301654 0.13636363636301654 0.13636363631301654
# opioid use disorder percocet addiction 0.67751414 0.46697431802749634
# opioid use disorder fentanyl addiction 0.6314642 0.568220317363739
# opiate and benzo addiction was on opiates and benzos for 10 years 0.7568981 0.749589204788208
# opiate and benzo addiction then methadone and clonazepam 0.7157947 0.48930901288986206
# opioid use disorder recovering from opioid use disorder 0.883915 0.8550974130630493
# opioid use disorder back and forth between h and subs 0.4013769 -0.007160824723541737
# kratom addiction kratom and thc addict 0.81342375 0.8263598680496216
# opioid use disorder drank alcohol 0.5174067 0.12897968292236328
# opioid withdrawal withdrawal from substance 0.6862037 0.709307074546814
# opioid use disorder heroin use disorder 0.77379644 0.7169877886772156
# opioid use disorder fent 0.38782609 0.14119595289230347
# opioid use disorder opioid 0.71936935 0.7944380044937134
# opioid use disorder off of subs for 7 days 0.45320418 -0.018884995952248573
# kratom dependency kratom 0.8761625 0.6785656213760376
# opioid use disorder suboxone use with low tolerance 0.5684133 0.25436270236968994
# opioid use disorder been on suboxone since august of 2021 0.4600666 0.2905558943748474
# opioid use disorder recovered from fentanyl 30s use 0.47737235 0.28198516368865967
# opioid use disorder weed and fent addict 0.53079706 0.45559579133987427
# opioid use disorder fenta addiction 0.47549427 0.5261602997779846
# fentanyl addiction fentanyl addiction 1.0000001 1.0
# opioid use disorder using blues 0.3911443 0.10040435940027237
# opioid use disorder bars 0.40705448 0.04028736427426338
# opioid use disorder and ice 0.3673185 0.026028724387288094
# opioid use disorder opiate use disorder 0.89067954 0.8772305250167847
# opioid withdrawal recovering from dirty 30s addiction 0.562251 0.36564522981643677
# opioid use disorder relapsed on heroin 0.6247264 0.49254661798477173
# heroin addiction recovering from heroin addiction 0.8492157 0.8075442314147949
# opioid addiction using suboxone 0.5155739 0.22378942370414734
# 1 25 28
# relapse event-specific-arguments condition 0.039999999999840004 0.03571428571415817 0.03773584900662158
# morphine prescription morphine prescription 0.99999994 1.0000001192092896
# availability of fentanyl shitty fent replacing good h 0.47310132 0.2750357687473297
# missed appointment fathers day 0.6653464 0.26500165462493896
# sleeping issues insomnia 0.7025203 0.6100912690162659
# lack of research wanting to quit suboxone 0.52976197 0.026936626061797142
# pain pain 1.0000001 1.0000001192092896
# 2 12 13
# relapse event-specific-arguments trigger 0.16666666666527777 0.1538461538449704 0.1599999999488
# methadone and clonazepam suboxone 0.45848858 0.3817923069000244
# suboxone sub 0.6590155 0.37370967864990234
# bupe patches bupe patch 0.94221675 0.9494718313217163
# suboxone suboxone 1.0 1.0
# thc subs 0.6120343 0.2553676962852478
# suboxone suboxone 1.0 1.0
# gabapentin subs 0.40028292 0.01751042529940605
# gabapentin gabapentin 1.0 1.000000238418579
# gabapentin muscle relaxers 0.6194408 0.3376624584197998
# xanax subs 0.41115862 0.18329769372940063
# xanax xanax 1.0000001 0.9999999403953552
# muscle relaxers subs 0.4536728 0.08415370434522629
# muscle relaxers muscle relaxers 0.99999994 1.0000001192092896
# suboxone 812mg suboxone 0.82027054 0.8272020816802979
# suboxone suboxone 1.0 1.0
# subs subs 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# sub subs 0.79202896 0.8165544271469116
# suboxone suboxone 1.0 1.0
# suboxone ambien 0.55143833 0.34220874309539795
# suboxone benzos 0.80525124 0.35993492603302
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# kratom and h buprenorphine 0.48232043 0.23004800081253052
# kratom suboxone 0.68420106 0.28886210918426514
# suboxone suboxone 1.0 1.0
# subutex subutex 1.0 0.9999999403953552
# buprenophine buprenophine 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# 16 34 36
# relapse event-specific-arguments existing/current-medications 0.4705882352927335 0.44444444444320985 0.4571428570915918
# percs percocet 0.6829824 0.5684541463851929
# fentanyl pressed 30s 0.30653974 0.10178772360086441
# kratom kratom 1.0 1.0
# kratom diluadin 0.68895537 0.20705321431159973
# subs oxy 0.59775823 0.24639689922332764
# subs diluadin 0.6078126 0.13063856959342957
# oxy oxy 1.0000001 1.0
# diluadin diluadin 1.0000001 1.0000001192092896
# fent fent and percs 0.72123665 0.659132719039917
# morphine morphine 1.0 1.0
# oxycodone oxycodone and percocet 0.9128873 0.8080217838287354
# heroin heroin 1.0 0.9999999403953552
# kratom thc 0.6397693 0.19885066151618958
# beer alcohol 0.89537066 0.7729755640029907
# kratom kratom 1.0 1.0
# dirty 30s dirty 30s 1.0 1.0
# heroin or fentanyl heroin 0.60925114 0.7629001140594482
# fentanyl fent 0.44581997 0.594990074634552
# opioid opioid 1.0000001 1.0
# h and fent h and fent 1.0 1.0000001192092896
# subconscious suboxone 0.6113368 0.12764541804790497
# oxy 30s fakesfentanyl oxy 30s fentanyl 0.8143205 0.6151379942893982
# fent 30’s fentanyl 30 0.4481392 0.6560710668563843
# fentanyl fentanyl 0.9999999 1.0
# fent fentanyl 0.44581997 0.594990074634552
# heroin heroin 1.0 0.9999999403953552
# alcohol alcohol 1.0000001 1.0
# cocaine cocaine 0.9999999 1.0
# blues and bars blues 0.7453164 0.7579206228256226
# blues and bars bars 0.66334254 0.7547569274902344
# blues and bars meth 0.52390337 0.15819531679153442
# blues and bars ice 0.60707766 0.3007701635360718
# h kratom 0.606806 0.15433502197265625
# h h 1.0 1.0000001192092896
# subs kratom 0.64132977 0.1125117763876915
# subs dirty 30s 0.56266874 0.2771579623222351
# heroin heroin 1.0 0.9999999403953552
# heroin heroin 1.0 0.9999999403953552
# kratom kratom 1.0 1.0
# 17 35 41
# relapse event-specific-arguments relapse-substance 0.48571428571289793 0.4146341463404521 0.44736842100176594
# 3 days 3 days 1.0 1.0
# 2 days yesterday and today 0.6538601 0.4147115647792816
# 1 year one year 0.8527212 0.9410743713378906
# few days several days 0.9084104 0.8521144390106201
# 3 to 4 days 34 days 0.7676211 0.7021538019180298
# 6 months 6 months 1.0 1.0
# 2 11 12
# relapse event-specific-arguments relapse-duration 0.18181818181652892 0.16666666666527777 0.17391304342684308
# suboxone script started taking suboxone 0.5959101 0.6484803557395935
# bernese method bernese method 0.9999999 1.0000001192092896
# bridging with percs switching back to suboxone 0.6362139 0.01172318123281002
# taking suboxone taking suboxone again 0.9086514 0.8979825973510742
# support group help quitting with support group help 0.78422713 0.7726240158081055
# suboxone treatment wants to start subacade 0.46962035 0.2799479067325592
# suboxone treatment switching clinics 0.5147058 0.08893216401338577
# kratom bernese method 0.6157966 0.08662057667970657
# suboxone bernese method 0.60902154 0.11415667831897736
# suboxone subs 0.6372401 0.35214412212371826
# narcan suggested to use narcan 0.72465396 0.796481728553772
# trying to take subs trying to switch back to suboxone 0.703525 0.37793999910354614
# taking sub taking more subs 0.7234358 0.8132668733596802
# trying different sleep aids use sleep meds 0.6976338 0.6441724300384521
# trying different sleep aids ambien 0.44812286 0.4378840923309326
# trying different sleep aids benzos 0.5856678 0.07123719900846481
# suboxone using suboxone 0.8965359 0.881891131401062
# suboxone and methadone wants to start moud 0.37482384 0.16163849830627441
# suboxone and methadone start at 24mg 0.37244365 0.2443053126335144
# suboxone and methadone no meth 0.60267967 0.4361519515514374
# suboxone quickmd 0.65537 0.19767093658447266
# suboxone buprenorphine 0.7300226 0.4441099166870117
# 2mg medication 2 mg moud 0.80248594 0.6742839813232422
# methadone plan to use methadone 0.82719845 0.8345564603805542
# 1 20 25
# relapse event-specific-arguments relapse-intervention 0.04999999999975 0.039999999999840004 0.0444444443948642
# 36 hours 36 hours 0.9999999 1.000000238418579
# 26 hours 26 hours after last fent 0.6962218 0.5916523933410645
# 26 hours 1 hour after percs 0.71561867 0.3625604510307312
# one week one week 1.0 1.0000001192092896
# 3 days three days 0.88923156 0.9686784148216248
# at least 72 hours 72 hours 0.83975184 0.8102807998657227
# 7 days 7 days 1.0000001 1.000000238418579
# 7 hours 7hrs 0.7660037 0.8327016830444336
# 24 hours 24 hours 0.9999999 1.0
# 20 hours 20 hours 1.0000001 0.9999999403953552
# 5 11 13
# relapse event-specific-arguments waiting-time 0.45454545454132234 0.38461538461242606 0.4166666666135417
# 33 33 1.0 1.0000001192092896
# 1 2 2
# relapse subject-effect-arguments age 0.499999999975 0.499999999975 0.499999999925
# male male 1.0 1.0
# 1 3 3
# relapse subject-effect-arguments gender 0.3333333333222222 0.3333333333222222 0.3333333332722222
# addiction kratom and thc addict 0.4875885 0.4387704133987427
# fentanyl addiction fentanyl addiction 1.0000001 1.0
# chronic pain from car accident chronic pain from car accident 0.99999994 0.9999998211860657
# arthritis in hips arthritis in hips 0.9999999 1.0
# heroin addiction heroin addiction 1.0000001 1.0000001192092896
# 4 13 14
# relapse subject-effect-arguments conditions 0.3076923076899408 0.2857142857122449 0.2962962962441701
# withdrawals withdrawal symptoms 0.75209516 0.6750657558441162
# unfunctional withdrawal 0.44826767 0.15143314003944397
# sick withdrawal 0.7449503 0.190669983625412
# feeling too good feeling good 0.80115825 0.8202781677246094
# precipitated withdrawal cold turkey withdrawal 0.59179324 0.5898809432983398
# wd symptoms wd symptoms 0.9999999 1.0
# precipitated withdrawal withdrawals 0.5682187 0.6526491045951843
# throw up and nod out throw up and nod out 1.0000001 0.9999998807907104
# withdrawal symptoms normal withdrawal symptoms 0.9092207 0.9262498617172241
# knees aching and hurting sickness 0.5217454 0.20780140161514282
# knees aching and hurting achy knees 0.6863962 0.5760393142700195
# sleeping insomnia 0.54318744 0.6494461297988892
# not feeling cocaine high cant feel cocaine high 0.75926113 0.9116815328598022
# precipitated withdrawal lack of sleep 0.5473531 0.2216104120016098
# sweaty sweaty 1.0000001 1.0
# sweaty cant sit still 0.51109606 0.3057635426521301
# skin crawling skin crawling 1.0 1.0000001192092896
# cant sit still cant sit still 1.0 0.9999999403953552
# weeping due to pain pain 0.6580271 0.4845089614391327
# 5 22 24
# relapse subject-effect-arguments side-effects 0.22727272727169423 0.2083333333324653 0.21739130429697542
# worse than normal too much 0.6282484 0.25706595182418823
# bad high 0.76385975 0.32130658626556396
# stressing me out medium 0.5307454 0.24184633791446686
# bad high 0.76385975 0.32130658626556396
# 0 9 9
# relapse subject-effect-arguments severity 0.0 0.0 0.0
# around 80 hr mark 80 hours ago 0.7225863 0.5233258008956909
# last hour hour ago 0.80620414 0.7713100910186768
# few months few months ago 0.8462985 0.7042762041091919
# day 2 today 0.7390811 0.5192213654518127
# 0 6 6
# relapse subject-effect-arguments start-time 0.0 0.0 0.0
# 20 hours 20 hours 1.0000001 0.9999999403953552
# 1 5 5
# relapse subject-effect-arguments side-effect-duration 0.199999999996 0.199999999996 0.19999999994599998
# suboxone script hot soaks 0.4727911 0.07226268202066422
# suboxone script imodium 0.5923078 0.2263593077659607
# suboxone script distractions 0.54263395 -0.0176938995718956
# suboxone script walks 0.51647633 0.0037844395264983177
# hot soaks hot soaks 0.99999994 1.0
# hot soaks distractions 0.59362084 0.08781875669956207
# hot soaks walks 0.43657553 0.07946085184812546
# imodium imodium 1.0 1.0000001192092896
# imodium walks 0.48289353 0.17693763971328735
# distractions distractions 0.9999999 1.0
# walks walks 1.0 1.0000001192092896
# bernese method bernese method 0.9999999 1.0000001192092896
# taper down benzos suboxone 0.69190377 0.23231200873851776
# taper down benzos oxycodone 0.58856446 0.28187623620033264
# taper down benzos diliduan 0.38512367 0.16343817114830017
# suboxone suboxone 1.0 1.0
# suboxone diliduan 0.42774695 0.20863020420074463
# ashton method oxycodone 0.3779421 0.049360040575265884
# ashton method diliduan 0.39035955 0.09212271124124527
# taking 4 15mg percs to make first 24 hours bearable wait 24 hours 0.59174913 0.27240636944770813
# taking 4 15mg percs to make first 24 hours bearable start off with 1 mg 0.61321604 0.5122866630554199
# using bupe patches wait 5 days for morphine to work 0.54357857 0.15511468052864075
# taking subs to reduce oxy effects taking less subs and observing how you feel 0.6558262 0.49114882946014404
# support group help quitting with support group help 0.78422713 0.7726240158081055
# subs need more than 2mg of subs 0.5681388 0.5150091648101807
# thc need more than 2mg of subs 0.43290687 0.1518377661705017
# suboxone and sublocade treatment switching clinics 0.45804858 0.039805639535188675
# sub taper regular supply of subs 0.6030479 0.3462325930595398
# taking suboxone dose planning to change subs dose 0.6485254 0.5270959138870239
# kratom bernese method 0.6157966 0.08662057667970657
# suboxone bernese method 0.60902154 0.11415667831897736
# bernese method bernese method 0.9999999 1.0000001192092896
# suboxone induction quitting cold turkey 0.57896096 0.04205338656902313
# have narcan on hand suggested to use narcan 0.62104964 0.875446081161499
# taking suboxone bernese method 0.54978144 0.10320813208818436
# bernese method bernese method 0.9999999 1.0000001192092896
# took sub more subs 0.72714895 0.5898299217224121
# took sub comfort meds 0.51439375 0.038305461406707764
# took more subs more subs 0.8511328 0.8509616255760193
# took more subs comfort meds 0.5926298 0.07724308967590332
# tried melatonin take sleep meds 0.6957094 0.6821472644805908
# tried melatonin ambien 0.452365 0.35850733518600464
# tried melatonin benzo 0.55261165 0.2190515398979187
# seroquel take sleep meds 0.52792275 0.2404874861240387
# seroquel ambien 0.6153807 0.3988839089870453
# seroquel benzo 0.721472 0.5294622182846069
# trazadone take sleep meds 0.52715224 0.08362098038196564
# trazadone ambien 0.5880398 0.3745473623275757
# trazadone benzo 0.7220043 0.4754028916358948
# zoloft take sleep meds 0.5147469 0.2398744821548462
# zoloft ambien 0.50608253 0.397222101688385
# zoloft benzo 0.5713928 0.39603668451309204
# weed take sleep meds 0.5502763 0.10839378088712692
# weed ambien 0.5207935 0.3316512703895569
# weed benzo 0.81156623 0.45555102825164795
# using suboxone to get off fentanyl get suboxone from doctors in area 0.6831275 0.5800038576126099
# start with low dose take 24mg for first month 0.65577143 0.5873842835426331
# start with low dose then 8mg or less 0.6235027 0.5170180797576904
# start with low dose alcohol can help but no meth 0.6083329 0.4246892035007477
# wait between doses take 24mg for first month 0.5765189 0.47833141684532166
# wait between doses then 8mg or less 0.5723533 0.4493904709815979
# wait between doses alcohol can help but no meth 0.511986 0.28402087092399597
# taking buprenorphine tablets wait 24 hours after last opiate use 0.66924775 0.4832400381565094
# dissolving under tongue wait 24 hours after last opiate use 0.5848662 0.11889346688985825
# using kratom use kratom 0.9380358 0.9669150114059448
# took 2mg moud intake 0.6195193 0.1964622139930725
# get on methadone planning to use methadone 0.79225373 0.8340611457824707
# ordered kratom kratom while on suboxone 0.75805044 0.5358110666275024
# taking suboxone kratom while on suboxone 0.60916936 0.7000879049301147
# 8 42 36
# relapse subject-effect-arguments intervention 0.19047619047573694 0.22222222222160493 0.20512820507797497
# results-Llama-3-70B-Instructbatch_question_guided_0.99.json
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Results/1-new-results-Llama-3-70B-Instruct.json
# batch description_guided 0.749
# individual with anxiety and butterflies individual altered treatment due to withdrawals 0.7443658 0.27354496717453003
# individual reducing benzodiazepine use individual seeking advice on splitting tablets 0.5834509 0.3620055317878723
# individual taking sublingual strips individual hating taste of strips asking about snorting 0.6690772 0.4158536493778229
# individual with 15 years of suboxone use individual seeking information on tramadol and suboxone use 0.87868506 0.49377942085266113
# individual with heavy past opioid experience individual wants to start taking suboxone 0.66858226 0.37580862641334534
# individual switching from methadone to subs individual switching from methadone to subs 0.9999999 1.0
# individual trying to quit individual asking about cutting strips 0.7723751 0.23328596353530884
# person taking 8mg medication daily individual who accidentally double dosed 0.746095 0.3377828299999237
# individual taking pillsstrips individual asking for difference between strips and pills 0.7844571 0.6779167652130127
# individual taking 1mg bupe individual considering boofing bupe 0.7303688 0.528030514717102
# individual quitting percs indivudal who just quit percs fearing suboxone treatment 0.6416147 0.5972685813903809
# young individual taking 90mg addys 0.47676635 -0.024622054770588875
# 155 lbs individual taking 90mg addys 0.5620976 0.10847145318984985
# fast metabolism individual taking 90mg addys 0.5276619 0.20254306495189667
# individual switching from methadone to suboxone individual switching from methadone to suboxone 0.9999999 1.0
# individual taking suboxone individual who got high from suboxone and wants to take more 0.77076674 0.838104784488678
# individual taking suboxone individual willing to remove nalaxone from suboxone to avoid withdrawals 0.78377545 0.6825829148292542
# individual taking 8mg medication daily individual who always wants to take thier subs 0.59587765 0.22561860084533691
# individual tapering down medication individual tapering medication dosage 0.85198474 0.8303743600845337
# ...
# sweaty sweaty 1.0000001 1.0
# sweaty cannot sit still 0.57161814 0.281718909740448
# skin crawling skin crawling 1.0 1.0000001192092896
# cant sit still cannot sit still 0.7429808 0.9561108946800232
# sickness and arthritis in hips experiencing sickness 0.5825036 0.5005788803100586
# no withdrawal symptoms zero wd symptoms 0.6008471 0.4272141754627228
# suboxone may block kratom effects suboxone may block effects of kratom 0.96378946 0.9869282245635986
# 3 22 22
# relapse main-arguments effects 0.13636363636301654 0.13636363636301654 0.13636363631301654
# opioid use disorder percocet addiction 0.67751414 0.46697431802749634
# opioid use disorder fentanyl addiction 0.6314642 0.568220317363739
# opiate and benzo addiction was on opiates and benzos for 10 years 0.7568981 0.749589204788208
# opiate and benzo addiction then methadone and clonazepam 0.7157947 0.48930901288986206
# opioid use disorder recovering from opioid use disorder 0.883915 0.8550974130630493
# opioid use disorder back and forth between h and subs 0.4013769 -0.007160824723541737
# kratom addiction kratom and thc addict 0.81342375 0.8263598680496216
# opioid use disorder drank alcohol 0.5174067 0.12897968292236328
# opioid withdrawal withdrawal from substance 0.6862037 0.709307074546814
# opioid use disorder heroin use disorder 0.77379644 0.7169877886772156
# opioid use disorder fent 0.38782609 0.14119595289230347
# opioid use disorder opioid 0.71936935 0.7944380044937134
# opioid use disorder off of subs for 7 days 0.45320418 -0.018884995952248573
# kratom dependency kratom 0.8761625 0.6785656213760376
# opioid use disorder suboxone use with low tolerance 0.5684133 0.25436270236968994
# opioid use disorder been on suboxone since august of 2021 0.4600666 0.2905558943748474
# opioid use disorder recovered from fentanyl 30s use 0.47737235 0.28198516368865967
# opioid use disorder weed and fent addict 0.53079706 0.45559579133987427
# opioid use disorder fenta addiction 0.47549427 0.5261602997779846
# fentanyl addiction fentanyl addiction 1.0000001 1.0
# opioid use disorder using blues 0.3911443 0.10040435940027237
# opioid use disorder bars 0.40705448 0.04028736427426338
# opioid use disorder and ice 0.3673185 0.026028724387288094
# opioid use disorder opiate use disorder 0.89067954 0.8772305250167847
# opioid withdrawal recovering from dirty 30s addiction 0.562251 0.36564522981643677
# opioid use disorder relapsed on heroin 0.6247264 0.49254661798477173
# heroin addiction recovering from heroin addiction 0.8492157 0.8075442314147949
# opioid addiction using suboxone 0.5155739 0.22378942370414734
# 1 25 28
# relapse event-specific-arguments condition 0.039999999999840004 0.03571428571415817 0.03773584900662158
# morphine prescription morphine prescription 0.99999994 1.0000001192092896
# availability of fentanyl shitty fent replacing good h 0.47310132 0.2750357687473297
# missed appointment fathers day 0.6653464 0.26500165462493896
# sleeping issues insomnia 0.7025203 0.6100912690162659
# lack of research wanting to quit suboxone 0.52976197 0.026936626061797142
# pain pain 1.0000001 1.0000001192092896
# 2 12 13
# relapse event-specific-arguments trigger 0.16666666666527777 0.1538461538449704 0.1599999999488
# methadone and clonazepam suboxone 0.45848858 0.3817923069000244
# suboxone sub 0.6590155 0.37370967864990234
# bupe patches bupe patch 0.94221675 0.9494718313217163
# suboxone suboxone 1.0 1.0
# thc subs 0.6120343 0.2553676962852478
# suboxone suboxone 1.0 1.0
# gabapentin subs 0.40028292 0.01751042529940605
# gabapentin gabapentin 1.0 1.000000238418579
# gabapentin muscle relaxers 0.6194408 0.3376624584197998
# xanax subs 0.41115862 0.18329769372940063
# xanax xanax 1.0000001 0.9999999403953552
# muscle relaxers subs 0.4536728 0.08415370434522629
# muscle relaxers muscle relaxers 0.99999994 1.0000001192092896
# suboxone 812mg suboxone 0.82027054 0.8272020816802979
# suboxone suboxone 1.0 1.0
# subs subs 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# sub subs 0.79202896 0.8165544271469116
# suboxone suboxone 1.0 1.0
# suboxone ambien 0.55143833 0.34220874309539795
# suboxone benzos 0.80525124 0.35993492603302
# suboxone suboxone 1.0 1.0
# suboxone suboxone 1.0 1.0
# kratom and h buprenorphine 0.48232043 0.23004800081253052
# kratom suboxone 0.68420106 0.28886210918426514
# suboxone suboxone 1.0 1.0
# subutex subutex 1.0 0.9999999403953552
# buprenophine buprenophine 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# 16 34 36
# relapse event-specific-arguments existing/current-medications 0.4705882352927335 0.44444444444320985 0.4571428570915918
# percs percocet 0.6829824 0.5684541463851929
# fentanyl pressed 30s 0.30653974 0.10178772360086441
# kratom kratom 1.0 1.0
# kratom diluadin 0.68895537 0.20705321431159973
# subs oxy 0.59775823 0.24639689922332764
# subs diluadin 0.6078126 0.13063856959342957
# oxy oxy 1.0000001 1.0
# diluadin diluadin 1.0000001 1.0000001192092896
# fent fent and percs 0.72123665 0.659132719039917
# morphine morphine 1.0 1.0
# oxycodone oxycodone and percocet 0.9128873 0.8080217838287354
# heroin heroin 1.0 0.9999999403953552
# kratom thc 0.6397693 0.19885066151618958
# beer alcohol 0.89537066 0.7729755640029907
# kratom kratom 1.0 1.0
# dirty 30s dirty 30s 1.0 1.0
# heroin or fentanyl heroin 0.60925114 0.7629001140594482
# fentanyl fent 0.44581997 0.594990074634552
# opioid opioid 1.0000001 1.0
# h and fent h and fent 1.0 1.0000001192092896
# subconscious suboxone 0.6113368 0.12764541804790497
# oxy 30s fakesfentanyl oxy 30s fentanyl 0.8143205 0.6151379942893982
# fent 30’s fentanyl 30 0.4481392 0.6560710668563843
# fentanyl fentanyl 0.9999999 1.0
# fent fentanyl 0.44581997 0.594990074634552
# heroin heroin 1.0 0.9999999403953552
# alcohol alcohol 1.0000001 1.0
# cocaine cocaine 0.9999999 1.0
# blues and bars blues 0.7453164 0.7579206228256226
# blues and bars bars 0.66334254 0.7547569274902344
# blues and bars meth 0.52390337 0.15819531679153442
# blues and bars ice 0.60707766 0.3007701635360718
# h kratom 0.606806 0.15433502197265625
# h h 1.0 1.0000001192092896
# subs kratom 0.64132977 0.1125117763876915
# subs dirty 30s 0.56266874 0.2771579623222351
# heroin heroin 1.0 0.9999999403953552
# heroin heroin 1.0 0.9999999403953552
# kratom kratom 1.0 1.0
# 17 35 41
# relapse event-specific-arguments relapse-substance 0.48571428571289793 0.4146341463404521 0.44736842100176594
# 3 days 3 days 1.0 1.0
# 2 days yesterday and today 0.6538601 0.4147115647792816
# 1 year one year 0.8527212 0.9410743713378906
# few days several days 0.9084104 0.8521144390106201
# 3 to 4 days 34 days 0.7676211 0.7021538019180298
# 6 months 6 months 1.0 1.0
# 2 11 12
# relapse event-specific-arguments relapse-duration 0.18181818181652892 0.16666666666527777 0.17391304342684308
# suboxone script started taking suboxone 0.5959101 0.6484803557395935
# bernese method bernese method 0.9999999 1.0000001192092896
# bridging with percs switching back to suboxone 0.6362139 0.01172318123281002
# taking suboxone taking suboxone again 0.9086514 0.8979825973510742
# support group help quitting with support group help 0.78422713 0.7726240158081055
# suboxone treatment wants to start subacade 0.46962035 0.2799479067325592
# suboxone treatment switching clinics 0.5147058 0.08893216401338577
# kratom bernese method 0.6157966 0.08662057667970657
# suboxone bernese method 0.60902154 0.11415667831897736
# suboxone subs 0.6372401 0.35214412212371826
# narcan suggested to use narcan 0.72465396 0.796481728553772
# trying to take subs trying to switch back to suboxone 0.703525 0.37793999910354614
# taking sub taking more subs 0.7234358 0.8132668733596802
# trying different sleep aids use sleep meds 0.6976338 0.6441724300384521
# trying different sleep aids ambien 0.44812286 0.4378840923309326
# trying different sleep aids benzos 0.5856678 0.07123719900846481
# suboxone using suboxone 0.8965359 0.881891131401062
# suboxone and methadone wants to start moud 0.37482384 0.16163849830627441
# suboxone and methadone start at 24mg 0.37244365 0.2443053126335144
# suboxone and methadone no meth 0.60267967 0.4361519515514374
# suboxone quickmd 0.65537 0.19767093658447266
# suboxone buprenorphine 0.7300226 0.4441099166870117
# 2mg medication 2 mg moud 0.80248594 0.6742839813232422
# methadone plan to use methadone 0.82719845 0.8345564603805542
# 1 20 25
# relapse event-specific-arguments relapse-intervention 0.04999999999975 0.039999999999840004 0.0444444443948642
# 36 hours 36 hours 0.9999999 1.000000238418579
# 26 hours 26 hours after last fent 0.6962218 0.5916523933410645
# 26 hours 1 hour after percs 0.71561867 0.3625604510307312
# one week one week 1.0 1.0000001192092896
# 3 days three days 0.88923156 0.9686784148216248
# at least 72 hours 72 hours 0.83975184 0.8102807998657227
# 7 days 7 days 1.0000001 1.000000238418579
# 7 hours 7hrs 0.7660037 0.8327016830444336
# 24 hours 24 hours 0.9999999 1.0
# 20 hours 20 hours 1.0000001 0.9999999403953552
# 5 11 13
# relapse event-specific-arguments waiting-time 0.45454545454132234 0.38461538461242606 0.4166666666135417
# 33 33 1.0 1.0000001192092896
# 1 2 2
# relapse subject-effect-arguments age 0.499999999975 0.499999999975 0.499999999925
# male male 1.0 1.0
# 1 3 3
# relapse subject-effect-arguments gender 0.3333333333222222 0.3333333333222222 0.3333333332722222
# addiction kratom and thc addict 0.4875885 0.4387704133987427
# fentanyl addiction fentanyl addiction 1.0000001 1.0
# chronic pain from car accident chronic pain from car accident 0.99999994 0.9999998211860657
# arthritis in hips arthritis in hips 0.9999999 1.0
# heroin addiction heroin addiction 1.0000001 1.0000001192092896
# 4 13 14
# relapse subject-effect-arguments conditions 0.3076923076899408 0.2857142857122449 0.2962962962441701
# withdrawals withdrawal symptoms 0.75209516 0.6750657558441162
# unfunctional withdrawal 0.44826767 0.15143314003944397
# sick withdrawal 0.7449503 0.190669983625412
# feeling too good feeling good 0.80115825 0.8202781677246094
# precipitated withdrawal cold turkey withdrawal 0.59179324 0.5898809432983398
# wd symptoms wd symptoms 0.9999999 1.0
# precipitated withdrawal withdrawals 0.5682187 0.6526491045951843
# throw up and nod out throw up and nod out 1.0000001 0.9999998807907104
# withdrawal symptoms normal withdrawal symptoms 0.9092207 0.9262498617172241
# knees aching and hurting sickness 0.5217454 0.20780140161514282
# knees aching and hurting achy knees 0.6863962 0.5760393142700195
# sleeping insomnia 0.54318744 0.6494461297988892
# not feeling cocaine high cant feel cocaine high 0.75926113 0.9116815328598022
# precipitated withdrawal lack of sleep 0.5473531 0.2216104120016098
# sweaty sweaty 1.0000001 1.0
# sweaty cant sit still 0.51109606 0.3057635426521301
# skin crawling skin crawling 1.0 1.0000001192092896
# cant sit still cant sit still 1.0 0.9999999403953552
# weeping due to pain pain 0.6580271 0.4845089614391327
# 5 22 24
# relapse subject-effect-arguments side-effects 0.22727272727169423 0.2083333333324653 0.21739130429697542
# worse than normal too much 0.6282484 0.25706595182418823
# bad high 0.76385975 0.32130658626556396
# stressing me out medium 0.5307454 0.24184633791446686
# bad high 0.76385975 0.32130658626556396
# 0 9 9
# relapse subject-effect-arguments severity 0.0 0.0 0.0
# around 80 hr mark 80 hours ago 0.7225863 0.5233258008956909
# last hour hour ago 0.80620414 0.7713100910186768
# few months few months ago 0.8462985 0.7042762041091919
# day 2 today 0.7390811 0.5192213654518127
# 0 6 6
# relapse subject-effect-arguments start-time 0.0 0.0 0.0
# 20 hours 20 hours 1.0000001 0.9999999403953552
# 1 5 5
# relapse subject-effect-arguments side-effect-duration 0.199999999996 0.199999999996 0.19999999994599998
# suboxone script hot soaks 0.4727911 0.07226268202066422
# suboxone script imodium 0.5923078 0.2263593077659607
# suboxone script distractions 0.54263395 -0.0176938995718956
# suboxone script walks 0.51647633 0.0037844395264983177
# hot soaks hot soaks 0.99999994 1.0
# hot soaks distractions 0.59362084 0.08781875669956207
# hot soaks walks 0.43657553 0.07946085184812546
# imodium imodium 1.0 1.0000001192092896
# imodium walks 0.48289353 0.17693763971328735
# distractions distractions 0.9999999 1.0
# walks walks 1.0 1.0000001192092896
# bernese method bernese method 0.9999999 1.0000001192092896
# taper down benzos suboxone 0.69190377 0.23231200873851776
# taper down benzos oxycodone 0.58856446 0.28187623620033264
# taper down benzos diliduan 0.38512367 0.16343817114830017
# suboxone suboxone 1.0 1.0
# suboxone diliduan 0.42774695 0.20863020420074463
# ashton method oxycodone 0.3779421 0.049360040575265884
# ashton method diliduan 0.39035955 0.09212271124124527
# taking 4 15mg percs to make first 24 hours bearable wait 24 hours 0.59174913 0.27240636944770813
# taking 4 15mg percs to make first 24 hours bearable start off with 1 mg 0.61321604 0.5122866630554199
# using bupe patches wait 5 days for morphine to work 0.54357857 0.15511468052864075
# taking subs to reduce oxy effects taking less subs and observing how you feel 0.6558262 0.49114882946014404
# support group help quitting with support group help 0.78422713 0.7726240158081055
# subs need more than 2mg of subs 0.5681388 0.5150091648101807
# thc need more than 2mg of subs 0.43290687 0.1518377661705017
# suboxone and sublocade treatment switching clinics 0.45804858 0.039805639535188675
# sub taper regular supply of subs 0.6030479 0.3462325930595398
# taking suboxone dose planning to change subs dose 0.6485254 0.5270959138870239
# kratom bernese method 0.6157966 0.08662057667970657
# suboxone bernese method 0.60902154 0.11415667831897736
# bernese method bernese method 0.9999999 1.0000001192092896
# suboxone induction quitting cold turkey 0.57896096 0.04205338656902313
# have narcan on hand suggested to use narcan 0.62104964 0.875446081161499
# taking suboxone bernese method 0.54978144 0.10320813208818436
# bernese method bernese method 0.9999999 1.0000001192092896
# took sub more subs 0.72714895 0.5898299217224121
# took sub comfort meds 0.51439375 0.038305461406707764
# took more subs more subs 0.8511328 0.8509616255760193
# took more subs comfort meds 0.5926298 0.07724308967590332
# tried melatonin take sleep meds 0.6957094 0.6821472644805908
# tried melatonin ambien 0.452365 0.35850733518600464
# tried melatonin benzo 0.55261165 0.2190515398979187
# seroquel take sleep meds 0.52792275 0.2404874861240387
# seroquel ambien 0.6153807 0.3988839089870453
# seroquel benzo 0.721472 0.5294622182846069
# trazadone take sleep meds 0.52715224 0.08362098038196564
# trazadone ambien 0.5880398 0.3745473623275757
# trazadone benzo 0.7220043 0.4754028916358948
# zoloft take sleep meds 0.5147469 0.2398744821548462
# zoloft ambien 0.50608253 0.397222101688385
# zoloft benzo 0.5713928 0.39603668451309204
# weed take sleep meds 0.5502763 0.10839378088712692
# weed ambien 0.5207935 0.3316512703895569
# weed benzo 0.81156623 0.45555102825164795
# using suboxone to get off fentanyl get suboxone from doctors in area 0.6831275 0.5800038576126099
# start with low dose take 24mg for first month 0.65577143 0.5873842835426331
# start with low dose then 8mg or less 0.6235027 0.5170180797576904
# start with low dose alcohol can help but no meth 0.6083329 0.4246892035007477
# wait between doses take 24mg for first month 0.5765189 0.47833141684532166
# wait between doses then 8mg or less 0.5723533 0.4493904709815979
# wait between doses alcohol can help but no meth 0.511986 0.28402087092399597
# taking buprenorphine tablets wait 24 hours after last opiate use 0.66924775 0.4832400381565094
# dissolving under tongue wait 24 hours after last opiate use 0.5848662 0.11889346688985825
# using kratom use kratom 0.9380358 0.9669150114059448
# took 2mg moud intake 0.6195193 0.1964622139930725
# get on methadone planning to use methadone 0.79225373 0.8340611457824707
# ordered kratom kratom while on suboxone 0.75805044 0.5358110666275024
# taking suboxone kratom while on suboxone 0.60916936 0.7000879049301147
# 8 42 36
# relapse subject-effect-arguments intervention 0.19047619047573694 0.22222222222160493 0.20512820507797497
# results-Llama-3-70B-Instructbatch_question_guided_0.99.json
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Results/2-new-results-Llama-3-70B-Instruct.json
# CPU times: user 1h 51min 43s, sys: 13min 32s, total: 2h 5min 16s
# Wall time: 5h 34min 26s

# %% [markdown]
# printing to understanding the nesting in the results dict

# %%
print(results_dict.keys())
print(results_dict['batch_description_guided_0.749'].keys())
print(results_dict['batch_description_guided_0.749']['tapering'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments']['effects'])
# Out:
# dict_keys(['batch_description_guided_0.749', 'batch_description_guided_0.99', 'batch_question_guided_0.749', 'batch_question_guided_0.99', 'isolated_description_guided_0.749', 'isolated_description_guided_0.99', 'isolated_question_guided_0.749', 'isolated_question_guided_0.99'])
# dict_keys(['taking-moud', 'tapering', 'relapse'])
# dict_keys(['main-arguments', 'event-specific-arguments', 'subject-effect-arguments'])
# dict_keys(['subject/patient', 'effects', 'tapering-event'])
# [[0.4583333333314236, 0.54999999999725, 0.49999999994814043], [11, 24, 20]]
