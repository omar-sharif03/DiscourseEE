# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %%capture
# !pip install transformers # If you are using collab, "!" is required to download
# !pip install bert-score
# !pip install -U sentence-transformers

import nltk
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer, PorterStemmer

# Download NLTK resources
nltk.download('punkt')
nltk.download('wordnet')

# %%
import os, json
import numpy as np
from argparse import ArgumentParser
from tqdm import tqdm
from collections import defaultdict
import pandas as pd
from pprint import pprint
import re, string
from google.colab import files

from transformers import BertTokenizer, BertModel
from sentence_transformers import SentenceTransformer, util
import torch
import copy

# %% [markdown]
# ## Calculating evaluation scores

# %%
def read_json_file(name):
    with open(name, 'r') as f:
        data = json.load(f)
        return data

def save_json(json_data, file_name):
    json_data = json.dumps(json_data)
    print(file_name)
    with open(file_name, "w") as json_file:
          json_file.write(json_data)

# %%
# def perform_lemmatization(text):

#     # Tokenize the text into words
#     words = word_tokenize(text)
#     lemmatizer = WordNetLemmatizer()
#     stemmer = PorterStemmer()
#     lemmatized_and_stemmed_words = [(lemmatizer.lemmatize(word), stemmer.stem(word)) for word in words]

#     lemmatized_words, stemmed_words = zip(*lemmatized_and_stemmed_words)
#     lemmatized_text = ' '.join(lemmatized_words)
#     stemmed_text = ' '.join(stemmed_words)

#     # print("Original text:", text)
#     # print("Lemmatized text:", lemmatized_text)
#     # print("Stemmed text:", stemmed_text)
#     return stemmed_text

def clac_sbert_score(text1, text2):
    model = SentenceTransformer("all-MiniLM-L6-v2")

    embeddings1 = model.encode(text1, convert_to_tensor=True)
    embeddings2 = model.encode(text2, convert_to_tensor=True)

    cosine_score = util.cos_sim(embeddings1, embeddings2)
    #print(cosine_score.item())
    return cosine_score.item()

def calc_cosine_similarity(text1, text2):

    tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")
    model = BertModel.from_pretrained("bert-base-uncased")

    # text1 = perform_lemmatization(text1)
    # text2 = perform_lemmatization(text2)

    inputs1 = tokenizer(text1, return_tensors="pt", padding=True, truncation=True)
    inputs2 = tokenizer(text2, return_tensors="pt", padding=True, truncation=True)

    outputs1 = model(**inputs1)
    outputs2 = model(**inputs2)

    embeddings1 = outputs1.last_hidden_state.mean(dim=1).detach().numpy()
    embeddings2 = outputs2.last_hidden_state.mean(dim=1).detach().numpy()

    #Calculate cosine similarity
    similarity = np.dot(embeddings1, embeddings2.T) / (np.linalg.norm(embeddings1) * np.linalg.norm(embeddings2))

    #print("Similarity between the texts:", similarity)
    return similarity[0][0]

# %%
def is_null_or_empty(string):
    return string is None or string.strip().lower() == 'null' or string.strip() == ''

def normalize_string(s):
      def remove_articles(text):
          regex = re.compile(r'\b(a|an|the)\b', re.UNICODE)
          return re.sub(regex, ' ', text)
      def white_space_fix(text):
          return ' '.join(text.split())
      def remove_punc(text):
          exclude = set(string.punctuation)
          return ''.join(ch for ch in text if ch not in exclude)
      def lower(text):
          return text.lower()
      return white_space_fix(remove_articles(remove_punc(lower(s))))


def calculate_score(predictions, ground_truth_labels, similarity_threshold):
    true_pos, pred_count, gtruth_count = 0, len(predictions), len(ground_truth_labels)

    if ((len(ground_truth_labels)==1 and is_null_or_empty(ground_truth_labels[0]))): #only not calculating when ground-truth is null
        #print("xxx ", predictions, labels) #(len(predictions)==1 and is_null_or_empty(predictions[0]))
        return 0, 0, 0 #skipping this sample
    else:
        actual_labels = copy.deepcopy(ground_truth_labels)
        # print(predictions, actual_labels)
        # print(len(predictions), len(actual_labels))
        for p in predictions:
            for g in actual_labels:
                if(g.strip() == ''): gtruth_count -=1 ## if any ground-truth is empty reducing that count.
                if(is_null_or_empty(p) or is_null_or_empty(g)): continue ##if prediction/ground-truth is null then skip
                np, ng = normalize_string(p), normalize_string(g)
                sim_value = calc_cosine_similarity(np,ng)
                sbert_score = clac_sbert_score(np, ng)
                print(np, ng, sim_value, sbert_score)
                if(sim_value>similarity_threshold or sbert_score>similarity_threshold):
                    true_pos += 1
                    actual_labels.remove(g)
        # print(predictions, labels)
        # print(true_pos, pred_count, gtruth_count)
        return true_pos, pred_count, gtruth_count

def calc_precision_recall_f1(true_pos, pred_count, gtruth_count):
    print(true_pos, pred_count, gtruth_count)
    precision = true_pos/(pred_count + 1e-10)
    recall = true_pos/(gtruth_count + 1e-10)
    f1 = 2 * precision * recall / (precision + recall + 1e-10)
    return precision, recall, f1

# %%
def select_event_specific_data(event, data):
    ev_data = []
    for dt in data:
        if event==dt['label']:
            ev_data.append(dt)
    return ev_data

def calc_results(all_data, event_types, arg_types, events_roles, pred_name, gtruth_name, similarity_threshold):
    results = {}
    for event in event_types:
        results[event] = {}
        for arg_type in arg_types:
            results[event][arg_type] = {}
            arguments = list(events_roles[event][arg_type].keys())
            for arg in arguments:
                tp, pc, gc = 0, 0, 0 #initialize the true_positive, pred_count, ground_truth-count for each arguments
                event_specifc_data = select_event_specific_data(event, all_data) ##geting the data for a specific event type.
                for dt in event_specifc_data:
                    label = dt['label']
                    pred_list = dt[pred_name][arg_type][arg] #predictions
                    gtruth_list = dt[gtruth_name][arg_type][arg] #ground-truth arguments
                    #print(pred_list, gtruth_list)
                    true_pos, pred_count, gtruth_count = 0, 0, 0
                    try:
                       true_pos, pred_count, gtruth_count = calculate_score(pred_list,
                                                                         gtruth_list, similarity_threshold)
                    except:
                        print(event, arg_type, arg)
                        print(pred_list, gtruth_list)
                        print("Error occured at", dt['doc_id'])

                    tp+= true_pos
                    pc+= pred_count
                    gc+= gtruth_count
                if(gc==0):
                    continue #skiping those values, where we do not have any ground truth.

                precision, recall, f1 = calc_precision_recall_f1(tp, pc, gc)
                print(event, arg_type, arg, precision, recall, f1)
                #saving the values in two items is a list
                #first item has (precision, recall, f1 scores) #second item has (true_pos, pred_count, ground_truth_count values)
                results[event][arg_type][arg]= [[precision, recall, f1], [tp, pc, gc]]

    return results

# %%
# %%time

events_roles = read_json_file('role_definitions.json')

prompt_types = ['batch'] #['batch', 'isolated']
exp_types = ['description_guided', 'question_guided']
event_types = ['taking-moud', 'tapering', 'relapse']
arg_types = ['main-arguments', 'event-specific-arguments', 'subject-effect-arguments']
similarity_threshold = [0.749, 0.99]

number = '1'
name = 'Llama-3-8B-Instruct'
folder_path = 'Argument-Extraction-Predictions'
file_name = f'{number}-processed-{name}_test_100_predictions.json'
print(os.path.join(folder_path, file_name))
all_data = read_json_file(os.path.join(folder_path, file_name))

print(all_data[0].keys())
print(len(all_data))
# Out:
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Predictions/1-processed-Llama-3-8B-Instruct_test_100_predictions.json
# dict_keys(['doc_id', 'id', 'text1', 'text2', 'label', 'thread-length', 'ground-truth-arguments', 'raw-batch_description_guided-predictions', 'raw-batch_question_guided-predictions', 'processed-batch_description_guided-predictions', 'processed-batch_question_guided-predictions'])
# 100
# CPU times: user 26 ms, sys: 3.97 ms, total: 29.9 ms
# Wall time: 1.68 s

# %%
# %%time
numbers = ['0', '1', '2']

for number in numbers:
    file_name = f'{number}-processed-{name}_test_100_predictions.json'
    all_data = read_json_file(os.path.join(folder_path, file_name))

    results_dict = {}
    for p_type in prompt_types:
          for e_type in exp_types:
              g_name = 'ground-truth-arguments'
              p_name = f'processed-{p_type}_{e_type}-predictions'
              for s_t in similarity_threshold:
                  print(p_type, e_type, s_t)
                  results = calc_results(all_data, event_types, arg_types, events_roles,
                            p_name, g_name, s_t)
                  save_json(results, f'results-{name}{p_type}_{e_type}_{s_t}.json')
                  results_dict[f'{p_type}_{e_type}_{s_t}']=results


    result_folder_path = 'Argument-Extraction-Results'
    save_json(results_dict, os.path.join(folder_path,f'{number}-new-results-{name}.json'))
# Out:
# batch description_guided 0.749
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Streaming output truncated to the last 5000 lines.
# tapering subject-effect-arguments start-time 0.16666666666388888 0.16666666666388888 0.16666666661388888
# 3 days since friday 0.7055432 0.5238864421844482
# 17 days 17 days 1.0 1.0
# 1 3 3
# tapering subject-effect-arguments side-effect-duration 0.3333333333222222 0.3333333333222222 0.3333333332722222
# tapering dose by 4mg day give taper two weeks to stabalize 0.7245973 0.39732620120048523
# taking another 2mg suggested to make 2mg last 4 0.68896085 0.7539603114128113
# snorting suboxone quitting suboxone and snorting 0.8771032 0.871834933757782
# kratom taking caution using kratom 0.6896595 0.7595901489257812
# time taking caution using kratom 0.45612243 -0.017250683158636093
# 6mg of suboxone taking 6mg suboxone or exercising 0.80560195 0.8076955080032349
# tried sleeping medicine with no luck phenibutweedbenzos 0.49509203 0.1314089298248291
# sinus meds netty pot and ibuprofenacetaminophen before dosing 0.5201631 0.17810463905334473
# netty pot netty pot and ibuprofenacetaminophen before dosing 0.31423795 0.5950645208358765
# ibuprofen or acetaminophen before dosing netty pot and ibuprofenacetaminophen before dosing 0.9566869 0.7378914952278137
# trying to taper off suboxone kratom and benzos 0.72321 0.19487404823303223
# trying different doses kratom and benzos 0.55444705 0.29283010959625244
# proper taper and after care used kratom to get off suboxone 0.54809755 0.09696199744939804
# exercise tramadol 0.6425554 0.2787035405635834
# exercise exercise 0.9999999 1.0
# exercise vitamins 0.6969115 0.16704267263412476
# natural sleep aids tramadol 0.6417817 0.1556248664855957
# natural sleep aids natural sleep aid 0.92738754 0.9280279278755188
# natural sleep aids vitamins 0.6801343 0.1871732920408249
# vitamins tramadol 0.5397529 0.13178053498268127
# vitamins natural sleep aid 0.6733579 0.1948312669992447
# vitamins vitamins 1.0 1.0
# low dose opiatebenzos tramadol 0.47220933 0.35578322410583496
# low dose opiatebenzos natural sleep aid 0.68666077 0.12440219521522522
# kratom get off subsgo to program 0.66832143 0.10457468032836914
# what measures are taken to address or reduce side effects getting shot 0.43815175 0.05902082845568657
# 2 20 16
# tapering subject-effect-arguments intervention 0.0999999999995 0.12499999999921876 0.11111111106111111
# individual experiencing relapse individual quitting percs 0.5551893 0.35351118445396423
# 22yearold male 22 years old male addicted to fentanyl 0.50828004 0.27136462926864624
# 22yearold male wants to start bernese method 0.54084355 0.06923206150531769
# 110115lbs 22 years old male addicted to fentanyl 0.4916427 0.1162964403629303
# 110115lbs wants to start bernese method 0.49265254 0.017210453748703003
# individual relapsed on kratom and other substances individual relapsed on with multiple substances 0.90346587 0.7206258773803711
# individual is still experiencing withdrawal symptoms individual asking for timing to take subs after relapse 0.760939 0.3948739767074585
# individual experiencing relapse individual eager to enjoy relapsing on bupe patches 0.60390425 0.4140337109565735
# individual taking oxycodone and suboxone individual relapses with oxycodone and percocet 0.8505413 0.6592695713043213
# individual is struggling with addiction person quitting h with support group help 0.7148984 0.35759836435317993
# individual struggling with addiction for 5 years individual who wants to start subs 0.6472016 0.1721293330192566
# missed appointment and had few beers individual relapsed with beers and wants to taper with subacade 0.7012473 0.43318623304367065
# individual experiencing withdrawal indivdual took kratom during withdrawal treatment 0.5451817 0.4784061908721924
# ive been on 812mg day for about year individual who relapsed after being on suboxone for past year 0.60440284 0.3590058386325836
# individual experiencing fentanyl relapse individual quitting fentanyl 0.8275065 0.7834752798080444
# individual relapsing after 7day break individual restarting subs 0.5707225 0.35923367738723755
# individual relapsed after quitting kratom individual quitting cold turkey for kratom dependency 0.7372674 0.7556953430175781
# individual experiencing relapse with 8mg of subconscious indivdual who snorted suboxone in fear of overdosing 0.7540793 0.30868643522262573
# individual relapsed and is trying to get back on subs person struggling to get back to subs after relapse 0.88376296 0.9000349640846252
# individual relapsed on fentanyl individual who relapsed on fentanyl 30 0.8967951 0.8710623979568481
# individual struggling with addiction and sleep issues individual on suboxone who used to use weed but now uses fentanyl for insomnia 0.62094903 0.4865022897720337
# individual trying to get off fent individual trying to quit fent 0.8226493 0.8590712547302246
# i relapsed on heroin for under week individual relapsed on heroin for 34 days and aims to resume moud 0.7733895 0.7695653438568115
# individual getting rid of prescription percs individual switching from fent to subs using oxy 0.61413956 0.10405109822750092
# individual trying to get off fentanyl and on to suboxone patient whose use of suboxone blocks cocaine high 0.81578505 0.63214111328125
# individual experiencing relapse individual taking substances and wants to start suboxone 0.6317697 0.23442843556404114
# individual experiencing chronic pain and addiction individual anticipating precipitated withdrawal 0.59070325 0.33078184723854065
# used it to get off of subs individual wondering if kratom helps with withdrawals 0.55313426 0.19916072487831116
# individual experiencing withdrawal symptoms individual wants to quit from 75mg suboxone 0.59520525 0.3654286861419678
# individual experiencing heroin relapse individual starting intake after last heroin dose 0.72204095 0.654045581817627
# individual relapsed after 3 years of subutex treatment individual who uses subutex but relapsed on heroin 0.79189616 0.7201664447784424
# individual struggling with addiction and medication management individual relapses with lots of medications 0.75394154 0.6193879246711731
# individual experiencing pain and weeping indivdual in pain planning to use kratom 0.61892766 0.29025477170944214
# 0 36 36
# relapse main-arguments subject/patient 0.0 0.0 0.0
# using around 1015 strong pressed 30s daily using around 1015 strong pressed 30’s daily 0.9052134 0.9742526412010193
# taking kratom taking kratom 0.99999994 0.9999999403953552
# taking kratom oxy 0.5818191 0.05702944099903107
# taking kratom diluadin 0.66988105 0.13743895292282104
# subs subs 1.0000001 1.0000001192092896
# subs diluadin 0.6078126 0.13063856959342957
# oxy oxy 1.0000001 1.0
# diluadin diluadin 1.0000001 1.0000001192092896
# taking fent analogues and delaying induction relapse to fent and percs 0.6112876 0.374557226896286
# taking bupe patches relapsing with morphine soon 0.49460799 0.21296928822994232
# taking oxycodone 20mg oxycodone this morning 0.8597623 0.7783268690109253
# taking oxycodone percs last night and this morning 0.40740505 0.07437606155872345
# occurrence of taking or using addictive substances back and forth between h and subs 0.4146965 -0.014646165072917938
# taking kratom and thc high dosing thc 0.76485974 0.7045606374740601
# had few beers on fathers day relapsed with beer on fathers day 0.8114983 0.844465434551239
# taking kratom took 3g of kratom 0.7602733 0.6356901526451111
# how does heroin use happen taking heroin 0.67969656 0.7489680647850037
# i relapsed yesterday and today havent taken suboxone since friday 0.6151992 0.4208493232727051
# taking fentanyl relapsing on fent after cold turkey withdrawal 0.4502415 0.44118204712867737
# relapse occurred after year on h and fent h and fent 0.6411331 0.47684404253959656
# taking 8mg of subconscious with nontolerance snorted 8mg suboxone 0.76904464 0.35744720697402954
# taking oxy 30s took oxy 30sfentanyl 0.7879209 0.828371524810791
# possibly fentanyl took oxy 30sfentanyl 0.6961376 0.2767762839794159
# after relapse took oxy 30sfentanyl 0.36119378 0.2566834092140198
# took fentanyl 30s for few days relapsed at 1130pm last night 0.54330325 0.29524439573287964
# taking fentanyl for sleep use fentanyl for sleep 0.8864337 0.9660135507583618
# i relapsed for 3 to 4 days relapse on heroin for 34 days 0.7626235 0.6838852763175964
# taking cocaine while on suboxone used coke and adderole while on suboxone 0.75348026 0.8049529790878296
# taking addictive substances taking blues 0.50488687 0.27274295687675476
# taking addictive substances bars 0.40288472 0.19123125076293945
# taking addictive substances and ice 0.44484946 0.11142614483833313
# taking part of one buprenorphine tablet kratom 0.48295167 0.16255798935890198
# taking part of one buprenorphine tablet h 0.24488162 -0.05093211308121681
# had no idea it existed until friend used kratom to get off subs 0.6011437 0.12269653379917145
# taking subs for 4 days dirty 30s and potential use of kratom if needed 0.5434861 0.09668941795825958
# taking heroin after 20 hours patient relapsing on heroin 0.7200619 0.6013433337211609
# heroin relapse after 6 months of use relapsed 6 months ago 0.75794196 0.7069540023803711
# heroin relapse after 6 months of use using 15 g herion per day 0.6883496 0.09673018753528595
# taking buprenophine and pregabalin without proper moderation 3mg clonazepam 0.76166177 0.40785592794418335
# taking buprenophine and pregabalin without proper moderation 2mg buprenophine 0.7691987 0.6414846181869507
# taking buprenophine and pregabalin without proper moderation 300mg pregabalin 0.48470682 0.6030929088592529
# taking kratom while on suboxone considering using kratom while on suboxone 0.8993857 0.959877610206604
# 4 35 39
# relapse main-arguments relapse-event 0.11428571428538775 0.10256410256383958 0.108108108057962
# getting suboxone script getting suboxone 0.82896143 0.7875547409057617
# dealing with withdrawal getting suboxone 0.64647084 0.16355179250240326
# start with super small dose of subs wants to start bernese method 0.6544352 0.23641842603683472
# slowly increase daily wants to start bernese method 0.57943183 0.10147175192832947
# seeking help from doctor and hoping for best hoping to get more help than suboxone to quit benzos 0.5708421 0.2793196737766266
# waiting 24 hours before starting subs subs 0.56542706 0.4328118562698364
# waiting for morphine prescription possible use of current bupe patch 0.56093585 0.0900794118642807
# taking suboxone taking 1mg or less of suboxone and gaging feeling before taking other 1mg 0.75542593 0.6944700479507446
# subject is trying to induce subs subs 0.5041451 0.5243841409683228
# waiting with 2mg of subs in bedside table starting subs tomorrow morning 0.54919726 0.3841628432273865
# wait week before starting treatment planing to take subacade 0.6095258 0.20050272345542908
# feeling too good following withdrawl procedure again 0.46864066 0.08220978081226349
# i havent taken my suboxone dose since friday night continuing suboxone 0.4733213 0.606545090675354
# taking kratom and then suboxone bernese method with sub 0.6205636 0.2290847897529602
# starting with 4mg am and 4pm plans to start subs with 4mg am 0.64453465 0.7622135877609253
# starting with 4mg am and 4pm 4pm 0.72721255 0.5346742868423462
# adjusting up if needed plans to start subs with 4mg am 0.5065995 0.2552243769168854
# adjusting up if needed 4pm 0.47861782 0.07188472151756287
# subject intends to quit suboxone subs after year 0.5392717 0.1911848485469818
# trying to take subs suboxone 0.54269624 0.41644877195358276
# but theyre not working suboxone 0.5119665 0.10905539989471436
# taking more suboxone for relief took sub at 630am 0.43765354 0.27043384313583374
# trying otc sleep meds taking suboxone while relapsing 0.74253666 0.19257692992687225
# ambien taking suboxone while relapsing 0.47216377 0.24572263658046722
# or benzo taking suboxone while relapsing 0.58061194 0.1513139307498932
# getting prescription wants to start suboxone 0.59685785 0.27987927198410034
# am i good to take small piece considering taking small piece of moud 0.75561064 0.55012047290802
# following treatment plan wants to start moud 0.58969945 0.2146405577659607
# waiting 24 hours after last opiate use buprenorphine tablets 0.64229274 0.40965455770492554
# taking 2mg dose moud intake after waiting for 20 hours 0.69496435 0.19133716821670532
# planning to get on methadone treatment plans to use methadone 0.7897942 0.9008482098579407
# 0 33 27
# relapse main-arguments resuming-moud-after-relapse 0.0 0.0 0.0
# sweating possible sweating and withdrawal symptoms if dose is too high 0.3807496 0.5346927642822266
# go into wds possible sweating and withdrawal symptoms if dose is too high 0.4067968 0.07449769228696823
# feeling sick and unfunctional due to benzo wd feeling very sick from kratom 0.726318 0.5352072715759277
# will i go into pwd if i dont wait to take it concerned about precipitated withdrawal 0.5021309 0.27071455121040344
# avoiding precipitated withdrawal cold turkey withdrawal 0.59257865 0.5821318626403809
# potential overdose and need for narcan possible overdose 0.5980267 0.648982048034668
# withdrawal symptoms still present despite taking full dose normal withdrawal symptoms despite full dose 0.9326817 0.939087986946106
# knees aching and hurting with no relief sickness 0.4908885 0.17611323297023773
# knees aching and hurting with no relief achy knees 0.61592084 0.5379188656806946
# stress and difficulty sleeping sleep troubles 0.63798296 0.7044457793235779
# can you drink while taking suboxone requires more alcohol to get drunk 0.6740788 0.3635154962539673
# can you drink while taking suboxone less enjoyable 0.34746626 -0.012812541797757149
# no feeling of cocaine high cant feel cocaine high 0.73241943 0.8881059885025024
# precipitated withdrawal possible precipitated withdrawal 0.95114 0.9594312906265259
# extremely easy for me withdrawals 0.43670726 0.1972549855709076
# feel sick might have paws from dirty 30s 0.48283556 0.05758420377969742
# paws from dirty 30s might have paws from dirty 30s 0.84016585 0.9149936437606812
# sweaty sweaty 1.0000001 1.0
# sweaty cannot sit still 0.57161814 0.281718909740448
# skin crawling skin crawling 1.0 1.0000001192092896
# cant sit still cannot sit still 0.7429808 0.9561108946800232
# sickness and arthritis symptoms experiencing sickness 0.61704564 0.6147295236587524
# still under influence of clonazepam zero wd symptoms 0.32438195 0.04003463312983513
# unable to manage meds zero wd symptoms 0.5209817 0.04543932527303696
# blocking effects of kratom by suboxone suboxone may block effects of kratom 0.9597782 0.9808081388473511
# 2 23 22
# relapse main-arguments effects 0.08695652173875237 0.09090909090867769 0.08888888883851852
# opioid use disorder percocet addiction 0.67751414 0.46697431802749634
# opioid use disorder fentanyl addiction 0.6314642 0.568220317363739
# opioid and benzo addiction was on opiates and benzos for 10 years 0.71117854 0.7013381123542786
# opioid and benzo addiction then methadone and clonazepam 0.7222518 0.46443676948547363
# substance use disorder recovering from opioid use disorder 0.7855837 0.5600271224975586
# heroin use disorder back and forth between h and subs 0.48717478 0.008012931793928146
# substance use disorder kratom and thc addict 0.5019199 0.4733947813510895
# fentanyl use disorder fent 0.43729997 0.4165436029434204
# substance use disorder off of subs for 7 days 0.47387117 0.05141030251979828
# kratom dependency kratom 0.8761625 0.6785656213760376
# opioid use disorder been on suboxone since august of 2021 0.4600666 0.2905558943748474
# fentanyl use disorder recovered from fentanyl 30s use 0.76966184 0.6352648735046387
# suboxone treatment weed and fent addict 0.5553373 0.2723127603530884
# fentanyl addiction fentanyl addiction 1.0000001 1.0
# opioid use disorder using blues 0.3911443 0.10040435940027237
# opioid use disorder bars 0.40705448 0.04028736427426338
# opioid use disorder and ice 0.3673185 0.026028724387288094
# opiate use disorder opiate use disorder 1.0 0.9999998807907104
# subutex use disorder relapsed on heroin 0.56140244 0.12383938580751419
# heroin addiction recovering from heroin addiction 0.8492157 0.8075442314147949
# 2 25 28
# relapse event-specific-arguments condition 0.07999999999968001 0.07142857142831634 0.07547169806308295
# benzo wd benzos withdrawal 0.7270576 0.5742059946060181
# availability of good heroin and disappearance of fentanyl shitty fent replacing good h 0.5099102 0.3127089738845825
# pw cold turkey withdrawal 0.51727784 0.12801142036914825
# naloxone in suboxone cold turkey withdrawal 0.40451005 0.08604821562767029
# fentanyl for sleep insomnia 0.52588224 0.4371081292629242
# relapse has arthritis 0.48805857 0.16746369004249573
# relapse doesnt want to deal with sickness 0.465113 0.21657347679138184
# 0 12 13
# relapse event-specific-arguments trigger 0.0 0.0 0.0
# fentanyl subs 0.36771965 0.05724162608385086
# methadone suboxone 0.65222186 0.5160515308380127
# clonazepam suboxone 0.6118494 0.3532829284667969
# xan suboxone 0.63466686 0.10540968179702759
# subs suboxone 0.6372401 0.35214412212371826
# oxy suboxone 0.5907413 0.42621904611587524
# diluadin suboxone 0.7260546 0.1376102864742279
# kratom suboxone 0.68420106 0.28886210918426514
# suboxone sub 0.6590155 0.37370967864990234
# bupe patches bupe patch 0.94221675 0.9494718313217163
# morphine bupe patch 0.6080477 0.2376817762851715
# oxycodone suboxone 0.62908375 0.5426725745201111
# none mentioned subs 0.6590257 0.1908840388059616
# thc subs 0.6120343 0.2553676962852478
# suboxone suboxone 1.0 1.0
# suboxone dose planning to change subs dose 0.63506883 0.5438565015792847
# kratom and suboxone bernese method 0.56358427 0.07154348492622375
# suboxone quitting cold turkey 0.58823824 0.10271614044904709
# narcan suggested to use narcan 0.72465396 0.796481728553772
# taking full dose of 22mg subs bernese method 0.46371865 0.11352886259555817
# took sub more subs 0.72714895 0.5898299217224121
# took sub comfort meds 0.51439375 0.038305461406707764
# took more throughout day more subs 0.66589683 0.30472996830940247
# took more throughout day comfort meds 0.5570309 0.1640535444021225
# otc sleep meds take sleep meds 0.81830573 0.6619113683700562
# otc sleep meds ambien 0.5215544 0.4475407898426056
# otc sleep meds benzo 0.5030761 0.16665324568748474
# ambien take sleep meds 0.5594879 0.39291852712631226
# ambien ambien 1.0 1.0
# benzo take sleep meds 0.5987935 0.1261572539806366
# benzo benzo 0.9999999 1.0000001192092896
# suboxone get suboxone from doctors in area 0.60713136 0.6520882248878479
# suboxone and methadone take 24mg for first month 0.4610781 0.2656518220901489
# suboxone and methadone then 8mg or less 0.49265867 0.284331738948822
# suboxone and methadone alcohol can help but no meth 0.67157453 0.4313075542449951
# taking part of one buprenorphine tablet wait 24 hours after last opiate use 0.74415845 0.46584126353263855
# dissolving under tongue wait 24 hours after last opiate use 0.5848662 0.11889346688985825
# 2mg of medication moud intake 0.61417365 0.15616104006767273
# methadone planning to use methadone 0.82764244 0.8021569848060608
# suboxone kratom while on suboxone 0.7228825 0.6629152297973633
# kratom kratom while on suboxone 0.7781838 0.6015783548355103
# 3 31 36
# relapse subject-effect-arguments intervention 0.09677419354807493 0.08333333333310185 0.08955223875598128
# results-Llama-3-8B-Instructbatch_question_guided_0.99.json
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Predictions/1-new-results-Llama-3-8B-Instruct.json
# batch description_guided 0.749
# person experiencing anxiety and butterflies individual altered treatment due to withdrawals 0.7378527 0.24555020034313202
# individual reducing medication dose individual seeking advice on splitting tablets 0.7241674 0.36297664046287537
# individual in post individual hating taste of strips asking about snorting 0.46582472 0.09897655248641968
# individual with tooth infection individual seeking information on tramadol and suboxone use 0.5762052 0.0376846082508564
# individual with heavy past experience with opioids individual wants to start taking suboxone 0.7307399 0.4051511585712433
# individual who switched from methadone to subs individual switching from methadone to subs 0.88749206 0.8857861757278442
# individual trying to quit slowly individual asking about cutting strips 0.787184 0.18356993794441223
# commenter individual who accidentally double dosed 0.4797941 0.1476771980524063
# friend individual asking for difference between strips and pills 0.35928962 0.03259466215968132
# individual trying to stretch supply individual considering boofing bupe 0.6472187 0.18628808856010437
# individual quitting percs indivudal who just quit percs fearing suboxone treatment 0.6416147 0.5972685813903809
# young individual taking 90mg addys 0.47676635 -0.024622054770588875
# 155 lbs individual taking 90mg addys 0.5620976 0.10847145318984985
# fast metabolism individual individual taking 90mg addys 0.5631444 0.27291643619537354
# individual undergoing methadone to suboxone switch individual switching from methadone to suboxone 0.9476705 0.916408360004425
# individual individual who got high from suboxone and wants to take more 0.2624888 0.08850428462028503
# curious individual individual willing to remove nalaxone from suboxone to avoid withdrawals 0.32432032 0.05221876874566078
# individual with addiction individual who always wants to take thier subs 0.5440389 0.3926296830177307
# dose doesnt last 24hrs waking up early with aching legs 0.5005527 0.062117159366607666
# aching legs waking up early with aching legs 0.7142076 0.6700297594070435
# uncomfortable waking up early with aching legs 0.42142978 0.22360646724700928
# no relapses feeling warm and fuzzy like kratom 0.512503 0.12437494844198227
# abstinence maintained feeling warm and fuzzy like kratom 0.4742467 -0.02125255949795246
# reset progress worrying about detox 0.6004165 0.17103330790996552
# getting sick after 8 hours mixing kratom and subs may not work 0.5962488 0.08125258982181549
# desire for more cravings 0.7464665 0.5144323110580444
# negative thoughts cravings 0.7876267 0.33862102031707764
# concerns about tolerance and contraindications probably high tolerance 0.49563178 0.39965543150901794
# withdrawal symptoms addicted to subs 0.62560755 0.2372269630432129
# withdrawal symptoms cant quit 0.59041053 0.4255645275115967
# withdrawal symptoms withdrawal 0.7734773 0.6977071166038513
# anxiety attacks addicted to subs 0.5667587 0.20323923230171204
# anxiety attacks cant quit 0.50589275 0.19345703721046448
# difficulty quitting addicted to subs 0.6876205 0.2877627909183502
# difficulty quitting cant quit 0.66659397 0.8102301359176636
# irregular sleep patterns wake up every hour 0.64003724 0.4329010844230652
# waking up every hour wake up every hour 0.9397142 0.8955116271972656
# loss of orgasmic function anorgasmia 0.61848426 0.24803516268730164
# withdraws withdrawal symptoms 0.68039376 0.5416828393936157
# feeling hopeless and wanting to quit pain from shots 0.6059868 0.13050389289855957
# slipped and used heroin withdrawal 0.52431035 0.37490540742874146
# feeling like zombie dependency 0.6412877 0.09741787612438202
# feeling like zombie zombielike state 0.7361744 0.6503598690032959
# feeling like zombie depression 0.6778005 0.4079155921936035
# feeling like zombie chronic fatigue 0.61096597 0.3291340470314026
# depression dependency 0.83327657 0.27154672145843506
# depression depression 1.0 1.0
# and chronic fatigue zombielike state 0.46734 0.1674671322107315
# and chronic fatigue chronic fatigue 0.80839163 0.7664414644241333
# 13 33 30
# taking-moud main-arguments effects 0.39393939393820016 0.4333333333318889 0.4126984126472159
# medications used in treatment suboxone 0.46879607 0.3055291175842285
# buprenorphine subs 0.41856447 0.17016413807868958
# subs subs strips 0.8779379 0.6687115430831909
# suboxone suboxone 1.0 1.0
# opioids suboxone 0.60296845 0.4491247832775116
# methadone methadone 0.99999994 1.0000001192092896
# buprenorphine buprenorphine 1.0 1.0
# pills and strips pillsstrips 0.70550084 0.6164283752441406
# buprenorphine bupe 0.5045616 0.46576303243637085
# suboxone suboxone 1.0 1.0
# addys naloxone 0.44375664 0.14678359031677246
# methadone suboxone 0.65222186 0.5160515308380127
# suboxone suboxone 1.0 1.0
# suboxone subxone 0.7989681 0.6358637809753418
# suboxone suboxone 1.0 1.0
# buprenorphine subs 0.41856447 0.17016413807868958
# subutex suboxone 0.6977222 0.5441408753395081
# buprenorphine buprenorphine 1.0 1.0
# suboxone sub 0.6590155 0.37370967864990234
# fent sub 0.64668584 0.2244819700717926
# percocet sub 0.56641257 0.1886790245771408
# sub strip suboxone 0.6527379 0.3806406855583191
# generic brands of bupe with and without naloxone subs 0.3931734 0.04585610330104828
# generic brands of bupe with and without naloxone subutex 0.46562642 0.25648829340934753
# fentanyl suboxone 0.6496843 0.4136883616447449
# suboxene suboxone 0.87658244 0.7365410327911377
# tapentadol tapentadol 1.0000001 1.0000001192092896
# suboxone suboxone 1.0 1.0
# 11 days 11 days 0.9999999 1.0
# 3 years and 3 months 3 years and 3 months 1.0 1.000000238418579
# week week 1.0000001 0.9999999403953552
# 1 year about year 0.6745636 0.6880276799201965
# several months last several months 0.81528795 0.747855544090271
# 4 days 4 days 1.0 1.0
# 4 years 4 years 1.0 1.0
# 10 15 12
# taking-moud event-specific-arguments treatment-duration 0.6666666666622222 0.8333333333263889 0.740740740685871
# oral orally 0.771724 0.8305009603500366
# orally and snorting sublingual 0.53589857 0.25094637274742126
# oral orally 0.771724 0.8305009603500366
# oral vs sublingualbuccal ublingually 0.40362597 0.14196696877479553
# oral orally 0.771724 0.8305009603500366
# orallysublingually dissolve in water and use syringe 0.43775877 0.18473458290100098
# taken orally absorbed through veins under tongue 0.5851213 0.37452787160873413
# orally oralsublingual 0.65997213 0.7053251266479492
# sublingual orally 0.55780464 0.3133595883846283
# orally between gumslipsplugged 0.3447084 0.39930927753448486
# sublingually between gumslipsplugged 0.54354787 0.3348439335823059
# orally orally 1.0000001 1.0000001192092896
# orally oralsublingual 0.65997213 0.7053251266479492
# ...
# opioid use disorder percocet addiction 0.67751414 0.46697431802749634
# opioid use disorder fentanyl addiction 0.6314642 0.568220317363739
# opioid and benzo addiction was on opiates and benzos for 10 years 0.71117854 0.7013381123542786
# opioid and benzo addiction then methadone and clonazepam 0.7222518 0.46443676948547363
# substance use disorder recovering from opioid use disorder 0.7855837 0.5600271224975586
# heroin use disorder back and forth between h and subs 0.48717478 0.008012931793928146
# substance use disorder kratom and thc addict 0.5019199 0.4733947813510895
# fentanyl use disorder fent 0.43729997 0.4165436029434204
# substance use disorder off of subs for 7 days 0.47387117 0.05141030251979828
# kratom dependency kratom 0.8761625 0.6785656213760376
# opioid use disorder been on suboxone since august of 2021 0.4600666 0.2905558943748474
# fentanyl use disorder recovered from fentanyl 30s use 0.76966184 0.6352648735046387
# suboxone treatment weed and fent addict 0.5553373 0.2723127603530884
# fentanyl addiction fentanyl addiction 1.0000001 1.0
# opioid use disorder using blues 0.3911443 0.10040435940027237
# opioid use disorder bars 0.40705448 0.04028736427426338
# opioid use disorder and ice 0.3673185 0.026028724387288094
# opiate use disorder opiate use disorder 1.0 0.9999998807907104
# subutex use disorder relapsed on heroin 0.56140244 0.12383938580751419
# heroin addiction recovering from heroin addiction 0.8492157 0.8075442314147949
# 2 25 28
# relapse event-specific-arguments condition 0.07999999999968001 0.07142857142831634 0.07547169806308295
# benzo wd benzos withdrawal 0.7270576 0.5742059946060181
# availability of good heroin and disappearance of fentanyl shitty fent replacing good h 0.5099102 0.3127089738845825
# pw cold turkey withdrawal 0.51727784 0.12801142036914825
# naloxone in suboxone cold turkey withdrawal 0.40451005 0.08604821562767029
# fentanyl for sleep insomnia 0.52588224 0.4371081292629242
# relapse has arthritis 0.48805857 0.16746369004249573
# relapse doesnt want to deal with sickness 0.465113 0.21657347679138184
# 0 12 13
# relapse event-specific-arguments trigger 0.0 0.0 0.0
# fentanyl subs 0.36771965 0.05724162608385086
# methadone suboxone 0.65222186 0.5160515308380127
# clonazepam suboxone 0.6118494 0.3532829284667969
# xan suboxone 0.63466686 0.10540968179702759
# subs suboxone 0.6372401 0.35214412212371826
# oxy suboxone 0.5907413 0.42621904611587524
# diluadin suboxone 0.7260546 0.1376102864742279
# kratom suboxone 0.68420106 0.28886210918426514
# suboxone sub 0.6590155 0.37370967864990234
# bupe patches bupe patch 0.94221675 0.9494718313217163
# heroin heroin 1.0 0.9999999403953552
# heroin heroin 1.0 0.9999999403953552
# heroin clonazepam and pregabalin 0.40234783 0.19952215254306793
# kratom kratom 1.0 1.0
# 12 32 41
# relapse event-specific-arguments relapse-substance 0.3749999999988281 0.2926829268285544 0.32876712323753043
# 3 days 3 days 1.0 1.0
# less than 12 hours two days 0.7694153 0.6099355220794678
# 1 day one day 0.75720555 0.8594462871551514
# 2 days yesterday and today 0.6538601 0.4147115647792816
# year one year 0.65159154 0.6878727674484253
# few days several days 0.9084104 0.8521144390106201
# 34 days 34 days 1.0000001 1.0
# ongoing one day 0.6224894 0.27737098932266235
# 6 months 6 months 1.0 1.0
# unknown two days last night 0.48104694 0.27759963274002075
# unknown this morning 0.6259484 0.2883065342903137
# 3 11 12
# relapse event-specific-arguments relapse-duration 0.2727272727247934 0.24999999999791667 0.26086956516521737
# suboxone script started taking suboxone 0.5959101 0.6484803557395935
# bernese method bernese method 0.9999999 1.0000001192092896
# 4 15mg percs switching back to suboxone 0.54416394 0.1446455717086792
# taking 1 mg or less of subs taking suboxone again 0.6866443 0.5199445486068726
# support group help quitting with support group help 0.78422713 0.7726240158081055
# none continue taking subs 0.604614 0.08780664205551147
# suboxone bernese method 0.60902154 0.11415667831897736
# tough it out subs 0.48728156 0.16956444084644318
# update suggested to use narcan 0.47080675 0.06507051736116409
# trying to get back off oxy and take subs trying to switch back to suboxone 0.72089714 0.5504250526428223
# taking more suboxone taking more subs 0.6696343 0.4399554431438446
# seeking help use sleep meds 0.56468314 0.09016938507556915
# seeking help ambien 0.52150345 0.2018330991268158
# seeking help benzos 0.61662585 0.20447981357574463
# medical supervision wants to start moud 0.49961168 0.1396143138408661
# medical supervision start at 24mg 0.48163503 0.045766495168209076
# medical supervision no meth 0.61036766 0.10694469511508942
# none mentioned quickmd 0.6867078 0.22884535789489746
# none mentioned buprenorphine 0.41479772 0.18175579607486725
# subutex plan to use methadone 0.44398963 0.12078887969255447
# 1 19 25
# relapse event-specific-arguments relapse-intervention 0.05263157894709142 0.039999999999840004 0.04545454540526861
# 36 hours 36 hours 0.9999999 1.000000238418579
# 26 hours 26 hours after last fent 0.6962218 0.5916523933410645
# 26 hours 1 hour after percs 0.71561867 0.3625604510307312
# 3 weeks one week 0.7962649 0.7498917579650879
# 3 days three days 0.88923156 0.9686784148216248
# after last dose of suboxone 72 hours 0.42334864 0.16018524765968323
# 7 days 7 days 1.0000001 1.000000238418579
# 6 hours 7hrs 0.76667947 0.7638030052185059
# 24 hours 24 hours 0.9999999 1.0
# 2 hours 20 hours 0.934708 0.7653253078460693
# unknown couple hours last night 0.4994113 0.22650742530822754
# unknown this morning 0.6259484 0.2883065342903137
# 3 11 13
# relapse event-specific-arguments waiting-time 0.2727272727247934 0.23076923076745562 0.24999999994826386
# 22 22 0.9999999 1.0
# 33 33 1.0 1.0000001192092896
# 2 2 2
# relapse subject-effect-arguments age 0.99999999995 0.99999999995 0.9999999999
# male male 1.0 1.0
# 1 3 3
# relapse subject-effect-arguments gender 0.3333333333222222 0.3333333333222222 0.3333333332722222
# bridged with percs wait 24 hours 0.53767836 -0.0027921777218580246
# bridged with percs start off with 1 mg 0.5178635 0.07194235920906067
# wearing bupe patch wait 5 days for morphine to work 0.5372964 0.12693718075752258
# support group help quitting with support group help 0.78422713 0.7726240158081055
# suboxone 2mg need more than 2mg of subs 0.5949856 0.650827169418335
# thc need more than 2mg of subs 0.43290687 0.1518377661705017
# tapering with sublocade switching clinics 0.5050735 0.05881915241479874
# tapering off subs regular supply of subs 0.74630255 0.4512713551521301
# considering 7 or 14 day taper regular supply of subs 0.6046194 0.06945952773094177
# suboxone dose planning to change subs dose 0.63506883 0.5438565015792847
# kratom and suboxone bernese method 0.56358427 0.07154348492622375
# suboxone quitting cold turkey 0.58823824 0.10271614044904709
# narcan suggested to use narcan 0.72465396 0.796481728553772
# taking full dose of 22mg subs bernese method 0.46371865 0.11352886259555817
# took sub more subs 0.72714895 0.5898299217224121
# took sub comfort meds 0.51439375 0.038305461406707764
# took more throughout day more subs 0.66589683 0.30472996830940247
# took more throughout day comfort meds 0.5570309 0.1640535444021225
# otc sleep meds take sleep meds 0.81830573 0.6619113683700562
# otc sleep meds ambien 0.5215544 0.4475407898426056
# otc sleep meds benzo 0.5030761 0.16665324568748474
# ambien take sleep meds 0.5594879 0.39291852712631226
# ambien ambien 1.0 1.0
# benzo take sleep meds 0.5987935 0.1261572539806366
# benzo benzo 0.9999999 1.0000001192092896
# suboxone get suboxone from doctors in area 0.60713136 0.6520882248878479
# suboxone and methadone take 24mg for first month 0.4610781 0.2656518220901489
# suboxone and methadone then 8mg or less 0.49265867 0.284331738948822
# suboxone and methadone alcohol can help but no meth 0.67157453 0.4313075542449951
# taking part of one buprenorphine tablet wait 24 hours after last opiate use 0.74415845 0.46584126353263855
# dissolving under tongue wait 24 hours after last opiate use 0.5848662 0.11889346688985825
# 2mg of medication moud intake 0.61417365 0.15616104006767273
# methadone planning to use methadone 0.82764244 0.8021569848060608
# suboxone kratom while on suboxone 0.7228825 0.6629152297973633
# kratom kratom while on suboxone 0.7781838 0.6015783548355103
# 3 31 36
# relapse subject-effect-arguments intervention 0.09677419354807493 0.08333333333310185 0.08955223875598128
# results-Llama-3-8B-Instructbatch_question_guided_0.99.json
# /content/drive/Shareddrives/Reddit Misinformation/Data/New-Avg-Run-Experiments/Argument-Extraction-Predictions/2-new-results-Llama-3-8B-Instruct.json
# CPU times: user 2h 13min 57s, sys: 14min 31s, total: 2h 28min 29s
# Wall time: 5h 19min 44s

# %% [markdown]
# printing to understanding the nesting in the results dict

# %%
print(results_dict.keys())
print(results_dict['batch_description_guided_0.749'].keys())
print(results_dict['batch_description_guided_0.749']['tapering'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments'].keys())
print(results_dict['batch_description_guided_0.749']['tapering']['main-arguments']['effects'])
# Out:
# dict_keys(['batch_description_guided_0.749', 'batch_description_guided_0.99', 'batch_question_guided_0.749', 'batch_question_guided_0.99', 'isolated_description_guided_0.749', 'isolated_description_guided_0.99', 'isolated_question_guided_0.749', 'isolated_question_guided_0.99'])
# dict_keys(['taking-moud', 'tapering', 'relapse'])
# dict_keys(['main-arguments', 'event-specific-arguments', 'subject-effect-arguments'])
# dict_keys(['subject/patient', 'effects', 'tapering-event'])
# [[0.4583333333314236, 0.54999999999725, 0.49999999994814043], [11, 24, 20]]
